# %%
with open('./dataset.json', 'r', encoding='utf-8') as file:  
    data = file.read()  
  
# 将「」替换为双引号  
updated_data = data.replace('「', '“').replace('」', '”') 

updated_data = data.replace('『', '“').replace('』', '”') 

updated_data = data.replace('「', '“').replace('」', '”') 
# 将替换后的内容写回文件  
with open('./dataset2.json', 'w', encoding='utf-8') as file:  
    file.write(updated_data)

# %%
import json  
  
# 打开JSON文件并加载数据  
with open('./dataset2.json', 'r',encoding='utf-8') as file:
    json_data = file.readlines()  
  
# 将每四行数据合并为一个JSON对象  
novel_data = []
for i in range(0, len(json_data), 4):  
    json_str = ''.join(json_data[i:i+4])  
    json_obj = json.loads(json_str)  
    novel_data.append(json_obj)

# %%
novel_data[0].keys(), len(novel_data)
# Out:
# (dict_keys(['name', 'text']), 9239)

# %%
for i in novel_data:
    print(f"《{i['name']}》的字数为： {len(i['text'])} 字")
# Out:
# 《10. 再战登云台》的字数为： 12837 字
# 《看过哪些《爱格》中的虐心故事？ - 红尘 的回答 - 知乎》的字数为： 8631 字
# 《考研专业课应该如何复习？ - 知乎(1)》的字数为： 3925 字
# 《9. 仙门大比》的字数为： 12135 字
# 《8. 但为洲民故》的字数为： 12000 字
# 《如何以 “姐姐，别这样” 写一篇病娇文？ - 知乎(1)》的字数为： 15758 字
# 《7. 少主及笄礼》的字数为： 12895 字
# 《有哪些经典的打脸案例？ - 知乎》的字数为： 11085 字
# 《你的帅哥朋友是在哪里找的？ - 知乎》的字数为： 14865 字
# 《6. 剑君多欢喜》的字数为： 10702 字
# 《5. 梦回鲤鱼洲》的字数为： 12255 字
# 《世界上真的存在完美犯罪吗？ - 知乎(1)》的字数为： 11775 字
# 《49. 打脸顶流小花后，我全网爆红》的字数为： 14513 字
# 《有一个外科医生朋友是种怎样的体验？ - 知乎》的字数为： 15567 字
# 《有没有能把你甜哭的短篇小说_ - 知乎》的字数为： 12195 字
# 《48. 迟来的布洛芬》的字数为： 12164 字
# 《47. 煤老板靠塌房爆红啦》的字数为： 10699 字
# 《如何系统地训练口才？ - 知乎》的字数为： 3870 字
# 《4. 美人蛇蝎》的字数为： 11414 字
# 《如果唐僧拥有扫地僧的实力会对整个西游有什么影响？ - 知乎-f4b0ad5b3e6a》的字数为： 11882 字
# 《如何写一个反俗套的穿越故事？ - 知乎(1)》的字数为： 6737 字
# 《3. 小鬼阿溯》的字数为： 11508 字
# 《2. 他与千叶镇》的字数为： 14446 字
# 《男友对初恋念念不忘，我该怎么办？ - 知乎》的字数为： 12965 字
# 《1. 挑落登云台》的字数为： 15423 字
# 《如何真正客观评价项羽？ - 知乎(1)》的字数为： 5722 字
# 《有没有文笔绝佳高质量的言情小说_ - 知乎》的字数为： 15504 字
# 《50. 奶奶来了》的字数为： 11897 字
# 《有没有让你意难平的短篇小说？ - 宫墙往事 的回答 - 知乎》的字数为： 9180 字
# 《46. 软饭男友》的字数为： 15880 字
# 《有哪些主乖乖软软的小说？ - 知乎-3d5f0920379c》的字数为： 15683 字
# 《你遇到过的最恶心的事是什么？ - 知乎》的字数为： 13699 字
# 《45. 没素质后精神状态好很多》的字数为： 15588 字
# 《44. 替身的复仇》的字数为： 15720 字
# 《有文化可以有多可怕？ - 知乎》的字数为： 13121 字
# 《43. 极光下的向日葵》的字数为： 13115 字
# 《如何以“『你若敢喝，本王让你全族陪葬！』他刚说完，我端起毒酒一口饮下”为开头写个故事？ - 知乎》的字数为： 15557 字
# 《有一个很会的朋友是什么感受？ - 知乎-1aaf1e59d2e8》的字数为： 15743 字
# 《42. 拒绝雌竞，我和国民女神成了闺蜜》的字数为： 10460 字
# 《41. 穿书后我赢麻了》的字数为： 15070 字
# 《如何以“我把男主养废了”为开头写一个故事？ - 知乎》的字数为： 12145 字
# 《40. 嫁入豪门后，我靠摆烂爆红》的字数为： 13317 字
# 《有没有什么特别恐怖的鬼故事短篇的，适合半夜看的？ - 知乎》的字数为： 10562 字
# 《你经历过的尴尬是什么？ - 知乎》的字数为： 13385 字
# 《39. 疯批竹马》的字数为： 15542 字
# 《38. 后妈带绿茶娃上综艺后爆火了》的字数为： 15619 字
# 《如何以“我是京城第一美人”写一篇故事？ - 知乎》的字数为： 15648 字
# 《有哪些比较好看的重生小说_ - 知乎 (1)》的字数为： 15573 字
# 《27. 滚蛋吧，绿茶校花》的字数为： 13008 字
# 《26. 制霸娃综后，我成了全民儿媳》的字数为： 11693 字
# 《有没有好看的伪兄甜宠古言小说推荐？ - 知乎 (1)》的字数为： 15509 字
# 《25. 忠犬男友会鉴婊》的字数为： 10956 字
# 《有哪些不无脑甜文笔好的言情小说推荐_ - 知乎》的字数为： 15604 字
# 《哪些瞬间让你感受到父母对你的真实恶意？ - 知乎》的字数为： 12170 字
# 《24. 我帮妈妈爆红成顶流》的字数为： 15682 字
# 《23. 我和儿子在恐怖综艺爆火》的字数为： 15161 字
# 《真的是前任一哭现任必输吗？ - 公子词 的回答 - 知乎》的字数为： 5965 字
# 《37. 和前男友反击绿茶后我翻红了》的字数为： 12208 字
# 《为什么养宠物不能养猴子？ - 知乎》的字数为： 9021 字
# 《跟钢铁直男相处是种怎样的体验？ - 知乎》的字数为： 8183 字
# 《36. 网恋悖论》的字数为： 12925 字
# 《35. 后妈对照组反向带娃爆红了》的字数为： 10586 字
# 《有哪些甜甜的恋爱故事？ - 知乎(1)》的字数为： 10529 字
# 《34. 撕伞的快乐》的字数为： 15507 字
# 《你看过最爽的爽文有多爽？ - 小仙 的回答 - 知乎》的字数为： 15551 字
# 《可以分享一个最见不得人的秘密吗？ - 知乎》的字数为： 15371 字
# 《33. 穿成对照组女配后我爆火了》的字数为： 15577 字
# 《32. 夏日骄阳》的字数为： 15597 字
# 《生活中有没有特别绿茶的女生？ - 知乎(1)》的字数为： 9420 字
# 《31. 手撕登堂入室的保姆》的字数为： 14260 字
# 《如果你是虐文里的女主你会怎么办？ - 知乎》的字数为： 15489 字
# 《你所见过的最厉害的小三都有哪些手段？说说吧？ - 知乎》的字数为： 13063 字
# 《30. 真心为你》的字数为： 14484 字
# 《29. 卷王在选秀综艺翻红了》的字数为： 15736 字
# 《人类知道世界的终极真理后会疯掉吗_ - 知乎(1)》的字数为： 12724 字
# 《28. 他是会鉴茶的疯批恋爱脑》的字数为： 14423 字
# 《历史上有哪些开始被认为是占了大便宜，后来却吃亏的事情？ - 知乎》的字数为： 9832 字
# 《有哪些实用的心理学技巧 ？ - 盐选成长计划 的回答 - 知乎》的字数为： 3861 字
# 《22. 海岛求生后，我爆红娱乐圈！》的字数为： 15616 字
# 《病娇可怕么？ - 知乎》的字数为： 15727 字
# 《是什么原因突然就让你放弃了一个一直喜欢追求很久的人？ - 知乎 - 副本(1)》的字数为： 10818 字
# 《21. 摆烂后我爆红了》的字数为： 15761 字
# 《20. 向阳而生》的字数为： 14857 字
# 《你听过哪些真实的灵异事件？ - 知乎》的字数为： 9383 字
# 《女人的第六感究竟可怕到什么程度？ - 知乎》的字数为： 13237 字
# 《19. 我靠预言之力在娱乐圈爆火》的字数为： 15563 字
# 《亲子鉴定中心有哪些毁三观的事。？ - 知乎(1)》的字数为： 15165 字
# 《你听过最恐怖故事是什么？ - 知乎》的字数为： 15527 字
# 《18. 小作精的鱿鱼游戏》的字数为： 13011 字
# 《17. 同根生》的字数为： 11449 字
# 《大家都是在什么情况下表白的？表白说什么呀？ - 知乎 (1)》的字数为： 12066 字
# 《16. 反杀黑心闺蜜》的字数为： 10899 字
# 《有没有能甜到打滚的小说？ - 知乎 (3)》的字数为： 15632 字
# 《暗恋时最心塞的瞬间是哪一刻？ - 知乎》的字数为： 15762 字
# 《15. 绿茶青梅爱上我》的字数为： 10712 字
# 《14. 亲妈是真千金》的字数为： 15716 字
# 《有什么追男生的小招数？ - 知乎(1)》的字数为： 15342 字
# 《13. 我用铁锅征服荒野》的字数为： 11211 字
# 《你所经历过的最恐怖惊悚的故事是什么？ - 知乎(1)》的字数为： 9912 字
# 《如何以【我将来是要做皇后的】为开头，写一篇故事？ - 知乎》的字数为： 14377 字
# 《12. 我靠C语言火爆全网》的字数为： 15666 字
# 《11. 我和继女在娃综互掐爆火娱乐圈》的字数为： 15928 字
# 《女人的第六感究竟可怕到什么程度？ - 知乎》的字数为： 13237 字
# 《10. 星光逆袭》的字数为： 13112 字
# 《现代如果有天庭会是是什么样子？ - 知乎》的字数为： 10246 字
# 《读的书很快会忘掉，那么读书的意义在哪里_ - 知乎》的字数为： 4178 字
# 《9. 除我外所有人都重生了》的字数为： 10902 字
# 《8. 发疯系甜妹》的字数为： 14649 字
# 《被病娇喜欢是怎样一种体验？ - 知乎》的字数为： 15571 字
# 《7. 网红绿茶老师冒充我》的字数为： 10927 字
# 《有没有主三观正，不傻白甜，小说逻辑通畅的值得阅读的言情小说？ - 知乎-df412f6ef96f》的字数为： 15306 字
# 《你经历过哪些大型社死现场？ - 知乎》的字数为： 15612 字
# 《6. 归国网红》的字数为： 12691 字
# 《5. 小糊咖疯狂掉马后》的字数为： 13376 字
# 《有哪些真实发生的著名连环或变态杀人案？ - 知乎》的字数为： 11582 字
# 《4. 恋爱脑觉醒后》的字数为： 12899 字
# 《如何以“怎么？这就哭了？”为开头写一篇小说_ - 知乎》的字数为： 15645 字
# 《如何以“不许摸”为开头写一个故事_ - 知乎》的字数为： 15554 字
# 《3. 歹毒汉子茶》的字数为： 12665 字
# 《2. 热水冲泡汉子茶》的字数为： 11046 字
# 《教师资格证考试，考高中教资还是初中教资？有什么区别吗？难度差别如何？ - 知乎(1)》的字数为： 6662 字
# 《1. 我靠怂在娱乐圈爆火》的字数为： 15801 字
# 《能不能从霸道总裁的手下的角度写故事？ - 知乎》的字数为： 15496 字
# 《突然知道一个被瞒了很久的秘密是一种怎样的体验？ - Seasee Youl 的回答 - 知乎》的字数为： 9573 字
# 《16. 反杀黑心闺蜜》的字数为： 10899 字
# 《有没有能甜到打滚的小说？ - 知乎 (3)》的字数为： 15632 字
# 《暗恋时最心塞的瞬间是哪一刻？ - 知乎》的字数为： 15762 字
# 《15. 绿茶青梅爱上我》的字数为： 10712 字
# 《14. 亲妈是真千金》的字数为： 15716 字
# 《有什么追男生的小招数？ - 知乎(1)》的字数为： 15342 字
# 《13. 我用铁锅征服荒野》的字数为： 11211 字
# 《你所经历过的最恐怖惊悚的故事是什么？ - 知乎(1)》的字数为： 9912 字
# 《如何以【我将来是要做皇后的】为开头，写一篇故事？ - 知乎》的字数为： 14377 字
# 《12. 我靠C语言火爆全网》的字数为： 15666 字
# 《11. 我和继女在娃综互掐爆火娱乐圈》的字数为： 15928 字
# 《女人的第六感究竟可怕到什么程度？ - 知乎》的字数为： 13237 字
# 《10. 星光逆袭》的字数为： 13112 字
# 《现代如果有天庭会是是什么样子？ - 知乎》的字数为： 10246 字
# 《读的书很快会忘掉，那么读书的意义在哪里_ - 知乎》的字数为： 4178 字
# 《9. 除我外所有人都重生了》的字数为： 10902 字
# 《8. 发疯系甜妹》的字数为： 14649 字
# 《被病娇喜欢是怎样一种体验？ - 知乎》的字数为： 15571 字
# 《7. 网红绿茶老师冒充我》的字数为： 10927 字
# 《有没有主三观正，不傻白甜，小说逻辑通畅的值得阅读的言情小说？ - 知乎-df412f6ef96f》的字数为： 15306 字
# 《你经历过哪些大型社死现场？ - 知乎》的字数为： 15612 字
# 《6. 归国网红》的字数为： 12691 字
# 《5. 小糊咖疯狂掉马后》的字数为： 13376 字
# 《有哪些真实发生的著名连环或变态杀人案？ - 知乎》的字数为： 11582 字
# 《4. 恋爱脑觉醒后》的字数为： 12899 字
# 《如何以“怎么？这就哭了？”为开头写一篇小说_ - 知乎》的字数为： 15645 字
# 《如何以“不许摸”为开头写一个故事_ - 知乎》的字数为： 15554 字
# 《3. 歹毒汉子茶》的字数为： 12665 字
# 《2. 热水冲泡汉子茶》的字数为： 11046 字
# 《教师资格证考试，考高中教资还是初中教资？有什么区别吗？难度差别如何？ - 知乎(1)》的字数为： 6662 字
# 《1. 我靠怂在娱乐圈爆火》的字数为： 15801 字
# 《能不能从霸道总裁的手下的角度写故事？ - 知乎》的字数为： 15496 字
# 《突然知道一个被瞒了很久的秘密是一种怎样的体验？ - Seasee Youl 的回答 - 知乎》的字数为： 9573 字
# 《有哪些实用的心理学技巧 ？ - 盐选成长计划 的回答 - 知乎》的字数为： 3861 字
# 《如何以“我把病娇睡了”为开头，写一篇小说？ - 知乎》的字数为： 15581 字
# 《如何以“摄政王和阿姊圆房那天，喊的是我的名字”为开头写一篇小说？ - 知乎》的字数为： 15633 字
# 《43. 致命婆婆》的字数为： 10489 字
# 《42. 逃离人贩村》的字数为： 11119 字
# 《部分性侵类案件中受害人为什么会被强奸致死？ - 知乎》的字数为： 10679 字
# 《41. 爱亡城》的字数为： 15642 字
# 《高三有哪些相见恨晚的刷题技巧？ - 知乎》的字数为： 7152 字
# 《你从什么时候觉得平行时空一定存在的？ - 知乎》的字数为： 15763 字
# 《40. 沼泽恶花》的字数为： 13398 字
# 《39. 反方向时钟》的字数为： 13612 字
# 《有没有女主先动心，男主一开始对女主冷淡，后来追妻火葬场的文？ - 知乎(1)》的字数为： 12636 字
# 《38. 脂肪胎》的字数为： 15762 字
# 《你们经历过哪些道德绑架的事？ - 知乎》的字数为： 11896 字
# 《生眼里的白月光是一个怎么样的存在？ - 知乎》的字数为： 11524 字
# 《37. 在我的开始是你的结束》的字数为： 10941 字
# 《36. 赴生之途》的字数为： 13943 字
# 《嫁给一个有钱人是不是一辈子都舒服得多？ - 知乎》的字数为： 10412 字
# 《35. 罪恶之花》的字数为： 10494 字
# 《有哪些言情小说是你心中的白月光朱砂痣？ - 知乎-fb02adaf046a》的字数为： 13245 字
# 《有什么厉害的记忆方法？ - 知乎》的字数为： 10135 字
# 《34. 丈夫针》的字数为： 15989 字
# 《33. 昼颜》的字数为： 15826 字
# 《真正的黑社会是什么样子的呢？ - 知乎》的字数为： 3786 字
# 《32. 恶毒女配我怕谁》的字数为： 12082 字
# 《有没有短一点的先婚后爱小甜文？ - 知乎(1)》的字数为： 15479 字
# 《有那种高岭之花主，被主勾引拉下神坛的文吗？ - 知乎》的字数为： 15546 字
# 《31. 鹭江往事》的字数为： 10621 字
# 《30. 禁闭游戏》的字数为： 11660 字
# 《历史上有哪些“君子报仇，十年不晚”的实例？ - 知乎》的字数为： 14569 字
# 《29. 千金赌约》的字数为： 14178 字
# 《对喜欢的人彻底死心是种怎样的体验？ - 知乎(1)》的字数为： 11319 字
# 《有哪一瞬间你觉得男朋友或老公很陋（low）？ - 知乎(2)》的字数为： 11101 字
# 《28. 老来得子》的字数为： 13465 字
# 《27. 白月光黑化了》的字数为： 15722 字
# 《如何以“我是皇帝，但皇后不爱我”为开头写一个故事？ - 知乎》的字数为： 15570 字
# 《26. 不再见》的字数为： 12490 字
# 《索罗斯能做空中国么？ - 知乎》的字数为： 2733 字
# 《如果拿五百万去澳门赌博，赢到了十几亿，不考虑赢钱的人的主观因素，赌场的人会放他带着巨款离开澳门吗？ - 知乎》的字数为： 10591 字
# 《25. 占有即深渊》的字数为： 11690 字
# 《24. 无处可逃》的字数为： 14328 字
# 《怎样提高说话时的瞬时反应能力？ - 知乎(1)》的字数为： 3758 字
# 《23. 灵魂互换后》的字数为： 15553 字
# 《有哪些很惨的女主角？ - 知乎》的字数为： 15476 字
# 《被人当做替身是一种什么样的感觉？ - 知乎(1)》的字数为： 12430 字
# 《22. 五女一子》的字数为： 12930 字
# 《21. 月光寂灭》的字数为： 11501 字
# 《逻辑思维差的人怎么锻炼思维，使思维清晰？ - 知乎(1)》的字数为： 4525 字
# 《20. 荆棘女孩》的字数为： 15593 字
# 《有哪些恶有恶报的故事？ - 知乎 (2)》的字数为： 12164 字
# 《有哪些你明知是假却希望是真的故事？ - 知乎(1)》的字数为： 9546 字
# 《19. 博导老公非自然死亡后》的字数为： 15557 字
# 《18. 心战役》的字数为： 10261 字
# 《有哪些令人浑身发抖的故事？ - 知乎(3)》的字数为： 10391 字
# 《17. 三年深情不及她》的字数为： 15487 字
# 《如果渣和渣在一起会怎样，会发生什么事？ - 知乎-ce401d2b7582》的字数为： 15743 字
# 《你穿到一个修仙文变成了一个试图勾引男主的恶毒女配，怎么办？ - 知乎(1)》的字数为： 8428 字
# 《16. 亲生女儿回家后》的字数为： 12921 字
# 《15. 房产之争》的字数为： 11112 字
# 《你见过的最神奇的朋友圈是什么？ - 知乎》的字数为： 9996 字
# 《14. 向阳而生》的字数为： 13306 字
# 《有哪些半小时内就能看完的超甜小故事？ - 知乎(1)》的字数为： 11860 字
# 《你见过哪些不按套路出牌的人？ - 知乎(1)》的字数为： 11874 字
# 《13. 神的仆人》的字数为： 12255 字
# 《12. 恶毒婆婆就是我》的字数为： 15021 字
# 《如何以“我做天妃200年了”为开头写个故事？ - 知乎(1)》的字数为： 15598 字
# 《11. 以我之名》的字数为： 12562 字
# 《中国近代历史上，有哪些全军覆没的部队？ - 知乎(1)》的字数为： 9224 字
# 《如果中国爆发丧尸怎么办？ - 知乎(2)》的字数为： 15548 字
# 《10. 烟疤》的字数为： 15523 字
# 《9. 陌生老公》的字数为： 14607 字
# 《父母的眼界真的决定孩子的眼界吗_ - 知乎(1)》的字数为： 10771 字
# 《8. 妹妹申请出战》的字数为： 10812 字
# 《你们谈恋爱累吗？ - 知乎(1)》的字数为： 15774 字
# 《当沙雕女主遇到病娇偏执男主会发生什么_ - 知乎》的字数为： 15556 字
# 《7. 放马过来》的字数为： 15398 字
# 《6. 保温壶是无辜的》的字数为： 15487 字
# 《你见过一眼就让你怦然心动 漂亮_可爱的神_生是什么样的？ - 知乎》的字数为： 12597 字
# 《5. 重生之反击闺蜜》的字数为： 11038 字
# 《那些喜欢大叔的女生后来怎么样了？ - 知乎(1)》的字数为： 12423 字
# 《4. 驯服野犬》的字数为： 15595 字
# 《3. 小姨失踪后》的字数为： 11332 字
# 《2. 时间游戏》的字数为： 15623 字
# 《卧底被毒贩发现，毒贩会做出什么残忍疯狂的行为？ - 知乎(1)》的字数为： 7199 字
# 《如何以“我囚禁了天帝近百年”为开头写个故事？ - 知乎》的字数为： 15582 字
# 《1. siri杀人始末》的字数为： 10627 字
# 《男生失去了很好的女生会后悔吗？ - 知乎(4)》的字数为： 9839 字
# 《50. 心动难逃》的字数为： 15569 字
# 《出轨真的会上瘾吗？ - 知乎(1)》的字数为： 6053 字
# 《有哪些真实的甜到齁甜到腻的爱情故事？ - 知乎(1)》的字数为： 10046 字
# 《49. 我与她，落轮回》的字数为： 15562 字
# 《48. 抄家前我搬空家产》的字数为： 10993 字
# 《大学生考研好还是直接就业好？ - 知乎》的字数为： 4459 字
# 《47. 遥念长安》的字数为： 15180 字
# 《为什么有些情侣谈着就感情越来越淡有些却越来越深？ - 知乎》的字数为： 5514 字
# 《健身房真的很乱吗？ - 知乎》的字数为： 8061 字
# 《46. 暮雨潇》的字数为： 15576 字
# 《45. 不信人间有白头》的字数为： 15789 字
# 《智商被侮辱的感觉是怎样的？ - 知乎》的字数为： 15584 字
# 《44. 锦绣阑珊》的字数为： 15480 字
# 《有什么特别甜特别宠的甜宠文？ - 知乎》的字数为： 4287 字
# 《你看过最恐怖的鬼故事是什么？ - 知乎》的字数为： 10422 字
# 《43. 公主归塞》的字数为： 15675 字
# 《42. 爱之砒霜》的字数为： 12387 字
# 《有些生可以恶心到什么程度？ - 知乎》的字数为： 11751 字
# 《41. 不被收买的皇后》的字数为： 14047 字
# 《有没有女主先心动，男主一开始对女主冷淡，后来追妻火葬场的小说？ - 知乎(1)》的字数为： 15502 字
# 《高考志愿填报，对于许多专业一无所知，该怎么办_ - 知乎》的字数为： 13452 字
# 《40. 吉祥止止》的字数为： 15443 字
# 《39. 夫君替我打脸绿茶》的字数为： 11083 字
# 《你见过最高级的绿茶婊是什么样的？ - 知乎》的字数为： 8639 字
# 《38. 可恶，朕又被将军气晕了》的字数为： 15571 字
# 《男生真的可以一直爱一个女生吗？ - 知乎》的字数为： 10868 字
# 《室友哪些不该看的东西被你无意之间看到了？ - 知乎》的字数为： 14740 字
# 《37. 嘴臭达人被迫绑定恋爱脑系统后》的字数为： 12374 字
# 《36. 贻我一枝春》的字数为： 15653 字
# 《有什么甜甜的小说推荐？ - 知乎-75ff2b8cdd9a》的字数为： 15565 字
# 《35. 女皇不高兴》的字数为： 10525 字
# 《你们谈恋爱累吗？ - 知乎》的字数为： 10932 字
# 《是什么样的鬼故事吓了你十几年？ - 知乎(1)》的字数为： 9010 字
# 《34. 新时代新天庭》的字数为： 12906 字
# 《33. 首富夫人的自我修养》的字数为： 12843 字
# 《有没有女主表面茶里茶气，背地里是个沙雕还有点腹黑的小说？ - 知乎(1)》的字数为： 14835 字
# 《32. 蓝鸢花开》的字数为： 15723 字
# 《有很甜的恋爱故事吗？ - 红尘 的回答 - 知乎》的字数为： 15441 字
# 《有什么甜甜的小说推荐？ - 知乎 (1)》的字数为： 15604 字
# 《31. 狐狸精要刺杀师尊》的字数为： 11664 字
# 《30. 她就当恶毒女配》的字数为： 10992 字
# 《如何看待普通家庭的女孩嫁入豪门 日子会好过吗_ - 知乎》的字数为： 5978 字
# 《29. 锦上云书》的字数为： 15713 字
# 《有那种很虐很虐，虐的你心肝疼的文吗？ - 知乎(1)》的字数为： 15698 字
# 《什么时候家人让你觉得心凉？ - 知乎》的字数为： 10939 字
# 《28. 救了个傻书生后我翻车了》的字数为： 14411 字
# 《27. 连云之雨》的字数为： 11504 字
# 《有没有主是变态，病娇，黑化，囚禁之类的He_ - 知乎》的字数为： 15763 字
# 《26. 义兄以美色误我》的字数为： 10688 字
# 《你见过的最阴暗的事是什么？ - 知乎》的字数为： 10669 字
# 《有哪些甜文值得推荐？ - 知乎(1)》的字数为： 12066 字
# 《25. 将军女儿不好惹》的字数为： 14537 字
# 《24. 我的猪猪闺蜜》的字数为： 11772 字
# 《23. 逐红莲》的字数为： 15526 字
# 《如果你穿越到校园甜文反面女二该怎么做？ - 知乎(1)》的字数为： 15519 字
# 《怀孕时让你最崩溃的瞬间是什么_ - 知乎》的字数为： 11132 字
# 《22. 迢迢我心》的字数为： 15384 字
# 《21. 虐文女主反虐男主》的字数为： 10703 字
# 《生活中有没有特别绿茶的女生？ - 知乎》的字数为： 15554 字
# 《20. 云下有川》的字数为： 15707 字
# 《为什么在一起很久的人会莫名其妙狠心分手_ - 知乎》的字数为： 10926 字
# 《当霸道总裁文里出现沙雕主会是怎么样的情节？ - 知乎》的字数为： 15710 字
# 《19. 媚骨引》的字数为： 15696 字
# 《18. 故人归》的字数为： 15593 字
# 《大部分直男喜欢怎样的女生？ - 知乎》的字数为： 10182 字
# 《17. 三生债》的字数为： 15592 字
# 《如果诸葛亮北伐成功进而一统三国，刘禅的评价会变成什么样？ - 知乎》的字数为： 10107 字
# 《你有没有在一瞬间突然认清了一个人》的字数为： 9714 字
# 《16. 人人都爱我母亲》的字数为： 15557 字
# 《15. 惟愿昭昭》的字数为： 13594 字
# 《如何以“我不想进宫”为开头写一篇文？ - 知乎》的字数为： 15572 字
# 《14. 温柔有罪》的字数为： 12577 字
# 《有没有主是老流氓的小说 类似《春日宴》的主？ - 知乎》的字数为： 15743 字
# 《和没教养的人一起吃饭能恶心到什么程度？ - 知乎》的字数为： 8626 字
# 《13. 梦中的穿越女》的字数为： 12130 字
# 《12. 不要相信那个现代人》的字数为： 12080 字
# 《有没有很甜但又不落俗套的言情小说？ - 知乎》的字数为： 13079 字
# 《11. 我欲与君相知》的字数为： 15630 字
# 《暗恋一个人最苦涩的感觉是什么？ - 知乎(1)》的字数为： 12297 字
# 《如果你穿成修仙文里的第一美人女配你会怎么样_ - 知乎》的字数为： 15606 字
# 《10. 萤月争辉》的字数为： 15666 字
# 《9. 怎么全是变态啊》的字数为： 15510 字
# 《8. 当恶毒贵妃摆烂之后》的字数为： 11357 字
# 《有很甜的恋爱故事吗？ - 知乎》的字数为： 15448 字
# 《你有经历过哪些社死现场_ - 知乎(1)》的字数为： 10006 字
# 《7. 皇后成长计划》的字数为： 8989 字
# 《6. 西风吹上两眉间》的字数为： 15608 字
# 《5. 佛赐姻缘》的字数为： 15727 字
# 《有高质量的虐男文吗？ - 知乎(1)》的字数为： 10578 字
# 《有文风轻松欢脱的沙雕文吗？》的字数为： 13422 字
# 《4. 疯批男主他要命》的字数为： 13931 字
# 《3. 御正》的字数为： 15480 字
# 《生真的觉得跟谁结婚都一样吗？为什么？ - 知乎》的字数为： 7371 字
# 《2. 两世霜》的字数为： 15667 字
# 《你听过最恐怖的故事是什么？ - 知乎(1)》的字数为： 12447 字
# 《有没有连续熬夜看完的古言？有没有向朋友疯狂安利的古言？ - 知乎(1)》的字数为： 11934 字
# 《1. 太子妃她身怀绝技》的字数为： 12843 字
# 《生或生可以不自爱到什么程度？ - 脸叔 的回答 - 知乎》的字数为： 10509 字
# 《5. 我想和你谈恋爱》的字数为： 15293 字
# 《如何以“上神剔我仙骨时，血溅了他一身”为开头写一个故事？ - 知乎》的字数为： 15544 字
# 《是什么让你开始放下手机去读书？ - 知乎》的字数为： 4291 字
# 《4. 合约婚姻》的字数为： 15250 字
# 《3. 小偷》的字数为： 15314 字
# 《番外·合欢 - 知乎》的字数为： 9789 字
# 《17. 被戳穿的谎言》的字数为： 7420 字
# 《如何以“娘娘，城破了”为开头写一个故事？ - 知乎》的字数为： 11219 字
# 《16. 匈奴王的阴谋》的字数为： 7312 字
# 《有没有背后一凉的鬼故事，快吓死我_ - 知乎(1)》的字数为： 10446 字
# 《为什么在一起很久的人会莫名其妙狠心分手_ - 知乎 (1)-73287223f8b0》的字数为： 10926 字
# 《15. 郡主小妹流浪记》的字数为： 9394 字
# 《14. 陆机的乐谱》的字数为： 7209 字
# 《如何写一篇“男主把女主当替身，然后发现自己也是替身”的文？ - 知乎》的字数为： 15544 字
# 《13. 傲娇傲到最后应有尽有》的字数为： 8664 字
# 《知乎上有哪些让你印象深刻的原创小说？ - 知乎》的字数为： 15512 字
# 《摧毁一个家长有多简单 ？ - 知乎(1)》的字数为： 10849 字
# 《12. 黑色情人节》的字数为： 7670 字
# 《11. 终于找到一份稳定的工作》的字数为： 8417 字
# 《如果你是替身文的替身，你会怎么做？ - 知乎》的字数为： 15706 字
# 《10. 宫中肚兜失窃案》的字数为： 7406 字
# 《有哪些让人熬夜也要看完的言情小说_ - 知乎》的字数为： 15598 字
# 《有哪些瞬间让你细思恐极？ - 小巫先生 的回答 - 知乎》的字数为： 15637 字
# 《9. 不好！皇上造反了！》的字数为： 7624 字
# 《8. 记一次失败的面试》的字数为： 9132 字
# 《有什么甜甜的小说推荐？ - 知乎(2)》的字数为： 15681 字
# 《7. 形象设计》的字数为： 8762 字
# 《有什么文笔好HE的言情小说吗？ - 知乎》的字数为： 15628 字
# 《如何以“娘娘，其实奴才不是真正的太监”为开头，写一个故事？ - 知乎》的字数为： 15535 字
# 《6. 叛逆鼓手》的字数为： 8096 字
# 《5. 一次成功的市场调研》的字数为： 7949 字
# 《有哪些有趣的“最弱异能”？ - 知乎(1)》的字数为： 6600 字
# 《4. 新的鼓手：黄泉警察》的字数为： 9174 字
# 《跟有钱人做朋友是种怎样的体验？ - 知乎》的字数为： 15393 字
# 《怎样提高说话时的瞬时反应能力？ - 知乎(2)(1)》的字数为： 3758 字
# 《3. 另类宫斗婆媳剧》的字数为： 6385 字
# 《2. 新的马头琴手：呼公公！》的字数为： 7500 字
# 《姐弟恋中的姐姐什么感觉？ - 知乎》的字数为： 10736 字
# 《1. 新的主唱：婵妃娘娘！》的字数为： 6345 字
# 《有没有主智商在线剧情又不拖拉的古言小说推荐？ - 知乎》的字数为： 12542 字
# 《能不能以一个特别会宫斗的皇上为视角写一篇宫斗文？ - 知乎》的字数为： 15488 字
# 《18. 如何高效备考事业单位？》的字数为： 8555 字
# 《如何以“我暗恋的男生是个病娇”为开头写一个故事？ - 知乎》的字数为： 15647 字
# 《17. .用机关思维，从领导角度，突破面试拿高分》的字数为： 6800 字
# 《大家有什么 n 的小说推荐？ - 知乎》的字数为： 15105 字
# 《能不能给我讲一段很甜很甜的爱情故事_ - 知乎》的字数为： 15649 字
# 《16. . 考官有话说：面试时，这些套话不要讲》的字数为： 5920 字
# 《15. .公务员面试，答题内容重要还是形式重要？》的字数为： 4543 字
# 《五大常任理事国都有过什么作？ - 知乎》的字数为： 5613 字
# 《14. . 不善言辞，如何通过公务员面试？》的字数为： 4999 字
# 《找工作几个月了，没技术，没能力，没有什么兴趣爱好，不知道做什么，该怎么确定目标？ - 知乎(1)》的字数为： 3439 字
# 《如何以“我是琴棋书画样样不行的公主”为开头写一个故事？ - 知乎(1)》的字数为： 15478 字
# 《13. . 申论大作文写作模板》的字数为： 11977 字
# 《12. .从 0. 到 1. ，申论 75. 分备考指南》的字数为： 15294 字
# 《如何在公务员面试中逆袭？ - 知乎》的字数为： 11915 字
# 《有哪些令人浑身发抖的故事？ - 知乎(11)》的字数为： 9976 字
# 《中国有哪些恐怖或鲜为人知的杀人案件？ - 知乎》的字数为： 9351 字
# 《7. .一个月如何冲刺上岸？》的字数为： 9943 字
# 《6. . 没有行测思维，刷题再多也难拿高分》的字数为： 4283 字
# 《如何培养说话的逻辑性？ - 知乎》的字数为： 5797 字
# 《11. .申论四大必考题型详解及高分技巧》的字数为： 15317 字
# 《有没有本以为是搞笑段子，结果是细思恐极的恐怖故事？ - 知乎》的字数为： 7730 字
# 《有没有主是妖艳贱货，主清心寡欲一本正经的小说推荐？ - 知乎》的字数为： 15746 字
# 《10. .申论考官的出题思路是什么？》的字数为： 7501 字
# 《9. .“资料分析”如何提高做题速度？》的字数为： 10350 字
# 《照骗能骗到什么程度？ - 知乎》的字数为： 12442 字
# 《8. .“选词填空”如何提高正确率？》的字数为： 15400 字
# 《5. . 如何主动预测公考的出题方式？》的字数为： 9657 字
# 《青梅竹马没有在一起是什么感觉？ - 知乎》的字数为： 9063 字
# 《你曾经做过最羞耻的事是什么？ - 故事档案局 的回答 - 知乎》的字数为： 15759 字
# 《4. . 在职备考，你需要多努力？》的字数为： 11816 字
# 《3. .公安机关公务员选岗、备考、政审、体检全过程知乎盐选 公安机关公务员选岗、备考、政审、体检全过程》的字数为： 10198 字
# 《有没有能甜到打滚的小说？ - 知乎(1)》的字数为： 8761 字
# 《32. 白月光是只猫(1. )》的字数为： 10676 字
# 《你在高中时听说过……》的字数为： 12363 字
# 《你是怎么和前任告的别？ - 知乎-e71d14fc9c94》的字数为： 7338 字
# 《31. 捡到一只小兔子(1. )》的字数为： 10703 字
# 《50. 狐寻予予》的字数为： 12290 字
# 《吃软饭是怎样的一种体验？ - 知乎(2)》的字数为： 8495 字
# 《2. .军队文职和公务员该怎么选择？》的字数为： 4204 字
# 《你有哪些最装逼而且成功的神操作？ - 知乎》的字数为： 11903 字
# 《如何与女生愉快地聊天？ - 知乎》的字数为： 3060 字
# 《1. .报考公务员时，如何选择岗位才能提高上岸率？》的字数为： 10100 字
# 《有没有小说主是妖艳贱货的好康小说！血书跪求漂亮推荐？ - 知乎》的字数为： 13467 字
# 《49. 我的朋友圈有超能力》的字数为： 11131 字
# 《有哪些让你二刷的言情小说？ - 知乎(2)》的字数为： 15496 字
# 《如何以“算了，我来嫁。”为开头写一个故事？ - 知乎(2)》的字数为： 15488 字
# 《48. 溪上晨光》的字数为： 14268 字
# 《47. 我和老公互换身体》的字数为： 15626 字
# 《如何以“我穿成了反派的情人，并且得罪了女主”为开头写一个故事？ - 知乎》的字数为： 15493 字
# 《有哪些半小时以内可以看完的短篇小甜文_ - 知乎》的字数为： 12013 字
# 《46. 海后的自我修养》的字数为： 10793 字
# 《45. 豪门姐弟之再归来》的字数为： 10970 字
# 《44. 宠物奇缘》的字数为： 13026 字
# 《43. 遇龙时相恋》的字数为： 15658 字
# 《42. 狐老板》的字数为： 15862 字
# 《41. 当心机婊遇上宠妻狂魔》的字数为： 11498 字
# 《40. 恶女王后和七个骑士》的字数为： 12193 字
# 《39. 攻略失败后修罗场了》的字数为： 10525 字
# 《38. 凶宅少女书法家》的字数为： 10062 字
# 《37. 邪神与少女》的字数为： 15573 字
# 《36. 女壮士的王子拯救计划》的字数为： 15549 字
# 《35. 我靠养崽攻略了病娇老板》的字数为： 12879 字
# 《34. 月光回温》的字数为： 15506 字
# 《33. 我的月亮》的字数为： 13414 字
# 《32. 白月光是只猫》的字数为： 10677 字
# 《31. 捡到一只小兔子》的字数为： 10704 字
# 《30. 血族新娘》的字数为： 14786 字
# 《29. 捡到八尾猫后》的字数为： 15689 字
# 《28. 乙女游戏的完美攻略》的字数为： 15463 字
# 《和女朋友同居是种怎样的体验？》的字数为： 11983 字
# 《27. 海边捡鲛人》的字数为： 11398 字
# 《26. 恶女她风情万种》的字数为： 15716 字
# 《有哪些半小时内就能看完的超甜小故事？》的字数为： 15818 字
# 《25. 攻略乙游男主》的字数为： 15554 字
# 《如果一个人长生不死，那么在现代社会他要怎样做才能避免被人发现？》的字数为： 10748 字
# 《24. 真千金能看见鬼》的字数为： 14669 字
# 《《时空缉凶》》的字数为： 15554 字
# 《23. 轮回之后说再见》的字数为： 12863 字
# 《您遭遇过最耻辱的事是什么？》的字数为： 11159 字
# 《22. 竹马哪有天降香》的字数为： 14837 字
# 《有哪个瞬间曾让你难以抑制的想哭？》的字数为： 15798 字
# 《如何培养在政府机关的公文写作能力？》的字数为： 6200 字
# 《21. 夫人的读心术》的字数为： 11753 字
# 《20. 撩人不自知》的字数为： 15681 字
# 《大便颜色跟身体健康状况有什么联系？》的字数为： 10360 字
# 《19. 我是一只鬼》的字数为： 13369 字
# 《现实中的姐弟恋真的很累吗？》的字数为： 14342 字
# 《网恋对象一个月了，挺喜欢他的。昨天他突然发自拍给我，觉得他长的丑怎么办？》的字数为： 15482 字
# 《18. 长岁暖知砚》的字数为： 15793 字
# 《17. 恶毒女配化身CP头子》的字数为： 13827 字
# 《你被吓得最惨的一次是什么情况？》的字数为： 12043 字
# 《16. 我穿成了恶毒婆婆》的字数为： 12606 字
# 《你遇到过最惊悚的事情是什么？ – 一介书生》的字数为： 13730 字
# 《你从哪一刻开始决定不再善良的？》的字数为： 13733 字
# 《15. 那年阳光正好》的字数为： 10840 字
# 《14. 与阿飘度过人生最后一年》的字数为： 12943 字
# 《太子与太子妃十分恩爱，但我是太子的侧妃》的字数为： 15716 字
# 《13. 我的Omega男娇妻》的字数为： 15630 字
# 《有没有让你毛骨悚然的真实案件？》的字数为： 7743 字
# 《你在不经意间听见或看见过什么不该听见或看见的声音或者事情？》的字数为： 15293 字
# 《12. 玄猫之恋》的字数为： 11530 字
# 《11. 不乖》的字数为： 11834 字
# 《《偏爱成瘾：她在世间谋生又谋爱》》的字数为： 15705 字
# 《10. 岁岁对弈》的字数为： 15084 字
# 《历史上北齐为什么被称为禽兽王朝？》的字数为： 15294 字
# 《喜欢上做夜场的女孩子，我该怎么办？》的字数为： 10801 字
# 《9. 在时间中拯救你我》的字数为： 14326 字
# 《8. 栀明》的字数为： 11377 字
# 《有钱人喜欢什么样的女生？》的字数为： 11950 字
# 《7. 虎鲸男友白切黑》的字数为： 13700 字
# 《有哪些剧情反转的有趣故事？》的字数为： 9889 字
# 《如果五虎上将跟随曹操，五子良将跟随刘备，结局会怎么样？》的字数为： 8182 字
# 《6. 攻略六张恋人牌》的字数为： 15451 字
# 《5. 颜知我心》的字数为： 15849 字
# 《如果穿越成为虐文的女配该怎么办？》的字数为： 15373 字
# 《1. 奶茶、蛋糕、标枪手：我的未来老公》的字数为： 15734 字
# 《4. 玄学少女会看命》的字数为： 14409 字
# 《高段位的心机婊是什么样子？》的字数为： 14917 字
# 《有没有什么让人回味无穷的鬼故事？》的字数为： 9185 字
# 《3. 我在童话世界修仙》的字数为： 10760 字
# 《2. 心底的花》的字数为： 8798 字
# 《什么是假甜女孩？》的字数为： 11350 字
# 《1. 赠我玫瑰与吻》的字数为： 12252 字
# 《有没有特别甜的故事？》的字数为： 11192 字
# 《想知道渣男到底都在想什么？》的字数为： 6744 字
# 《6. 悬丝木偶》的字数为： 15966 字
# 《作为医生看见面前一个暂时活蹦乱跳的喝了百草枯的病人是怎样一种感觉？》的字数为： 4690 字
# 《5. 全世界都在磕我和影帝的cp》的字数为： 15362 字
# 《为什么《傲慢与偏见》是经典？》的字数为： 7992 字
# 《你们听到过最恐怖的故事有哪些？》的字数为： 12446 字
# 《4. 乱了分寸的心动》的字数为： 15742 字
# 《3. 金牌讲师：夏日重现》的字数为： 15587 字
# 《如何以“我封妃那天，他在宫外跪了一夜”为开头写一篇古言小说？》的字数为： 14487 字
# 《2. 案发前后》的字数为： 15763 字
# 《为什么好端端的一个人会突然得了精神病？》的字数为： 4697 字
# 《有没有超级恐怖的鬼故事？》的字数为： 8902 字
# 《如何克服孤独感，习惯一个人的生活？》的字数为： 3378 字
# 《资本家已经拥有大量资产了，为什么还要剥削无产阶级？》的字数为： 103 字
# 《是哪个瞬间或哪件事让你深信人性本恶？》的字数为： 6334 字
# 《8. 单项选择题、多项选择题、几何大题题型解析，攻克高考！》的字数为： 5247 字
# 《7. 如何攻克压轴题？》的字数为： 5125 字
# 《6. 高三阶段如何通过刷题快速提分？》的字数为： 6580 字
# 《你有没有被原生家庭伤得遍体鳞伤过？》的字数为： 13190 字
# 《为什么中二病患者都喜欢设定自己在“恶”阵营？》的字数为： 6106 字
# 《5. 如何通过错题分析与错题集构建知识体系？》的字数为： 3660 字
# 《3. 踩分点：数学试卷的步骤分与卷面分》的字数为： 6288 字
# 《你遇到过哪些心理变态的人？》的字数为： 10309 字
# 《2. 流程：高考是怎样阅卷的？》的字数为： 5468 字
# 《人的心机可以可怕到什么程度？》的字数为： 11361 字
# 《和大叔谈恋爱是种怎样的体验？》的字数为： 15660 字
# 《35. 粽子》的字数为： 9220 字
# 《有没有什么甜文推荐，甜死我的那种？》的字数为： 14107 字
# 《34. 死痘》的字数为： 15403 字
# 《来讲一个你作死的小故事？》的字数为： 15510 字
# 《长的漂亮真的很有优势吗？》的字数为： 12523 字
# 《33. 骗》的字数为： 6519 字
# 《32. 优等生》的字数为： 8165 字
# 《26. 墙里的骸骨》的字数为： 15607 字
# 《房子隔音太差是什么体验？》的字数为： 15675 字
# 《31. 剪接》的字数为： 9101 字
# 《你有哪些特别恶心的亲戚？》的字数为： 11934 字
# 《有没有给人“无法理解的恐怖”的惊悚故事 ？》的字数为： 9664 字
# 《30. 门》的字数为： 8645 字
# 《29. 死人花圈》的字数为： 14910 字
# 《有一群很恶心的亲戚是一种什么样的体验？》的字数为： 15318 字
# 《24. 拾骨记》的字数为： 8792 字
# 《有没有什么绿茶语录，但是表面看不出绿茶的？》的字数为： 11119 字
# 《28. 换生》的字数为： 14822 字
# 《霸道总裁会自己洗内裤吗？》的字数为： 15501 字
# 《学生提前用完生活费是种怎样的体验？》的字数为： 15578 字
# 《27. 逃脱恶魔的监禁》的字数为： 10537 字
# 《26. 墙里的骸骨》的字数为： 15607 字
# 《22. 坠河疑案：一石三鸟的完美复仇》的字数为： 15366 字
# 《21. 隐身小姐》的字数为： 13020 字
# 《有没有好看的“虐妻一时爽，追妻火葬场”的小说？》的字数为： 15578 字
# 《25. 你能看见吗》的字数为： 10593 字
# 《凌晨三点，官方警报消息吵醒了你,消息内容是“不要抬头看月亮”》的字数为： 15577 字
# 《有一群很恶心的亲戚是一种什么样的体验？》的字数为： 15318 字
# 《24. 拾骨记》的字数为： 8792 字
# 《23. 漂流的草蒲团》的字数为： 9219 字
# 《你看什么样的虐文会被虐哭？》的字数为： 11823 字
# 《22. 坠河疑案：一石三鸟的完美复仇》的字数为： 15366 字
# 《21. 隐身小姐》的字数为： 13020 字
# 《脑洞：如果丧尸爆发了，你应该怎样生活？》的字数为： 12225 字
# 《20. 消失的赘婿》的字数为： 15428 字
# 《我封妃那天，他在宫外跪了一夜》的字数为： 15474 字
# 《和异性合租是种怎样的体验？》的字数为： 13916 字
# 《19. 细思极恐：阴魂阳谋》的字数为： 15503 字
# 《18. 愚人》的字数为： 7988 字
# 《男生真喜欢一个女生会有什么样的表现？》的字数为： 15678 字
# 《17. 骷髅窝》的字数为： 10867 字
# 《历史上对曹操评价高吗？为什么？》的字数为： 11674 字
# 《熬夜猝死前有什么征兆？》的字数为： 6376 字
# 《16. 追凶：少女的斗兽场》的字数为： 13299 字
# 《15. 并蒂莲花》的字数为： 15717 字
# 《有一个不爱自己的男朋友是怎样的体验？》的字数为： 15617 字
# 《14. 血色天使》的字数为： 9348 字
# 《有没有一些关于克格勃的趣事？》的字数为： 7769 字
# 《皇上把一张银行卡甩到我桌子上》的字数为： 13365 字
# 《13. 血色嫁衣》的字数为： 13389 字
# 《12. 我不是扶弟魔》的字数为： 11411 字
# 《以“我的男宠是可以随时干掉我的大佬”为开头，能写出什么样的故事？》的字数为： 15464 字
# 《11. 前男友死在婚宴上，我成了嫌疑犯？》的字数为： 10927 字
# 《你们闻过最臭的是什么？》的字数为： 8261 字
# 《10. 请替》的字数为： 15539 字
# 《《请回到2008》》的字数为： 15769 字
# 《9. 细思极恐：贩卖的爱情》的字数为： 15580 字
# 《如果用你的专业来写爽文，会是什么剧情？》的字数为： 15550 字
# 《8. 圈套》的字数为： 10733 字
# 《最努力憋笑的一次经历是什么？》的字数为： 9974 字
# 《有没有女主穿越到古代专心搞事业，认真学习知识进步，少一点宅斗，宫斗之类的，而且三观极正的小说？》的字数为： 12579 字
# 《7. 爱恨情仇一江水》的字数为： 6911 字
# 《6. 别让我学你》的字数为： 9566 字
# 《你和暧昧对象做过哪些刺激的事？》的字数为： 13551 字
# 《5. 乞丐公子》的字数为： 9834 字
# 《有一个体育生男票是什么样的体验？》的字数为： 9099 字
# 《4. 秘密》的字数为： 7701 字
# 《3. 弃子》的字数为： 9835 字
# 《高考作弊或者作弊被抓是种怎样的体验？》的字数为： 13313 字
# 《2. 生死之间（下）》的字数为： 9894 字
# 《你见过大学女生宿舍里哪些可怕的事情？》的字数为： 15385 字
# 《有什么甜甜的言情小说推荐啊？》的字数为： 15432 字
# 《1. 生死之间（上）》的字数为： 8492 字
# 《如何解读《海边的卡夫卡》这部小说？》的字数为： 7887 字
# 《大学宿舍可以有多恶心？》的字数为： 10068 字
# 《你写过或听过哪些关于人性的故事？》的字数为： 12018 字
# 《6. 遥遥清》的字数为： 15573 字
# 《5. 霸道魔君和他的娇娇龙狐》的字数为： 15558 字
# 《倘若把镇关西换成张飞，鲁智深能三拳打死他吗？》的字数为： 8201 字
# 《4. 何枝可依》的字数为： 15554 字
# 《中国神话中有什么细思恐极的细节或者阴谋论吗？》的字数为： 12400 字
# 《你们都知道哪些鬼故事，可以讲一下吗？》的字数为： 12717 字
# 《3. 迟迟春》的字数为： 15521 字
# 《2. 长梨别》的字数为： 14366 字
# 《如果有超能力，会不会被政府关押研究？》的字数为： 9846 字
# 《1. 皎皎明月》的字数为： 15554 字
# 《是什么时候让你突然放弃爱一个人？》的字数为： 15674 字
# 《世界上致死率最高的东西是什么？》的字数为： 4675 字
# 《8. 番外：秋意浓》的字数为： 10754 字
# 《有哪些不用细思也恐极的故事？》的字数为： 8770 字
# 《7. 番外：雁南归》的字数为： 5785 字
# 《有哪些全世界只有几例的罕见病 ？》的字数为： 9756 字
# 《为什么中国人对于北洋民国历史如此陌生？》的字数为： 9091 字
# 《6. 以己为棋》的字数为： 15499 字
# 《5. 后庭诡谲》的字数为： 12446 字
# 《大学舍友哪些行为让你恶心至极？》的字数为： 15287 字
# 《4. 波澜渐起》的字数为： 12145 字
# 《有没有真正的道术或者巫术？》的字数为： 14467 字
# 《女生谈恋爱现实点好不好？》的字数为： 11094 字
# 《3. 帝京风云》的字数为： 11166 字
# 《2. 云胡不喜》的字数为： 11396 字
# 《男女之间有纯友谊吗？》的字数为： 11029 字
# 《1. 少时相识》的字数为： 9480 字
# 《女大学生寝室的关系可以可怕到什么程度？》的字数为： 10725 字
# 《有没有哪些非常恐怖的鬼故事？》的字数为： 7863 字
# 《18. 番外》的字数为： 5393 字
# 《15. 奖学金风波》的字数为： 12467 字
# 《16. 小白杨树，新年快乐》的字数为： 9344 字
# 《健身房的男女关系很乱吗？》的字数为： 13227 字
# 《你看过最爽的爽文有多爽 ？》的字数为： 11859 字
# 《有什么让人听了背脊发凉的恐怖故事 ？》的字数为： 3331 字
# 《17. 他一直都在》的字数为： 13463 字
# 《你听过最恐怖的故事是什么？》的字数为： 12487 字
# 《如果我国爆发丧尸病毒，会很快沦陷吗？》的字数为： 15582 字
# 《12. 不一样的生日》的字数为： 8099 字
# 《13. 这并不是喜欢》的字数为： 7763 字
# 《“以绝大数人努力程度之低，根本没有要到拼天赋的地步”这句话可信吗？》的字数为： 5466 字
# 《14. 希望她开心多过于希望能和她在一起》的字数为： 9380 字
# 《各位医生是喜欢有医学知识储备的病人，还是喜欢没有医学知识储备的病人？》的字数为： 8516 字
# 《10. 小白杨树要岁岁平安》的字数为： 8649 字
# 《有哪些诡异邪性的民间故事？》的字数为： 10890 字
# 《如果我国爆发丧尸病毒，会很快沦陷吗？》的字数为： 15582 字
# 《6. 这世上会有一束光，是为她而来的吗》的字数为： 9005 字
# 《7. 陈思计》的字数为： 9720 字
# 《各位警察大锅们，审讯犯人有什么技巧吗？》的字数为： 11718 字
# 《有没有虐得你久久不能恢复的短篇小说？》的字数为： 15616 字
# 《8. 太阳能照亮我的人生》的字数为： 9949 字
# 《有没有一刻觉得女朋友很恶心？》的字数为： 13939 字
# 《9. 会吓到她的》的字数为： 9682 字
# 《有什么很有意思的考古事件？》的字数为： 10744 字
# 《11. 原生家庭》的字数为： 9538 字
# 《如果我国爆发丧尸病毒，会很快沦陷吗？》的字数为： 15582 字
# 《3. 好运从来都不属于她》的字数为： 8243 字
# 《4. 谁愿意跟一个无趣寡淡的人做朋友呢》的字数为： 8152 字
# 《有一个女儿是种怎样的体验？》的字数为： 13123 字
# 《异性间有没有纯友谊？》的字数为： 12946 字
# 《5. 告别高中》的字数为： 9905 字
# 《有什么小说男主角是和尚的吗？》的字数为： 15660 字
# 《1. 女主光环》的字数为： 15413 字
# 《台儿庄战役为什么能赢？》的字数为： 8665 字
# 《怎么以“除了我，我身边的人都重生了”为开头写个故事？》的字数为： 15500 字
# 《2. 保送快乐，祝得偿所愿》的字数为： 8414 字
# 《有一个妹妹是种怎样的体验？》的字数为： 13741 字
# 《7. 长公主在上》的字数为： 15586 字
# 《8. 暗夜流光》的字数为： 13109 字
# 《《故事会》中让你印象最深的故事是什么？》的字数为： 15585 字
# 《有哪些影响力被极大高估的历史事件？》的字数为： 11272 字
# 《9. 不渝》的字数为： 13170 字
# 《有哪些女主人设很讨喜不作妖不弱智的小说推荐？》的字数为： 15610 字
# 《4. 祝君安》的字数为： 13104 字
# 《5. 春意满山》的字数为： 14362 字
# 《你听说过哪些恶有恶报的事 ？》的字数为： 13092 字
# 《摧毁一个孩子有多简单？》的字数为： 9955 字
# 《6. 大梦一场终成空》的字数为： 15628 字
# 《你听过最吓人的故事是什么？》的字数为： 8926 字
# 《1. 莲花珍珠》的字数为： 13854 字
# 《2. 勿停云》的字数为： 15619 字
# 《择偶时为什么要考虑身高？》的字数为： 10819 字
# 《我穿越成了恶毒女配》的字数为： 15512 字
# 《3. 平安不长安》的字数为： 15545 字
# 《有没有那种男主暗恋女主很久，一步步引诱女主爱上自己的小说？》的字数为： 15522 字
# 《历朝历代灭亡后宗室下场最惨的是哪个？》的字数为： 15151 字
# 《中国有哪些习惯是苏联影响的遗留？》的字数为： 10349 字
# 《15. 真相》的字数为： 15722 字
# 《16. 难缠》的字数为： 15709 字
# 《如果一个人染上了艾滋病，那么他还能活多久？》的字数为： 7676 字
# 《17. 替身》的字数为： 15729 字
# 《身边有个绿茶婊是种怎样的体验？》的字数为： 12218 字
# 《18. 幽冥》的字数为： 15703 字
# 《19. 找尸》的字数为： 15729 字
# 《有什么好看的仙侠小说吗？ –》的字数为： 15673 字
# 《20. 因果》的字数为： 15733 字
# 《21. 调查》的字数为： 15689 字
# 《22. 大结局 斗法》的字数为： 15705 字
# 《《肩上暖阳：她们曾与命运硬刚》》的字数为： 15612 字
# 《你的大学里有哪些荒唐的事？》的字数为： 15520 字
# 《14. 诡异》的字数为： 15725 字
# 《姐姐的腰，真软》的字数为： 15661 字
# 《8. 画皮》的字数为： 15704 字
# 《你一直暗恋的人突然反过来向你表白是一种什么样子的体验？》的字数为： 15667 字
# 《9. 诈尸》的字数为： 15773 字
# 《10. 水鬼》的字数为： 15741 字
# 《你身边有没有令人瞠目结舌的巧合？》的字数为： 13924 字
# 《去男科遇到女医生是一种什么体验？》的字数为： 10270 字
# 《11. 迎亲》的字数为： 15739 字
# 《为什么会经常觉得人活着没有意思？》的字数为： 4117 字
# 《12. 人性》的字数为： 15728 字
# 《13. 老店》的字数为： 15735 字
# 《你在无意间知道了哪些令人目瞪口呆的事情秘密？》的字数为： 13577 字
# 《1. 入局》的字数为： 15585 字
# 《那些人称“扶弟魔”的女人，后来怎么样了？》的字数为： 13677 字
# 《2. 求救》的字数为： 15496 字
# 《3. 鬼门关》的字数为： 15494 字
# 《4. 杀生》的字数为： 15693 字
# 《有没有那种女主是妖艳贱货又沙雕的小说推荐？》的字数为： 15670 字
# 《5. 食人鱼》的字数为： 15759 字
# 《你玩过最让你吓尿的恐怖游戏是什么？》的字数为： 15440 字
# 《6. 兵佣》的字数为： 15785 字
# 《7. 封印》的字数为： 15773 字
# 《可以推荐下现言甜文吗？》的字数为： 15713 字
# 《有没有什么可爱的睡前故事？》的字数为： 10808 字
# 《9. 绿茶和狐狸精（2. ）》的字数为： 8942 字
# 《始终怀不上孕是种怎样的体验？》的字数为： 13569 字
# 《5. 空姐海王的捕获》的字数为： 15439 字
# 《6. 分寸》的字数为： 9523 字
# 《你写过哪些风格黑暗的故事？》的字数为： 15585 字
# 《你认识的富二代有多渣？》的字数为： 15489 字
# 《7. 前男友》的字数为： 9034 字
# 《舆论让人贴近真相还是更远离真相呢？》的字数为： 12106 字
# 《8. 绿茶和狐狸精》的字数为： 8916 字
# 《10. 前女友是白月光》的字数为： 8983 字
# 《喜欢上了一个大叔怎么办？》的字数为： 10979 字
# 《你有过一不小心和异性亲密接触的尴尬经历吗？》的字数为： 15737 字
# 《4. 绿茶遇上海王》的字数为： 12254 字
# 《你遇到最毁三观的事是什么？》的字数为： 12029 字
# 《8. 没有不可治愈的伤痛》的字数为： 15771 字
# 《如果科学家发明了时间静止冰冻技术会怎么样？》的字数为： 7110 字
# 《人性背后的秘密》的字数为： 8654 字
# 《1. 实习生妹妹》的字数为： 9042 字
# 《如果你是天下第一铸剑坊的老板，却只想搞钱会发生什么剧情？》的字数为： 13407 字
# 《2. 我们只是朋友》的字数为： 8268 字
# 《有没有什么细思极恐的恐怖故事 ？》的字数为： 13688 字
# 《3. 金丝雀的人间游戏》的字数为： 10651 字
# 《那日我的夫君带回一位姑娘》的字数为： 15578 字
# 《1. 老公的白月光回国了》的字数为： 10832 字
# 《3. 必须要离婚》的字数为： 13882 字
# 《2. 精心准备的蛋糕》的字数为： 11546 字
# 《4. 扎眼的红玫瑰》的字数为： 11168 字
# 《社会狠狠的教会过你什么？》的字数为： 14751 字
# 《5. 接踵而来的诡异谜团》的字数为： 12325 字
# 《6. 前有狼后有虎》的字数为： 14751 字
# 《宇宙中的高等文明会不会一直在用人类尚无法察觉的手段观察着人类？》的字数为： 15414 字
# 《我他妈不是舔狗》的字数为： 15459 字
# 《7. 白月光她怀孕了》的字数为： 14851 字
# 《男生真的很不能接受彩礼吗？》的字数为： 8045 字
# 《有没有甜到让人小鹿乱撞的甜宠文？》的字数为： 15574 字
# 《被青梅竹马表白是什么体验？》的字数为： 15551 字
# 《5. 河外之战》的字数为： 11401 字
# 《你有什么不愿意告诉另一半的秘密？》的字数为： 11502 字
# 《作为从业多年的医生，你对医学生有什么忠告？》的字数为： 9547 字
# 《6. 绿洲》的字数为： 9460 字
# 《如何以“你失明了，突然有一天你恢复了视力，脑海里却有一个声音说『别告诉他们你看得见』”为开头写文章？》的字数为： 9438 字
# 《7. 对不起宝贝，你的头掉了》的字数为： 15330 字
# 《8. 生命起源：机械之心》的字数为： 15623 字
# 《为什么身边的朋友慢慢地都不打游戏了？》的字数为： 15277 字
# 《有没有很短且细思极恐的恐怖故事？》的字数为： 11057 字
# 《学舞蹈的女孩子私生活乱吗？》的字数为： 10637 字
# 《3. 东八区赛博城（二）》的字数为： 15431 字
# 《在美国刺杀总统属于什么罪名？》的字数为： 7422 字
# 《4. 时生》的字数为： 10537 字
# 《在后宫，不争宠如何苟到大结局？》的字数为： 15588 字
# 《2. 东八区赛博城》的字数为： 15402 字
# 《你遇到过哪些灵异的事儿？》的字数为： 12524 字
# 《1. 第三者》的字数为： 8536 字
# 《如果你保留了现在的记忆并回到了小学的课堂上，你会怎么做？》的字数为： 15573 字
# 《第 24 节 虐文女主的反杀》的字数为： 11152 字
# 《第 36 节 玄学大佬也考研》的字数为： 14067 字
# 《第 9 节 那盏茶》的字数为： 7881 字
# 《第 10 节 女帝》的字数为： 15523 字
# 《第 11 节 女帝（番外）》的字数为： 3043 字
# 《第 12 节 论我是如何将虐文沙雕化》的字数为： 15532 字
# 《第 14 节 岁岁终相见》的字数为： 15474 字
# 《第 15 节 岁岁终相见（安慰的小番外）》的字数为： 5138 字
# 《第 16 节 沈家戏台》的字数为： 8490 字
# 《第 17 节 何事沟渠捞明月》的字数为： 10937 字
# 《第 18 节 天下鸽子一锅炖》的字数为： 15523 字
# 《第 19 节 来世再爱小傻子》的字数为： 8427 字
# 《第 20 节 来世再爱小傻子（番外）》的字数为： 6018 字
# 《第 21 节 陨香魂》的字数为： 15315 字
# 《第 22 节 陨香魂（番外）》的字数为： 4006 字
# 《第 23 节 陨香魂·余年（赵宴篇番外）》的字数为： 3328 字
# 《第 24 节 谦谦如钰》的字数为： 9474 字
# 《第 26 节 落肩》的字数为： 15554 字
# 《第 32 节 沉舟》的字数为： 15702 字
# 《第 33 节 诉清欢》的字数为： 15530 字
# 《第 34 节 捡来的心上人》的字数为： 15521 字
# 《第 35 节 捡来的心上人（番外）》的字数为： 4431 字
# 《第 36 节 念丹珠》的字数为： 15584 字
# 《第 37 节 念丹珠（两个番外）》的字数为： 2739 字
# 《第 38 节 恶毒女配太难了》的字数为： 15486 字
# 《第 40 节 妾心如针》的字数为： 4874 字
# 《第 41 节 春和景明》的字数为： 15546 字
# 《第 42 节 洞房花烛夜，我家公子上了树》的字数为： 3306 字
# 《第 43 节 南山歌》的字数为： 15509 字
# 《第 45 节 子夜歌》的字数为： 7832 字
# 《第 46 节 为了独占皇帝，我成了皇帝》的字数为： 15599 字
# 《第 47 节 窃窃私语》的字数为： 15576 字
# 《第 49 节 女画师》的字数为： 15469 字
# 《第 50 节 再无晨曦》的字数为： 15292 字
# 《第 51 节 闻君有两意》的字数为： 15584 字
# 《第 52 节 赤伶》的字数为： 15439 字
# 《第 53 节 玉兰簪》的字数为： 15680 字
# 《第 54 节 苓苓然也》的字数为： 15341 字
# 《第 55 节 苓苓然也（番外）》的字数为： 5820 字
# 《第 56 节 奸臣之女》的字数为： 15424 字
# 《第 57 节 云中曾寄锦书来》的字数为： 11636 字
# 《第 58 节 虞非池中物》的字数为： 15595 字
# 《第 59 节 皇帝今天催更了吗》的字数为： 15323 字
# 《第 60 节 若求得》的字数为： 15642 字
# 《第 61 节 摽有梅》的字数为： 15436 字
# 《第 62 节 鹿走苏台》的字数为： 12556 字
# 《第 63 节 幼帝不是幼弟》的字数为： 15477 字
# 《第 64 节 皎月照我还》的字数为： 15560 字
# 《第 65 节 缘来是你》的字数为： 15379 字
# 《第 66 节 胆小鬼》的字数为： 15480 字
# 《第 67 节 自缚》的字数为： 13057 字
# 《第 68 节 月满西楼》的字数为： 15419 字
# 《第 70 节 何处云起》的字数为： 15410 字
# 《第 71 节 离心而居》的字数为： 15500 字
# 《第 73 节 擒白》的字数为： 15733 字
# 《第 74 节 春尽杨花散》的字数为： 15547 字
# 《第 75 节 归雀》的字数为： 13109 字
# 《第 76 节 今天王妃爱上高数了吗？》的字数为： 15625 字
# 《第 77 节 笃余欢》的字数为： 15546 字
# 《第 1 节 我知道你喜欢我》的字数为： 15357 字
# 《第 2 节 影后的女二剧本+番外》的字数为： 15212 字
# 《第 5 节 全职陪玩》的字数为： 15411 字
# 《第 7 节 老公他天天想离婚》的字数为： 15433 字
# 《第 9 节 深度迷恋》的字数为： 15375 字
# 《第 10 节 青梅不奉陪》的字数为： 14069 字
# 《第 11 节 职业替身》的字数为： 15576 字
# 《第 12 节 当我决定离开你的时候》的字数为： 11458 字
# 《第 13 节 认输》的字数为： 15445 字
# 《第 14 节 初恋和物理》的字数为： 15498 字
# 《第 15 节 双面女友》的字数为： 15339 字
# 《第 16 节 她和我说再见》的字数为： 10084 字
# 《第 1 节 恶毒女二保命攻略·上》的字数为： 12804 字
# 《第 10 节 我没有······他了》的字数为： 8977 字
# 《2. 猫猫》的字数为： 15438 字
# 《第 1 节 跌落仙台，修入魔道》的字数为： 11272 字
# 《第 2 节 魔尊专属之物》的字数为： 9524 字
# 《第 3 节 彻头彻尾的废物》的字数为： 14087 字
# 《第 4 节 妖王夙汐》的字数为： 13211 字
# 《第 5 节 最大的威胁》的字数为： 15668 字
# 《第 6 节 青玉派》的字数为： 11069 字
# 《第 7 节 我喜欢你》的字数为： 11357 字
# 《第 8 节 石榴石手链》的字数为： 12651 字
# 《第 9 节 永远活在美好之中》的字数为： 8875 字
# 《第 10 节 赝品公主》的字数为： 11532 字
# 《第 11 节 活下去》的字数为： 12629 字
# 《第 12 节 前尘过往（上）》的字数为： 12701 字
# 《第 13 节 前尘过往（下）》的字数为： 15627 字
# 《第 14 节 四界之主》的字数为： 15242 字
# 《第 15 节 番外篇》的字数为： 13059 字
# 《第 1 节 灵堂艳舞》的字数为： 15491 字
# 《第 21 节 他与樱花》的字数为： 11658 字
# 《第 20 节 雪野漫长》的字数为： 13020 字
# 《第 19 节 竹马与栀花》的字数为： 13167 字
# 《第 17 节 少女的祈祷》的字数为： 13952 字
# 《第 16 节 关于春天的一件小事》的字数为： 12575 字
# 《第 15 节 委托恋情》的字数为： 12785 字
# 《第 13 节 缚月》的字数为： 11907 字
# 《第 12 节 雪意玫瑰》的字数为： 15773 字
# 《第 9 节 穿越养猫指南》的字数为： 11934 字
# 《第 8 节 月亮爱人》的字数为： 13259 字
# 《第 5 节 娇瓷》的字数为： 15836 字
# 《第 4 节 心火》的字数为： 15844 字
# 《第 3 节 男朋友的青梅》的字数为： 13983 字
# 《第 2 节 租来的男友》的字数为： 15879 字
# 《第 1 节 原来他也喜欢我》的字数为： 15799 字
# 《地师少女之鄱阳湖水猴子》的字数为： 15555 字
# 《地师少女之丰都鬼城》的字数为： 15519 字
# 《8》的字数为： 4550 字
# 《与顶流弟弟同居》的字数为： 15792 字
# 《变色金龙 一场恶斗 结局团圆》的字数为： 15215 字
# 《变色金龙 真假云飞 扑朔迷离》的字数为： 15413 字
# 《变色金龙 千里迢迢 寻师解困》的字数为： 15394 字
# 《变色金龙 翳雾风云 笼罩山庄》的字数为： 13084 字
# 《辣情霸色 第十五章》的字数为： 15299 字
# 《辣情霸色 第十四章》的字数为： 15281 字
# 《辣情霸色 第十三章》的字数为： 15201 字
# 《辣情霸色 第十二章》的字数为： 15290 字
# 《辣情霸色 第十一章》的字数为： 15229 字
# 《有文笔好不狗血的穿越或者重生文推荐吗?》的字数为： 25457 字
# 《如何以“我是被王爷/将军从青楼里赎回来的”为开头写…》的字数为： 32732 字
# 《108你在不经意间听见或看见过什么不该听见或看见的…》的字数为： 15290 字
# 《096有没有那种男主暗恋女主很久，一步步引诱女主爱…》的字数为： 15519 字
# 《094以“我的男宠是可以随时干掉我的大佬”为开头，…》的字数为： 15516 字
# 《辣情霸色 第 六 章》的字数为： 15291 字
# 《辣情霸色 第 二 章》的字数为： 15333 字
# 《辣情霸色 第一章 无心插柳》的字数为： 3467 字
# 《跟军人谈恋爱是怎样的体验？》的字数为： 9380 字
# 《你见过胆子最大的人是什么样的？》的字数为： 10245 字
# 《泡他》的字数为： 15637 字
# 《遇见星星》的字数为： 12969 字
# 《被校霸发现我有两幅面孔》的字数为： 15145 字
# 《十三年不止》的字数为： 11982 字
# 《甜味校霸》的字数为： 12309 字
# 《后宫之卫瑶》的字数为： 15536 字
# 《民间有哪些灵异禁忌？》的字数为： 11213 字
# 《有没有什么好看的小说，女主很飒很拽，男主也很酷的小说？》的字数为： 21423 字
# 《笙笙不息》的字数为： 14526 字
# 《有没有娱乐圈爽文，小糊咖意外翻红那种？》的字数为： 11932 字
# 《见君如故》的字数为： 12199 字
# 《背刺规则 2：恶灵校园》的字数为： 15641 字
# 《岳飞北伐时把赵构换成刘禅，他会令岳飞班师吗？》的字数为： 15569 字
# 《在春日与你离别》的字数为： 14191 字
# 《攻略失败后我绿了男主》的字数为： 13192 字
# 《你经历的哪个事件，让你现在想起来还后怕？》的字数为： 14346 字
# 《穿书后和大反派 HE 了》的字数为： 16738 字
# 《我的官配被穿书女拦截了》的字数为： 24572 字
# 《有没有好看的追妻火葬场的小说？》的字数为： 13761 字
# 《全员病娇》的字数为： 13799 字
# 《校园女配要靠内卷上清华》的字数为： 20695 字
# 《你认为最牛的科幻桥段或者科幻对象是什么？》的字数为： 29824 字
# 《苟住！末日植物大作战》的字数为： 15828 字
# 《苟住！吸血鬼的末日食堂》的字数为： 19200 字
# 《苟住！末日爱情超进化》的字数为： 25590 字
# 《苟住！末日拒绝圣母》的字数为： 25956 字
# 《皇宫中的人脸》的字数为： 14651 字
# 《裙下之臣》的字数为： 23389 字
# 《八百里加急的八音盒》的字数为： 10915 字
# 《怒放的曼陀罗》的字数为： 14748 字
# 《穿成修仙文的卷王大师姐》的字数为： 13364 字
# 《爱人与自洽》的字数为： 12194 字
# 《清风不再见》的字数为： 18590 字
# 《我在玛丽苏世界里躺赢》的字数为： 21704 字
# 《临江一许》的字数为： 15260 字
# 《异国恋男友出轨后，跪求我复合》的字数为： 10245 字
# 《梦醒十分说爱你》的字数为： 20634 字
# 《房产之争》的字数为： 11086 字
# 《如何成为恶毒婆婆的掌心宠》的字数为： 17051 字
# 《君问归期未有期》的字数为： 10929 字
# 《互换疑云》的字数为： 8925 字
# 《恶毒女配的崛起》的字数为： 13144 字
# 《只当唯一的姐》的字数为： 11952 字
# 《我的顶流男友是个恋爱脑》的字数为： 9892 字
# 《男友和千万粉丝女网红官宣以后，我用铁锅炖了他的鹅》的字数为： 13225 字
# 《有没有甜甜的睡前故事？》的字数为： 28905 字
# 《父亲死后，我被迫辍学打工》的字数为： 8216 字
# 《穿进霸总文，扰乱全局》的字数为： 11570 字
# 《小绿茶》的字数为： 3357 字
# 《见到前任是什么样的体验》的字数为： 17361 字
# 《我的爸妈》的字数为： 22200 字
# 《月光回暖》的字数为： 25658 字
# 《我只是女配》的字数为： 10692 字
# 《有什么令人爽翻的复仇文》的字数为： 10914 字
# 《茅坑里的黑鲶鱼》的字数为： 10394 字
# 《父母偏心到底有多伤人？》的字数为： 15752 字
# 《女配她人间清醒》的字数为： 13248 字
# 《有哪些女主很病弱男主占有欲超强的小说推荐？》的字数为： 17755 字
# 《直播男女事件》的字数为： 17375 字
# 《星星落下》的字数为： 15685 字
# 《大家都有过什么恐怖经历？》的字数为： 9593 字
# 《妾无双》的字数为： 14593 字
# 《和仙尊解绑的系统回来了》的字数为： 17129 字
# 《Siri 杀人始末》的字数为： 10642 字
# 《清醒不可爱》的字数为： 15572 字
# 《典妻》的字数为： 6289 字
# 《筹谋》的字数为： 7628 字
# 《攻略成功后，我抹杀了穿越女》的字数为： 19073 字
# 《当我卖掉了恋爱脑》的字数为： 10720 字
# 《穿进嗑学世界后》的字数为： 22816 字
# 《山水一程》的字数为： 23047 字
# 《室友说自己有抑郁症，让我把生活费分她一半》的字数为： 15353 字
# 《这个反派我不要了》的字数为： 15341 字
# 《盛夏将逝》的字数为： 14965 字
# 《我怀孕四个月后，老公的情人被杀了》的字数为： 12081 字
# 《宿敌悖论》的字数为： 13613 字
# 《璀璨如她》的字数为： 11577 字
# 《牌王 ?》的字数为： 14655 字
# 《摆烂女主退退退》的字数为： 14584 字
# 《对篮球队长负责》的字数为： 12140 字
# 《攻略反派boss》的字数为： 20028 字
# 《轻负》的字数为： 13236 字
# 《倾江之月秋瑟瑟》的字数为： 15232 字
# 《如果蜗牛有爱情》的字数为： 23497 字
# 《以物易物》的字数为： 6517 字
# 《有鱼》的字数为： 21701 字
# 《进击的女配》的字数为： 11572 字
# 《和上司谈恋爱是怎样的一种体验？》的字数为： 15739 字
# 《吾姐阿菀》的字数为： 15815 字
# 《前男友将我抵在门后问我当初为什么分手，我怒吼：你太大了！》的字数为： 18822 字
# 《重生后，我给皇帝下毒》的字数为： 14616 字
# 《重启世界》的字数为： 11252 字
# 《绵绵不期许》的字数为： 18086 字
# 《长生膏》的字数为： 21761 字
# 《我带的顶流和对家在一起了》的字数为： 15049 字
# 《抠门霸总和人间清醒金丝雀》的字数为： 12979 字
# 《将军夫人很惜命》的字数为： 11557 字
# 《有推荐的虐文吗？》的字数为： 11310 字
# 《葡萄成熟时》的字数为： 11730 字
# 《全程姨母笑的甜文有没有？》的字数为： 11739 字
# 《复活雪柳》的字数为： 21406 字
# 《豺狼》的字数为： 14912 字
# 《冷刃温酒》的字数为： 11693 字
# 《鄙视》的字数为： 13925 字
# 《听到老板心声后我震惊了》的字数为： 10727 字
# 《沉睡的白玫瑰》的字数为： 13881 字
# 《尔等不配》的字数为： 14631 字
# 《有什么暴虐虐到哭死的虐文推荐吗？》的字数为： 3341 字
# 《梦事三年（下）》的字数为： 12436 字
# 《炮灰白月光下线日记》的字数为： 15573 字
# 《22. 穿书后我试图改变剧情》的字数为： 14537 字
# 《20. 和对家爱豆穿书了》的字数为： 15658 字
# 《如果拿五百万去澳门赌博，赢到了十几亿，不考虑赢钱的人的主观因素，赌场的人会放他带着巨款离开澳门吗？》的字数为： 10585 字
# 《19. 被渣后我成了老板的猫》的字数为： 15556 字
# 《如果虐文女主突然醒悟，会有什么故事》的字数为： 15499 字
# 《7. 刘芳：我的价值不止在奉献》的字数为： 10236 字
# 《第 1 节 我靠读心术直播捡漏》的字数为： 13906 字
# 《第 2 节 我用旁白开挂》的字数为： 13971 字
# 《第 3 节 循环死亡》的字数为： 12919 字
# 《第 4 节 和重男轻女的爸爸互换身体之后》的字数为： 13050 字
# 《第 5 节 绿茶要拔我气管》的字数为： 13288 字
# 《第 6 节 被鬼王缠上后我运气爆棚了》的字数为： 11980 字
# 《第 7 节 造物主的救赎》的字数为： 11628 字
# 《第 8 节 贤妻良母系统》的字数为： 14668 字
# 《第 9 节 老娘不好惹》的字数为： 10665 字
# 《第 10 节 最优性价比》的字数为： 13122 字
# 《第 17 节 我这是捅了功德窝吧》的字数为： 10978 字
# 《第 18 节 三年高考，两月逆袭》的字数为： 12223 字
# 《第 19 节 臭鱼烂虾请锁死》的字数为： 12122 字
# 《第 20 节 星火燎原》的字数为： 15577 字
# 《第 21 节 你有系统又怎么样》的字数为： 10548 字
# 《第 25 节 秒杀法外狂徒》的字数为： 10993 字
# 《第 26 节 穿成po文女主她妈》的字数为： 15526 字
# 《第 27 节 自赎》的字数为： 11467 字
# 《第 28 节 长姐不干了》的字数为： 15422 字
# 《第 29 节 盛世》的字数为： 10758 字
# 《第 30 节 这个白雪不对劲》的字数为： 15655 字
# 《第 31 节 天才总是如此低调》的字数为： 12403 字
# 《第 32 节 灵气复苏后我杀疯了》的字数为： 12849 字
# 《第 33 节 乙女游戏女主觉醒意识后》的字数为： 12032 字
# 《第 34 节 反杀背刺》的字数为： 13025 字
# 《第 35 节 高考：画皮》的字数为： 15676 字
# 《第 37 节 高考：灿烂的她》的字数为： 11246 字
# 《第 1 节 我来姑苏，不做妾》的字数为： 15422 字
# 《第 2 节 见鹿》的字数为： 15494 字
# 《第 3 节 见鹿（两个甜腻腻的番外）》的字数为： 4802 字
# 《第 4 节 见鹿番外：江月何年初照人》的字数为： 5017 字
# 《第 5 节 见鹿番外：堪折》的字数为： 5395 字
# 《第 6 节 见鹿番外：雨打风吹去》的字数为： 5718 字
# 《第 7 节 见鹿番外：人道夏虫痴》的字数为： 6532 字
# 《第 8 节 我不做将军夫人好多年》的字数为： 15627 字
# 《第 27 节 不负相思》的字数为： 15500 字
# 《第 28 节 不负相思（两个番外）》的字数为： 9015 字
# 《第 29 节 恶毒女配一点也不恶毒记》的字数为： 15541 字
# 《第 31 节 寸相思（两个番外）》的字数为： 9326 字
# 《白月光回来我发疯》的字数为： 23136 字
# 《网络小说里有什么沙雕情节？》的字数为： 22914 字
# 《和顶流rapper恋综怼茶》的字数为： 15418 字
# 《黑料女王觉醒记》的字数为： 25240 字
# 《我和妈妈的齿轮》的字数为： 13444 字
# 《我捏碎了系统》的字数为： 11978 字
# 《密室规则怪谈》的字数为： 10757 字
# 《燕昭女帝》的字数为： 13304 字
# 《10. 主食选择：什么才是让你越吃越瘦的主食？》的字数为： 3992 字
# 《9. 能量预估：怎样快速判断食物的能量高低》的字数为： 3710 字
# 《7. 减肥怎么吃？ 教你制定属于自己的减肥食谱》的字数为： 5253 字
# 《6. 怎样守住基础代谢率，让你减肥不掉速》的字数为： 3700 字
# 《放不下的曾经》的字数为： 15619 字
# 《女主只想打职业》的字数为： 21497 字
# 《他和他的猫》的字数为： 12755 字
# 《有没有什么一看就停不下来的爽文？》的字数为： 8221 字
# 《校车乘车规则》的字数为： 12712 字
# 《《西游记》中，为什么越靠近灵山妖怪越凶残？离佛祖最远的大唐反而太平？》的字数为： 11128 字
# 《有什么百看不厌甜甜的睡前故事?》的字数为： 14987 字
# 《你在高中时听说过/做过什么轰动全校的事？》的字数为： 17609 字
# 《校草他总想和我复合》的字数为： 11676 字
# 《深渊凝视》的字数为： 11353 字
# 《我本以为我是女主》的字数为： 3002 字
# 《世子每天在作死》的字数为： 9903 字
# 《我要月亮奔我而来》的字数为： 11118 字
# 《京圈少爷三下乡》的字数为： 20571 字
# 《小号男友团》的字数为： 16086 字
# 《摄政王他能有什么坏心思呢》的字数为： 11735 字
# 《有哪些甜度爆表的小故事?》的字数为： 21166 字
# 《没想到吧，你也是替身！》的字数为： 13805 字
# 《瞎子美人》的字数为： 13089 字
# 《夫君一心让我秃头》的字数为： 17287 字
# 《我才不是黑毛鸡》的字数为： 11933 字
# 《春日奔逃》的字数为： 13143 字
# 《影帝的恋爱游戏：时针追逐秒针》的字数为： 13370 字
# 《花开花落自有时》的字数为： 14262 字
# 《末日躺平记事》的字数为： 16598 字
# 《椒吻》的字数为： 18110 字
# 《九块九的钻戒》的字数为： 11457 字
# 《有没有男主追妻火葬场 男二上位的古言？》的字数为： 10669 字
# 《我死后第五年，前夫突然后悔了……》的字数为： 11482 字
# 《不是配角》的字数为： 16091 字
# 《和顶流竹马参加恋综后，全网磕疯了》的字数为： 12790 字
# 《闺蜜害我被掏空器官，她不知道，48h后我们会互换身体》的字数为： 8919 字
# 《恶毒女配小跟班》的字数为： 18406 字
# 《穿书女王》的字数为： 11756 字
# 《是她的心尖尖》的字数为： 12542 字
# 《有没有什么女主很沙雕的文？》的字数为： 17065 字
# 《有没有女主性格很冷漠小说?》的字数为： 11993 字
# 《人蛇冢》的字数为： 15360 字
# 《要开心》的字数为： 13885 字
# 《只有我弟受伤的世界达成了》的字数为： 11581 字
# 《不死蒲公英》的字数为： 25315 字
# 《我的贾莲女士》的字数为： 11843 字
# 《成为卧底后我有了读心术》的字数为： 16621 字
# 《与你同行》的字数为： 11433 字
# 《她们的反击》的字数为： 9578 字
# 《竹马清词》的字数为： 16664 字
# 《和顶流相互暗恋的第七年》的字数为： 17637 字
# 《不愿她做未亡人》的字数为： 8069 字
# 《妖界交换生》的字数为： 25789 字
# 《缅北归来》的字数为： 21207 字
# 《娇娇宠爱》的字数为： 13003 字
# 《若你知我心意》的字数为： 12864 字
# 《高智商罪犯恐怖到什么程度？》的字数为： 3518 字
# 《小助理今天也在努力摸鱼》的字数为： 12800 字
# 《一个喜欢了很久的人，后来终于释怀了，再见的时候还会心动吗？》的字数为： 15632 字
# 《如何以“我惹了满京城最不该惹的人”为开头写一个故事？》的字数为： 15382 字
# 《你见过的狠人有多绝》的字数为： 17051 字
# 《不当小跟班》的字数为： 15162 字
# 《有没有爆笑无脑沙雕文》的字数为： 3507 字
# 《一个人阴暗起来可以阴暗到什么地步》的字数为： 13964 字
# 《桥上星》的字数为： 16680 字
# 《成为动物饲养员后》的字数为： 18080 字
# 《黑白之恋》的字数为： 12590 字
# 《有没有什么好看的短篇小甜文推荐？》的字数为： 14657 字
# 《茉莉与玫瑰》的字数为： 12436 字
# 《沙雕女主穿进虐文》的字数为： 11392 字
# 《有什么重生古风类的言情小说？》的字数为： 15722 字
# 《两世爱人》的字数为： 19686 字
# 《如果你穿成修仙文里的第一美人女配你会怎么样》的字数为： 15532 字
# 《中国历史上，有没有什么事件让你觉得“真是天佑中华啊！”》的字数为： 5987 字
# 《圣女小蛇》的字数为： 10532 字
# 《极光异能》的字数为： 20601 字
# 《吃人肉是一种什么体验》的字数为： 8364 字
# 《如何以“我被人挂在了表白墙”为开头，写一个故事？》的字数为： 15782 字
# 《婆婆可以恶心到什么程度？》的字数为： 15463 字
# 《在爱情面前你能卑微到什么程度？》的字数为： 12929 字
# 《为什么有人把金瓶梅称作奇书？》的字数为： 7086 字
# 《别来招惹，我无所不能》的字数为： 15755 字
# 《开挂剧本：爽文女主我来当》的字数为： 15663 字
# 《有什么好看的小甜文？》的字数为： 15640 字
# 《有没有什么短篇言情小说把你虐哭了？》的字数为： 15837 字
# 《花花世界、新新职业：她们孤身穿越都市丛林》的字数为： 15281 字
# 《罪与罚：女杀人犯的沉沦》的字数为： 15467 字
# 《红尘猎爱：为你，不计代价》的字数为： 15744 字
# 《世间烟火，甜亮你我》的字数为： 15906 字
# 《摆脱尬聊：社交高手必修课》的字数为： 15362 字
# 《控制欲占有欲太强怎么办？》的字数为： 3251 字
# 《可以写一个崩坏的童话故事吗？》的字数为： 15503 字
# 《严于绿己》的字数为： 15624 字
# 《为什么后宫中嫔妃们一定要争宠？ -》的字数为： 15581 字
# 《人工智能会造成人类大失业，还是会让人类社会空前繁荣？》的字数为： 3270 字
# 《有什么好看的小说值得推荐？》的字数为： 15557 字
# 《不可避免的影响》的字数为： 15454 字
# 《桃夭》的字数为： 15483 字
# 《枝头雀》的字数为： 15654 字
# 《宿管阿姨摆烂了》的字数为： 15651 字
# 《有哪些女主把男主当替身的小说？》的字数为： 15666 字
# 《可以推荐一些高甜文笔好的小说吗？ -江枫》的字数为： 12970 字
# 《那些被辜负的深情后来都怎么样了？》的字数为： 15585 字
# 《被最爱的人伤害背叛是什么感觉？》的字数为： 15493 字
# 《有哪些让人细思恐极的小故事？-小尘》的字数为： 12891 字
# 《为什么中国最近20年发展就跟开了挂一样？ -》的字数为： 15018 字
# 《有没有一些“虐妻一时爽，追妻火葬场”类的小说推荐？》的字数为： 14710 字
# 《穿越女的平凡生活》的字数为： 7123 字
# 《暮雨潇》的字数为： 6419 字
# 《我和我哥一起鉴茶》的字数为： 6369 字
# 《我被绑匪错当首富千金》的字数为： 5973 字
# 《哭包小恶龙》的字数为： 6152 字
# 《病秧子在娃综摆烂后爆火了》的字数为： 6058 字
# 《麻将情缘》的字数为： 6300 字
# 《苟住！末日豚鼠计划》的字数为： 6749 字
# 《蹭劫成仙》的字数为： 6423 字
# 《德国罗腾堡食人魔：爱你就要吃掉你》的字数为： 4718 字
# 《当这地球还有花》的字数为： 5667 字
# 《香火的报应》的字数为： 6120 字
# 《迟迟·番外》的字数为： 3753 字
# 《谈恋爱不如继承亿万家财》的字数为： 5938 字
# 《反派治愈任务》的字数为： 6067 字
# 《星禾》的字数为： 5863 字
# 《前男友暴富后》的字数为： 6349 字
# 《超分裂男友》的字数为： 6084 字
# 《攻略病娇男主》的字数为： 6234 字
# 《二分之一白月光剧本》的字数为： 5887 字
# 《女明星她正骨贼6》的字数为： 5730 字
# 《或许生不如死》的字数为： 5808 字
# 《我眼里不揉沙》的字数为： 5896 字
# 《套路熊孩子》的字数为： 6154 字
# 《我哥的白月光跟我跑了》的字数为： 6025 字
# 《我在恐怖综艺里发疯爆红》的字数为： 6350 字
# 《绝不被迷惑的男友》的字数为： 6043 字
# 《我有个顶流男友》的字数为： 6371 字
# 《女配的霸总他觉醒了》的字数为： 6152 字
# 《机械谬论》的字数为： 5701 字
# 《这校园恶毒女配我不当了》的字数为： 6125 字
# 《共生》的字数为： 6330 字
# 《我的哭包家人们》的字数为： 6445 字
# 《地府打工人》的字数为： 5871 字
# 《我与男主二三事》的字数为： 6235 字
# 《孽子》的字数为： 6566 字
# 《嘴炮女主她无所畏惧》的字数为： 6263 字
# 《无法拿起的手术刀》的字数为： 6064 字
# 《我不是整容怪》的字数为： 6340 字
# 《不信人间有白头》的字数为： 5890 字
# 《男友一家都是抹茶高手》的字数为： 6346 字
# 《鱼星》的字数为： 5605 字
# 《被抄袭后，我摆烂了》的字数为： 5812 字
# 《只对你心动》的字数为： 5822 字
# 《恶毒女配拯救计划》的字数为： 6423 字
# 《她的反向时钟》的字数为： 5993 字
# 《锦荣花》的字数为： 6133 字
# 《魂穿绿茶后我意外爆火了》的字数为： 6200 字
# 《请你先遗忘》的字数为： 6390 字
# 《宠婢为妻》的字数为： 5994 字
# 《影帝全家团宠我》的字数为： 5779 字
# 《亲爱的社恐症》的字数为： 6158 字
# 《女配的觉醒》的字数为： 5983 字
# 《南枝草原》的字数为： 6090 字
# 《论群演的自我修养》的字数为： 6030 字
# 《穿成影帝女儿》的字数为： 5892 字
# 《男神说不喜欢我》的字数为： 5696 字
# 《无敌幸运星》的字数为： 6234 字
# 《零点时分》的字数为： 5927 字
# 《大年初一：我把男友全家扫地出门》的字数为： 6454 字
# 《最有钱的小凤凰》的字数为： 6006 字
# 《替身小少爷》的字数为： 6352 字
# 《徐徐爱恋》的字数为： 5716 字
# 《当影帝成了恋爱脑后》的字数为： 6147 字
# 《春山空》的字数为： 6691 字
# 《全师门只有我是正常人》的字数为： 6185 字
# 《垃圾桶里的校草》的字数为： 5947 字
# 《得绝症之后》的字数为： 5888 字
# 《凭阑独自香》的字数为： 6135 字
# 《与男神互换后》的字数为： 6189 字
# 《你是我的私藏浪漫》的字数为： 5661 字
# 《穿越女的复仇》的字数为： 6040 字
# 《娱乐圈猫薄荷精》的字数为： 6457 字
# 《余生不多，请放肆地为自己活一回》的字数为： 5881 字
# 《永远偏爱阿婉》的字数为： 5929 字
# 《嫡女有谋》的字数为： 6027 字
# 《退婚太子妃》的字数为： 6464 字
# 《熊孩子大闹动物园》的字数为： 6195 字
# 《舔狗的觉醒》的字数为： 5870 字
# 《时时思慕，见你朝朝》的字数为： 5984 字
# 《海棠沾尘》的字数为： 6613 字
# 《尘鞅》的字数为： 6573 字
# 《我家粘人的螣蛇仙君》的字数为： 6119 字
# 《恋综里说爱你》的字数为： 6121 字
# 《我成为校花后》的字数为： 6479 字
# 《公主行：夷光明天下》的字数为： 5975 字
# 《毛毛小凤凰》的字数为： 6699 字
# 《影帝原来是茶狗》的字数为： 6006 字
# 《假千金暴富了》的字数为： 6289 字
# 《江亦珠》的字数为： 6325 字
# 《嘴臭CP》的字数为： 6433 字
# 《舌尖上的谋杀》的字数为： 5786 字
# 《家婆好姐妹》的字数为： 6197 字
# 《妈宝男成长计划》的字数为： 5678 字
# 《夫君是龙王》的字数为： 6316 字
# 《薄幸偏爱演》的字数为： 6297 字
# 《房产税为何迟迟不可开征？》的字数为： 8179 字
# 《两心知·番外》的字数为： 2905 字
# 《查寝大劫》的字数为： 5992 字
# 《千金的完美反击》的字数为： 6032 字
# 《青丘往事》的字数为： 6017 字
# 《开主角光环的女人》的字数为： 6460 字
# 《真千金归来后我被全家吸血》的字数为： 6679 字
# 《最后的怪物》的字数为： 6293 字
# 《我佛不度内卷人》的字数为： 5867 字
# 《夫君总觉得我要死怎么办》的字数为： 5936 字
# 《折花襟》的字数为： 6074 字
# 《钓系女星上恋综》的字数为： 5869 字
# 《你是我亲手养大的玫瑰》的字数为： 6077 字
# 《拯救小姨》的字数为： 6066 字
# 《侵霜华》的字数为： 6159 字
# 《当美艳狗仔遇上影帝》的字数为： 6098 字
# 《发现自己是假千金后成为团宠》的字数为： 6651 字
# 《年少一错，半生买单》的字数为： 6592 字
# 《多情应是我》的字数为： 6017 字
# 《守寡直播》的字数为： 5761 字
# 《女主是朵黑心莲》的字数为： 5999 字
# 《举报！我婆婆效仿小妈文学》的字数为： 6026 字
# 《顶流夫妇有点甜》的字数为： 6332 字
# 《被赶出家门后，我靠冲喜暴富了》的字数为： 6212 字
# 《影帝的马甲小娇妻》的字数为： 6500 字
# 《米粒珍珠》的字数为： 6038 字
# 《能让人说真话后，我绝地反击》的字数为： 6464 字
# 《我的极品嫂子》的字数为： 6566 字
# 《不负明月不负卿》的字数为： 6153 字
# 《白月光的七年婚变》的字数为： 6124 字
# 《首富后妈》的字数为： 6087 字
# 《重男轻女的奶奶悔不当初》的字数为： 5769 字
# 《豪门小保姆》的字数为： 6766 字
# 《种菜综艺撕绿茶》的字数为： 6531 字
# 《精神赎罪》的字数为： 6097 字
# 《白莲花冒充我身份》的字数为： 6310 字
# 《被迈巴赫撞断腿后我暴富了》的字数为： 5776 字
# 《我凭绿自己走上致富之路》的字数为： 6176 字
# 《和发小结婚是什么体验？ -》的字数为： 15708 字
# 《恶邻自由恶邻磨》的字数为： 7035 字
# 《前任的最佳助攻》的字数为： 6297 字
# 《两心知》的字数为： 6066 字
# 《他怀里的玫瑰》的字数为： 6235 字
# 《赠我新生》的字数为： 6199 字
# 《别惹我，我会骂人》的字数为： 6202 字
# 《娘子请自重》的字数为： 5775 字
# 《喇叭嘴替有点毒》的字数为： 6318 字
# 《关于有人在我坟头上盖舞厅这件事》的字数为： 6297 字
# 《安能复行舟》的字数为： 6220 字
# 《凝凝不语》的字数为： 5980 字
# 《德宁皇后》的字数为： 5738 字
# 《老祖宗他性格多变》的字数为： 5929 字
# 《摆烂太后要退休》的字数为： 6020 字
# 《网黑女星豁出去》的字数为： 5703 字
# 《觉醒透视眼后》的字数为： 6028 字
# 《凤凰还是鸡》的字数为： 6186 字
# 《被霸凌后我觉醒了读心术》的字数为： 5711 字
# 《校霸家的绿茶小狗》的字数为： 5898 字
# 《恶毒继母竟带我们走上人生巅峰》的字数为： 6171 字
# 《隐婚影帝官宣了》的字数为： 6183 字
# 《这次我选病娇的他·番外》的字数为： 5541 字
# 《玩山寨烟花炸了校霸后》的字数为： 5898 字
# 《我见青山多妩媚》的字数为： 6005 字
# 《番外：新春快乐》的字数为： 6181 字
# 《皇后是阿飘》的字数为： 6248 字
# 《念念不知予》的字数为： 6280 字
# 《招惹疯批》的字数为： 6304 字
# 《我非女主》的字数为： 5923 字
# 《死后跟暗恋对象在一起了》的字数为： 6360 字
# 《疯批美人复仇记》的字数为： 6231 字
# 《我们的灵魂永远相爱》的字数为： 6591 字
# 《心动为零》的字数为： 5994 字
# 《小玫瑰的最后十四天》的字数为： 6446 字
# 《冥郎》的字数为： 6595 字
# 《我和反派的天才崽崽》的字数为： 5696 字
# 《恶与罚》的字数为： 6287 字
# 《余生：番外篇》的字数为： 5973 字
# 《影帝的暗恋秘密》的字数为： 5976 字
# 《梦里花》的字数为： 6308 字
# 《拯救校霸从高考开始》的字数为： 6018 字
# 《床下狗尸》的字数为： 6607 字
# 《宋医生，天黑请闭眼》的字数为： 5828 字
# 《和十一年男友分手了》的字数为： 6310 字
# 《影帝被我爆料了》的字数为： 5901 字
# 《特别的料理》的字数为： 5992 字
# 《公主不做妾》的字数为： 6219 字
# 《情人节捡个男朋友》的字数为： 6028 字
# 《经年挚爱》的字数为： 6035 字
# 《坏小孩的约定》的字数为： 6466 字
# 《病名长生》的字数为： 6272 字
# 《不讲义气的影帝官宣后，我和顶流闪婚了》的字数为： 6084 字
# 《摆烂后被顶流闺蜜带飞了》的字数为： 6549 字
# 《他手机里有爱人，有秘密，有感情——转自天涯【 完结 】》的字数为： 14541 字
# 《什么样的男生一看就知道没谈过恋爱？》的字数为： 10174 字
# 《开工红包索命事件》的字数为： 6171 字
# 《末日摆烂记》的字数为： 6345 字
# 《泽尘而依》的字数为： 6250 字
# 《若珍宝》的字数为： 6317 字
# 《言灵师女星》的字数为： 5849 字
# 《Q版大学生》的字数为： 6115 字
# 《凤凰不好惹》的字数为： 5943 字
# 《虐文女主看到弹幕后狂虐渣男》的字数为： 6460 字
# 《眠眠向南》的字数为： 6500 字
# 《被绿后，我嫁给了前男友死对头》的字数为： 5391 字
# 《极限捡漏》的字数为： 5811 字
# 《被偷走气运后，我摆烂了》的字数为： 5894 字
# 《我的好人爸爸》的字数为： 6921 字
# 《拐走奶狗影帝》的字数为： 6192 字
# 《娇娇难宠》的字数为： 6318 字
# 《穿越后我靠当翻译苟住小命》的字数为： 6266 字
# 《和二哈的恋爱日常》的字数为： 6007 字
# 《女友索要天价彩礼，婚礼现场变葬礼》的字数为： 6355 字
# 《番外三：野心家的忏悔录》的字数为： 6070 字
# 《一心搞事业的丧尸王》的字数为： 6389 字
# 《爱在军训时》的字数为： 5861 字
# 《乌鸦嘴本嘴》的字数为： 6169 字
# 《醒亦念卿，梦亦念卿》的字数为： 6348 字
# 《末途》的字数为： 6515 字
# 《深情有悔》的字数为： 6565 字
# 《非常规剧情》的字数为： 6513 字
# 《夏风与冬雪》的字数为： 6406 字
# 《我只想退婚》的字数为： 6343 字
# 《星途灿烂鸡冠花》的字数为： 6514 字
# 《我在恋综手撕渣男贱女》的字数为： 5955 字
# 《逃不掉的循环》的字数为： 5858 字
# 《抄家前我搬空家产》的字数为： 5677 字
# 《室友的问题男友》的字数为： 6103 字
# 《暗恋明目张胆》的字数为： 5738 字
# 《丈夫的报复》的字数为： 6705 字
# 《吸血鬼爱上小道士》的字数为： 6248 字
# 《真情错付》的字数为： 5836 字
# 《男神学弟是匹狼》的字数为： 5750 字
# 《社牛社恐恋爱好难》的字数为： 6348 字
# 《规则怪谈：加班守则》的字数为： 6183 字
# 《我与她，落轮回》的字数为： 6486 字
# 《邪恶家族》的字数为： 6633 字
# 《鬼妃》的字数为： 6276 字
# 《我被反方三辩骂哭了》的字数为： 6227 字
# 《有什么特别甜特别宠的甜宠文？ -》的字数为： 4839 字
# 《带棺加班》的字数为： 5982 字
# 《我在娱乐圈带球跑》的字数为： 5874 字
# 《前男友他诈尸了》的字数为： 5797 字
# 《天瞳》的字数为： 6283 字
# 《交换女友》的字数为： 6448 字
# 《小姑子的反击》的字数为： 6025 字
# 《男友是狠人》的字数为： 6222 字
# 《滚蛋吧，渣男绿茶！》的字数为： 6441 字
# 《渡春》的字数为： 6304 字
# 《重生鸡毛战》的字数为： 6275 字
# 《卑劣的留学生》的字数为： 6510 字
# 《所念皆星河》的字数为： 5970 字
# 《梦与她》的字数为： 6238 字
# 《校霸的离谱心声》的字数为： 5649 字
# 《裙间秘密》的字数为： 6322 字
# 《二次依恋》的字数为： 6542 字
# 《第二人生》的字数为： 6010 字
# 《慢慢无归处》的字数为： 6489 字
# 《太子宠妾上位指南》的字数为： 6935 字
# 《我哥的未婚妻不对劲》的字数为： 6375 字
# 《月照栀子》的字数为： 6384 字
# 《我在综艺上靠扮演垃圾桶爆红》的字数为： 6231 字
# 《妖神之恋》的字数为： 6193 字
# 《住进校霸身体后》的字数为： 5820 字
# 《朝花落》的字数为： 5236 字
# 《真千金靠乌鸦嘴火爆全网》的字数为： 6026 字
# 《霸凌同学成了我家扫厕阿姨》的字数为： 5296 字
# 《苍绿妄想》的字数为： 6139 字
# 《我是顶流隐婚生崽的那个》的字数为： 6396 字
# 《一瞬成仙》的字数为： 6299 字
# 《雪芙蓉》的字数为： 6556 字
# 《茅山大力神丹》的字数为： 6060 字
# 《生若浮萍，爱似狂风暴雨》的字数为： 6771 字
# 《海后妈妈带球跑》的字数为： 5895 字
# 《第一梦：原文逼我上绝路》的字数为： 6164 字
# 《遗产争夺战》的字数为： 6010 字
# 《恋恋不晚》的字数为： 6254 字
# 《三流女明星的封神日常》的字数为： 5603 字
# 《恶毒女配狂想曲》的字数为： 5934 字
# 《翻身吧！恋爱脑》的字数为： 6232 字
# 《笨蛋美人发财记》的字数为： 5755 字
# 《怒撕总裁的茶艺黑化未婚妻》的字数为： 5723 字
# 《喵喵教立大功》的字数为： 6456 字
# 《重生我不是白月光》的字数为： 6216 字
# 《有光逐月》的字数为： 5986 字
# 《太子反悔我摆烂》的字数为： 6016 字
# 《丧尸眼中的大美女》的字数为： 5830 字
# 《江边映枝》的字数为： 6132 字
# 《念念不再见》的字数为： 5624 字
# 《暧昧无效》的字数为： 6451 字
# 《锦绣阑珊》的字数为： 6643 字
# 《醋精男友》的字数为： 6538 字
# 《天凉王不破》的字数为： 5560 字
# 《人格战役》的字数为： 6196 字
# 《瘫痪老公想回家》的字数为： 6573 字
# 《无声告白》的字数为： 6133 字
# 《老公的汉子婊兄弟》的字数为： 6202 字
# 《影帝的在逃妻子》的字数为： 5608 字
# 《女明星她家里有矿》的字数为： 6138 字
# 《被采访后热搜炸了》的字数为： 6315 字
# 《有个可怕的大学室友是一种怎样的体验？ -》的字数为： 10696 字
# 《最崖边缘上的历史》的字数为： 15451 字
# 《冷面犬妖教官竟是一个嘤嘤怪》的字数为： 6350 字
# 《极致纠缠》的字数为： 6349 字
# 《多余的真千金》的字数为： 6173 字
# 《非碳基白月光》的字数为： 6172 字
# 《男朋友是言灵》的字数为： 6181 字
# 《顶流是我前男友》的字数为： 6504 字
# 《心脏被骗走后》的字数为： 15659 字
# 《吊打高门弟媳》的字数为： 6602 字
# 《十里烟波处》的字数为： 5874 字
# 《校霸的特长》的字数为： 6037 字
# 《虐文女主看到剧透后》的字数为： 6314 字
# 《综艺恋爱》的字数为： 6039 字
# 《繁星入梦来》的字数为： 6007 字
# 《一万次心动》的字数为： 6014 字
# 《吊打极品亲戚》的字数为： 6314 字
# 《执迷有悟》的字数为： 6269 字
# 《读心恋综》的字数为： 6150 字
# 《他的肆爱独宠》的字数为： 6013 字
# 《我的满级弟弟》的字数为： 6552 字
# 《穿成龙傲天正宫之后》的字数为： 6407 字
# 《早春逝去》的字数为： 6454 字
# 《超时存在》的字数为： 5832 字
# 《幻梦终醒》的字数为： 6290 字
# 《老公找来的小保姆》的字数为： 6341 字
# 《霸总他会摇花手》的字数为： 5829 字
# 《公主归塞》的字数为： 6181 字
# 《高冷女星社死现场》的字数为： 6522 字
# 《牢笼怪谈》的字数为： 6633 字
# 《恶毒父母滚远点》的字数为： 6262 字
# 《悠悠有光》的字数为： 6094 字
# 《影帝是个恋爱脑》的字数为： 6120 字
# 《哈士奇立功》的字数为： 5939 字
# 《我成了竹马的舅妈》的字数为： 5888 字
# 《孙寡妇迁坟》的字数为： 5870 字
# 《过年合约乌龙》的字数为： 6284 字
# 《春风揽明月》的字数为： 5962 字
# 《穿进娱乐圈后我靠骂人爆红了》的字数为： 6017 字
# 《末世躺平不如狗》的字数为： 5919 字
# 《我的联谊男友》的字数为： 6009 字
# 《竹马失忆了》的字数为： 5927 字
# 《影后长了一张嘴》的字数为： 6471 字
# 《神奇当铺》的字数为： 6215 字
# 《我要练小号》的字数为： 6100 字
# 《地师少女之西藏人皮鼓》的字数为： 6409 字
# 《奇葩年年多》的字数为： 5955 字
# 《我靠摆烂走上富豪榜》的字数为： 6514 字
# 《我靠说真话在带娃综艺走红》的字数为： 6237 字
# 《十年后的女儿找来了》的字数为： 6164 字
# 《吉祥止止》的字数为： 6699 字
# 《不当救世主》的字数为： 15404 字
# 《有没有大神推荐古言小说推荐追妻火葬场追不回来的那种？》的字数为： 15545 字
# 《孕期也超甜》的字数为： 5892 字
# 《我的男朋友是神仙》的字数为： 6388 字
# 《七年落幕》的字数为： 5946 字
# 《美男与极品》的字数为： 5649 字
# 《女大佬虐渣记》的字数为： 6637 字
# 《穿成男主后妈后，我摆烂了》的字数为： 6198 字
# 《彩票中奖后我成了孤儿》的字数为： 5767 字
# 《基因的复仇》的字数为： 6099 字
# 《沉沦在爱里》的字数为： 6061 字
# 《暗恋男神有点甜》的字数为： 6032 字
# 《人生说明》的字数为： 6047 字
# 《念念不忘》的字数为： 5988 字
# 《黑红小花超会怼》的字数为： 6290 字
# 《恋综后我成了素质天花板》的字数为： 5999 字
# 《未生》的字数为： 6739 字
# 《校霸藏得深》的字数为： 5897 字
# 《月光在闪烁》的字数为： 6701 字
# 《你从未陪我看极光》的字数为： 6184 字
# 《跟着妈妈上综艺后我火了》的字数为： 5819 字
# 《影帝每天盼着和我官宣》的字数为： 6476 字
# 《你穿到了甜文男主小时候虐待他的恶毒女配怎么办？》的字数为： 15335 字
# 《同学聚会绿茶冒充我马甲》的字数为： 6321 字
# 《狼狗弟弟暗恋我》的字数为： 5708 字
# 《男友超宠我》的字数为： 6851 字
# 《现在就退婚》的字数为： 6378 字
# 《击碎少女梦》的字数为： 6392 字
# 《当红小花送温暖》的字数为： 6361 字
# 《恶意森林》的字数为： 6277 字
# 《延迟宠爱》的字数为： 5805 字
# 《绿茶小作文》的字数为： 6232 字
# 《结婚当天我不嫁了》的字数为： 6408 字
# 《嘴臭达人被迫绑定恋爱脑系统后》的字数为： 6478 字
# 《穿回校霸表白的那天》的字数为： 6434 字
# 《影帝又官宣了》的字数为： 5731 字
# 《龙套女主她超神了》的字数为： 5818 字
# 《打脸伪富男同学》的字数为： 6346 字
# 《和前男友上恋综后，我爆红了》的字数为： 6025 字
# 《养成系影帝》的字数为： 6000 字
# 《我把我妈捧红了》的字数为： 5996 字
# 《栗子情缘》的字数为： 5990 字
# 《玫瑰少女》的字数为： 6316 字
# 《呀！是假千金》的字数为： 6012 字
# 《雪意玫瑰》的字数为： 5750 字
# 《玫瑰失梦者》的字数为： 15559 字
# 《月光何皎皎》的字数为： 5745 字
# 《凤凰孵蛋：铁锅炖上仙》的字数为： 5947 字
# 《我叹浮生且如梦》的字数为： 6794 字
# 《初雪告白》的字数为： 5786 字
# 《理智的报复》的字数为： 6402 字
# 《婆婆的算盘》的字数为： 6231 字
# 《除夕夜放窜天猴》的字数为： 6254 字
# 《网恋对象竟是他》的字数为： 5846 字
# 《逃离恶毒婆婆》的字数为： 6570 字
# 《打脸顶流前任，今天热搜又是我》的字数为： 6432 字
# 《黑暗千金要逆袭》的字数为： 6133 字
# 《我的野王是哑巴》的字数为： 6505 字
# 《初遇今夏》的字数为： 5973 字
# 《作到最后，一无所有》的字数为： 6890 字
# 《清醒丧尸》的字数为： 5713 字
# 《贻我一枝春》的字数为： 6279 字
# 《我靠赶僵尸爆火娱乐圈》的字数为： 6061 字
# 《古董迷局》的字数为： 6240 字
# 《真假少爷》的字数为： 6203 字
# 《我修仙的身份曝光了》的字数为： 5957 字
# 《只会说真话后我人生开挂了》的字数为： 6215 字
# 《失踪的闺蜜》的字数为： 6330 字
# 《末世我的男朋友零元购》的字数为： 6609 字
# 《皇后娘娘太爱我了怎么办》的字数为： 5997 字
# 《猛鬼学校规则怪谈》的字数为： 6494 字
# 《恰好心动》的字数为： 6446 字
# 《我和女配双下乡》的字数为： 5790 字
# 《摆烂后，男主喜欢上了我》的字数为： 6402 字
# 《你携星光缓缓来》的字数为： 6553 字
# 《黑红后，我开始摆烂了》的字数为： 6163 字
# 《影帝甩出结婚证》的字数为： 5645 字
# 《逃离扶弟魔妈妈》的字数为： 6581 字
# 《我成了女配们的新团宠》的字数为： 6098 字
# 《长眠于冰雪》的字数为： 6385 字
# 《第七节大结局》的字数为： 6864 字
# 《施衿结褵：化为天上星空的平凡母亲》的字数为： 3458 字
# 《奶狗小同桌是大佬》的字数为： 5948 字
# 《人生重启计划》的字数为： 6351 字
# 《游戏悖论》的字数为： 5701 字
# 《影帝官宣当爸》的字数为： 5992 字
# 《影帝和我假结婚后总想假戏真做》的字数为： 6128 字
# 《前任成影帝后拉我上恋综》的字数为： 5774 字
# 《替女明星打赢PK后》的字数为： 6047 字
# 《道侣飞升后我佛了》的字数为： 5933 字
# 《嫂子是个伏弟魔》的字数为： 6474 字
# 《岁岁年年》的字数为： 6033 字
# 《首富夫人的自我修养》的字数为： 6084 字
# 《52次告白》的字数为： 6268 字
# 《七月重生》的字数为： 6125 字
# 《锦堂回春记》的字数为： 6225 字
# 《女汉子在线虐渣》的字数为： 6295 字
# 《打脸汉子茶》的字数为： 6283 字
# 《嫡女之争：我才是最强黑莲花》的字数为： 6306 字
# 《月老说我的姻缘是校霸》的字数为： 6185 字
# 《套中校霸》的字数为： 5723 字
# 《我靠PUA帮影后婆婆洗白》的字数为： 6053 字
# 《温秘书今天又传绯闻了吗》的字数为： 6280 字
# 《男主被我猛打脸》的字数为： 6091 字
# 《儿子曝光后，影帝他想父凭子贵》的字数为： 6131 字
# 《我成了暗恋对象的小猫咪》的字数为： 6443 字
# 《灰草向荣》的字数为： 6682 字
# 《校园扑克守则》的字数为： 6298 字
# 《被影帝弟弟连累后》的字数为： 6142 字
# 《我在综艺上满嘴哥哥，竟然爆火了》的字数为： 5862 字
# 《爱恨悠悠》的字数为： 5642 字
# 《与时光同美》的字数为： 5998 字
# 《我的亡夫是大好人》的字数为： 6227 字
# 《和影帝一起晒娃后我火了》的字数为： 5896 字
# 《招魂人》的字数为： 6684 字
# 《豪门哥哥有点宠》的字数为： 6640 字
# 《捞女的代价》的字数为： 6237 字
# 《奇葩剧本》的字数为： 5873 字
# 《拯救小姐计划》的字数为： 5712 字
# 《晚晚和骑士》的字数为： 5520 字
# 《等你的第十年》的字数为： 5796 字
# 《韧草当如茵》的字数为： 6155 字
# 《攻略三位病娇神明》的字数为： 5957 字
# 《间歇性重生》的字数为： 6442 字
# 《回不去的爱意》的字数为： 6058 字
# 《演技才是硬道理》的字数为： 5949 字
# 《第一只爆红的鹦鹉精》的字数为： 6221 字
# 《我靠考公爆红全网》的字数为： 6101 字
# 《穿成霸总他妈》的字数为： 6472 字
# 《青蛙竹马》的字数为： 6233 字
# 《嫁给男主的盲人哥哥》的字数为： 6586 字
# 《接手男友》的字数为： 6110 字
# 《在亲子综艺里我嘎嘎乱杀》的字数为： 6116 字
# 《难遇》的字数为： 5964 字
# 《闺蜜的好友验证》的字数为： 6067 字
# 《日理万机的首辅》的字数为： 6783 字
# 《等价交换》的字数为： 6594 字
# 《一句话，让我被惦记八年》的字数为： 5857 字
# 《18岁的他喜欢我》的字数为： 5435 字
# 《兔子的反击》的字数为： 6234 字
# 《真假千金爆火娱乐圈》的字数为： 6130 字
# 《直播劈腿，我爆火》的字数为： 6060 字
# 《别惹我，我会发疯》的字数为： 6344 字
# 《陆哥哥的小青梅》的字数为： 6036 字
# 《饲养魅魔》的字数为： 5829 字
# 《遇山遇你》的字数为： 15466 字
# 《我让欺我之人永堕地狱》的字数为： 5876 字
# 《折翅翱翔》的字数为： 6026 字
# 《男朋友他有女友了》的字数为： 6645 字
# 《我和影帝前男友一起上恋综》的字数为： 5813 字
# 《小鬼弟弟说爱我》的字数为： 5868 字
# 《大小姐驾到》的字数为： 5959 字
# 《娃综之人鱼的孩子》的字数为： 6455 字
# 《杀人游乐场》的字数为： 6699 字
# 《错换人生》的字数为： 6344 字
# 《绿茶请退散》的字数为： 6770 字
# 《强撩天帝后，我摆烂了》的字数为： 6089 字
# 《老爸让我低调》的字数为： 5952 字
# 《我在娱乐圈躺平摆烂后却大红大紫》的字数为： 6106 字
# 《我的大佬哥哥们》的字数为： 6809 字
# 《恶毒女配摆烂了》的字数为： 5784 字
# 《婚礼上的特殊嘉宾》的字数为： 5943 字
# 《和校霸闪婚后我暴富了》的字数为： 5874 字
# 《糟心的公婆》的字数为： 6694 字
# 《过敏爆火》的字数为： 5862 字
# 《第一名女孩》的字数为： 5951 字
# 《反击熊孩子》的字数为： 6633 字
# 《站在暗处的少年》的字数为： 6181 字
# 《影帝的自我攻略》的字数为： 6194 字
# 《打脸极品同学》的字数为： 6575 字
# 《竹马黑化后》的字数为： 6102 字
# 《公司破产后，我随老板继承家业》的字数为： 6107 字
# 《男友让我和别人约会》的字数为： 6164 字
# 《与你狂恋》的字数为： 6289 字
# 《智斗恶婆婆和妈宝男》的字数为： 6280 字
# 《本丧尸是朵娇花》的字数为： 6129 字
# 《错拿恶女剧本》的字数为： 6162 字
# 《被迫暂停的时间里，来自他的悄悄鼓励》的字数为： 5852 字
# 《逐红莲》的字数为： 6447 字
# 《老家历险记》的字数为： 6050 字
# 《和三个霸总上恋综后我爆红了》的字数为： 6196 字
# 《带鬼上玄综后翻红了》的字数为： 5790 字
# 《老公阳了之后》的字数为： 6581 字
# 《恶毒女配觉醒后》的字数为： 6286 字
# 《我因看鬼片无痛当妈》的字数为： 6164 字
# 《宿主他想攻略我》的字数为： 5824 字
# 《拿钱给自己砸了个男朋友》的字数为： 5596 字
# 《抢了我弟未婚妻》的字数为： 6475 字
# 《低段位绿茶》的字数为： 6583 字
# 《带影帝男友回家过年》的字数为： 6106 字
# 《奇葩一家人》的字数为： 6768 字
# 《都别争了我才是主角》的字数为： 5672 字
# 《新年愿望是汪汪叫》的字数为： 5894 字
# 《当我女扮男装后》的字数为： 5863 字
# 《除夕夜远离极品家人》的字数为： 6861 字
# 《怨种老板暗恋我》的字数为： 5759 字
# 《德古拉误吸狼人血》的字数为： 5989 字
# 《森林狼》的字数为： 5640 字
# 《救赎我的病娇竹马》的字数为： 5705 字
# 《救了个傻书生后我翻车了》的字数为： 6538 字
# 《医生的复仇》的字数为： 6283 字
# 《我的学霸男友》的字数为： 5870 字
# 《小姑最会作》的字数为： 6069 字
# 《迟来的婚纱照》的字数为： 6587 字
# 《全班团建在古代》的字数为： 6024 字
# 《坠落之日》的字数为： 6090 字
# 《她是心头好》的字数为： 5989 字
# 《皇后今天被套路了吗》的字数为： 6092 字
# 《我妹妹是小三的女儿》的字数为： 6536 字
# 《祝祁》的字数为： 6353 字
# 《校霸也爱绿茶小作精》的字数为： 6315 字
# 《我靠怼人时薪破亿》的字数为： 6245 字
# 《不如不相识》的字数为： 6091 字
# 《宫宴献妻记》的字数为： 6302 字
# 《上了亲子真人秀后我火了》的字数为： 5999 字
# ...
# 《你为了钱做过做疯狂的事是什么？》的字数为： 13051 字
# 《医护人员，信命吗？》的字数为： 4930 字
# 《君生我未生我生君已老是一种怎样的体验？》的字数为： 15629 字
# 《在古代皇帝会抱着自己的妃子入睡吗？还是侍寝完各睡各的？》的字数为： 3942 字
# 《如何判断这个人有钱没钱》的字数为： 15742 字
# 《有什么可以让我笑出鸡叫的小说？》的字数为： 15561 字
# 《有什么很甜的小甜文？》的字数为： 15883 字
# 《有没有什么好看的丧尸文推荐》的字数为： 15598 字
# 《有没有末日躺平不圣母的丧尸文？》的字数为： 15547 字
# 《重症监护室（ICU）平均8000元一天的收费是否合理，它一般包括哪些费用在内？》的字数为： 8299 字
# 《高考结束那晚你做了什么？》的字数为： 15587 字
# 《为什么不要去考验人性？》的字数为： 15066 字
# 《人在死亡前的真实感受是怎么样的？》的字数为： 9372 字
# 《什么才是真正的恶？》的字数为： 10231 字
# 《你们相信命吗？》的字数为： 4930 字
# 《和女生聊天，哪些话题百试不爽？》的字数为： 5226 字
# 《如何看待甘肃白银连环杀人案嫌疑人落网？》的字数为： 15325 字
# 《有没有听完脊背发凉的鬼故事？》的字数为： 15533 字
# 《生活中有哪些思极致恐的故事？》的字数为： 13920 字
# 《请问有哪些好看的规则类怪谈？》的字数为： 13215 字
# 《高考的前一晚你在干什么？》的字数为： 15509 字
# 《什么事情是你当了医生之后才知道的？》的字数为： 10305 字
# 《你们说……咱们中国的神仙和西方的神打起来，谁更牛逼？》的字数为： 8410 字
# 《你写过哪些脑洞大开的武侠故事？》的字数为： 15541 字
# 《你看过最爽的爽文有多爽？》的字数为： 15662 字
# 《你看过最爽的爽文有多爽？》的字数为： 15521 字
# 《你认为最可怕或最恐怖的事是什么？》的字数为： 13382 字
# 《你都见过什么样的医学盲？》的字数为： 9376 字
# 《各位医生是喜欢有医学知识储备的病人，还是喜欢没有医学知识储备的病人？》的字数为： 8676 字
# 《君生我未生我生君已老是一种怎样的体验？》的字数为： 15629 字
# 《左宗棠到底牛不牛逼？》的字数为： 6084 字
# 《年轻人如何在独居时有效地保持自律？》的字数为： 5738 字
# 《战争胜利后，潜伏在敌后的谍报人员结局怎样？》的字数为： 10104 字
# 《有什么特别大快人心的报复经历（尤其是对绿茶婊）？》的字数为： 11754 字
# 《校园暴力给人带来的影响有多大？》的字数为： 15552 字
# 《炫富真的很爽吗？》的字数为： 15407 字
# 《中国当初以什么名义买的瓦良格号？》的字数为： 9943 字
# 《你听过的最恐怖惊悚的故事是什么？》的字数为： 15677 字
# 《印度真的有部分中国新闻上说的那么落后吗？》的字数为： 5891 字
# 《印度真的有部分中国新闻上说的那么落后吗？》的字数为： 5891 字
# 《女孩子被富养是怎样的感受？》的字数为： 15453 字
# 《有一个闷骚的男朋友是怎样的一种体验？ ？》的字数为： 15691 字
# 《有个很主动的女朋友是一个什么样的体验？》的字数为： 10129 字
# 《有钱人都是怎么低调的？》的字数为： 13812 字
# 《要怎么走出堕落、低迷、拖延的状态？》的字数为： 7899 字
# 《“物理学的大厦已经落成，上面只有两朵乌云”是什么意思？》的字数为： 8823 字
# 《最好的复仇是怎样的？》的字数为： 12869 字
# 《有什么暖心的鬼故事？》的字数为： 15413 字
# 《有没有人看过男女主相互救赎的小说？》的字数为： 15615 字
# 《欺凌者敢欺凌有钱人吗》的字数为： 15604 字
# 《穷人突然有钱后能挥霍到什么程度？》的字数为： 15616 字
# 《老公不能理解你在婆家的委屈怎么办？》的字数为： 15429 字
# 《胖一点的男生应该怎么穿搭？》的字数为： 5245 字
# 《你最漂亮的一次“打脸”是怎样的？》的字数为： 15751 字
# 《太白金星：我现在慌得一匹》的字数为： 9876 字
# 《如果七天之后爆发丧尸，你该怎么办？》的字数为： 15652 字
# 《如果中国爆发丧尸怎么办？》的字数为： 14030 字
# 《家里从没有钱到有钱是一种什么样的体验？》的字数为： 15621 字
# 《有哪些虐男主的追妻火葬场小说？》的字数为： 15616 字
# 《有没有那种能把我虐哭的短篇小虐文，要那种虐的肝疼的？》的字数为： 15607 字
# 《管家女儿冒充我》的字数为： 15756 字
# 《黯淡水晶球》的字数为： 15486 字
# 《为什么想自律却自律不起来？》的字数为： 5160 字
# 《人类的科技，是否已经接近极限？》的字数为： 10566 字
# 《你最爽的一次炫富经历是什么？》的字数为： 12634 字
# 《劳荣枝具体做了一些什么事情？》的字数为： 15560 字
# 《如果哪吒，孙悟空加入复仇者联盟实力会处于什么水平》的字数为： 15235 字
# 《如果我国爆发丧尸病毒，会很快沦陷吗》的字数为： 15582 字
# 《学生提前用完生活费是种怎样的体验？》的字数为： 15585 字
# 《有没有末日丧尸的文？囤物资躺平的那种？》的字数为： 14497 字
# 《来讲一个你作死的小故事》的字数为： 15510 字
# 《灵犬护主》的字数为： 15446 字
# 《资本家已经拥有大量资产了，为什么还要剥削无产阶级？》的字数为： 15389 字
# 《东北野战军到底有多强》的字数为： 12202 字
# 《中国最凶残的杀人案是哪一件？》的字数为： 15421 字
# 《为了结果正义，是否可以放弃程序正义？》的字数为： 15296 字
# 《作为一个无经验的小白，怎么备考事业单位》的字数为： 8876 字
# 《你听过最恐怖的故事是什么？》的字数为： 15682 字
# 《你知道丧尸明天爆发了，还有短短五六个小时你会怎么做？》的字数为： 15409 字
# 《做渣女开心吗？》的字数为： 15396 字
# 《如果你是宠文里的女配怎么办？》的字数为： 15397 字
# 《如果把主角设定为门派卷王，这个故事可以如何展开？》的字数为： 15588 字
# 《最近生活过的苦，想看一些甜甜的小故事，有没有好心人可以推荐一下呢？》的字数为： 15795 字
# 《有什么让人脊背发凉的灵异经历？》的字数为： 15490 字
# 《有没有人装逼正好撞到你擅长的领域上的？》的字数为： 11284 字
# 《长期睡眠质量不好，怎么调理？》的字数为： 6058 字
# 《如果你是虐文里的女主你会怎么办？》的字数为： 14209 字
# 《有什么真的很恐怖或细思恐极的鬼故事？》的字数为： 8537 字
# 《末世重生：我带着全家求生》的字数为： 15465 字
# 《上海焰火》的字数为： 14684 字
# 《为什么杜特尔特对毒贩的手段那么残忍，没有毒贩暗杀他？》的字数为： 7785 字
# 《你最漂亮的一次“打脸”是怎样的？》的字数为： 15607 字
# 《古代的丫鬟每天都做什么？》的字数为： 15417 字
# 《国内有什么轰动全国的悬案啊？》的字数为： 10406 字
# 《在容错率几乎为零的行业工作是什么样的感受？》的字数为： 10265 字
# 《怎么才能心无旁骛地学习？》的字数为： 5790 字
# 《有什么令人脊背发凉的科幻故事吗？》的字数为： 12197 字
# 《有什么偏执病娇系男主的小说推荐吗？》的字数为： 15859 字
# 《有哪些很荒诞邪性的游戏？》的字数为： 15644 字
# 《有钱人都是怎么低调的？》的字数为： 14974 字
# 《男生会忘了初恋吗？》的字数为： 12575 字
# 《缅甸北部有多黑暗？》的字数为： 15580 字
# 《你知道丧尸明天爆发了，还有短短五六个小时你会怎么做？》的字数为： 15409 字
# 《有什么特别大快人心的报复经历（尤其是对绿茶婊）？》的字数为： 11754 字
# 《有没有一些细思极恐的鬼故事？》的字数为： 12485 字
# 《有没有那种女主故意勾引高岭之花男主，最后男主栽女主手里的小说？》的字数为： 15764 字
# 《有记录以来亲手杀人最多的人是谁？》的字数为： 12239 字
# 《美国这个国家的凝聚力如何？》的字数为： 6617 字
# 《说一说你最爽的经历》的字数为： 14679 字
# 《你有哪些力挽狂澜的神操作？》的字数为： 15429 字
# 《你见过的最低调的有钱人是什么样子的？》的字数为： 14974 字
# 《你见过的最漂亮的打脸是怎样的？》的字数为： 14856 字
# 《如果用你的专业来写爽文，会是什么剧情？》的字数为： 15577 字
# 《有什么甜甜的小故事？》的字数为： 15679 字
# 《有文化可以有多可怕？》的字数为： 15729 字
# 《有没有可爱点的鬼故事啊？》的字数为： 15507 字
# 《有没有可爱点的鬼故事啊？》的字数为： 14415 字
# 《男生也会嫌弃女生家里穷吗》的字数为： 14874 字
# 《能不能给我讲一段很甜很甜的爱情故事》的字数为： 15811 字
# 《脑洞：如果丧尸爆发了，你应该怎样生活？》的字数为： 15571 字
# 《一个人的城府能深到什么程度》的字数为： 15575 字
# 《你在游戏里作过哪些恶？》的字数为： 15652 字
# 《你所做过的最坏的事是什么？》的字数为： 15921 字
# 《你有哪些自以为聪明，但其实愚蠢透顶的操作？》的字数为： 12547 字
# 《你见过最恐怖的事是什么？》的字数为： 15511 字
# 《异性合租会不会日久生情？》的字数为： 13643 字
# 《有什么时候你觉得这个世界是假的》的字数为： 12637 字
# 《有哪些完结爽文？》的字数为： 13379 字
# 《什么时刻让你醒悟你被渣女玩弄了？》的字数为： 11869 字
# 《你见过的最漂亮的打脸是怎样的？》的字数为： 14289 字
# 《你读过最爽的爽文有哪些？》的字数为： 15565 字
# 《你遇到过最惊悚的事情是什么？》的字数为： 15685 字
# 《她的虚荣心》的字数为： 13294 字
# 《成为高考状元是一种怎样的体验？》的字数为： 15633 字
# 《支教回忆录》的字数为： 12142 字
# 《有哪一个瞬间让你对女朋友彻底失望》的字数为： 15371 字
# 《你能想到最弱的超能力是什么？》的字数为： 15588 字
# 《历史上有哪些著名的外交事件？》的字数为： 13220 字
# 《如何以“那日我的夫君带回一位姑娘”开头，写一篇古言文？》的字数为： 14052 字
# 《室友哪些不该看的东西被你无意之间看到了？》的字数为： 14544 字
# 《室友哪些不该看的东西被你无意之间看到了？》的字数为： 14544 字
# 《家里面有哪个亲戚令你感到恶心？》的字数为： 15622 字
# 《我把领导打了》的字数为： 12511 字
# 《有什么剧情反转的故事？》的字数为： 15851 字
# 《有末日躺平的丧尸小说吗》的字数为： 15659 字
# 《男生对女朋友的占有欲都很强吗？》的字数为： 15860 字
# 《结阴亲》的字数为： 12790 字
# 《锢神》的字数为： 10963 字
# 《你迄今为止知道的最惊悚的故事是什么？》的字数为： 12471 字
# 《有什么剧情反转的故事？》的字数为： 15851 字
# 《你见过哪些父母惊艳到你的教育方式？》的字数为： 12020 字
# 《你见过哪些蠢到家的罪犯？》的字数为： 12385 字
# 《有没有什么巨爽无比的爽文？》的字数为： 15789 字
# 《特别会聊天的人的思维方式是什么样子的？》的字数为： 4764 字
# 《高考时你的抽屉里突然凭空出现了一份正确无误的高考答案，你该怎么办？》的字数为： 12115 字
# 《为什么氢弹五常都搞出这么久了，其它国家还制造不了？》的字数为： 7523 字
# 《你在学校做过哪些使你一战成名、全校皆知的事？》的字数为： 15566 字
# 《你见过的最漂亮的打脸是怎样的？》的字数为： 15720 字
# 《如何才能有效的缩小贫富差距？》的字数为： 7347 字
# 《如果你被病娇囚禁了，会怎么办》的字数为： 15859 字
# 《有哪些细思恐极的故事？》的字数为： 10680 字
# 《有那种高岭之花男主，被女主勾引拉下神坛的文吗？》的字数为： 15437 字
# 《有钱人都是怎么低调的？》的字数为： 14974 字
# 《你听过最毁三观的故事是哪个？》的字数为： 9641 字
# 《你最漂亮的一次“打脸”是怎样的？》的字数为： 12543 字
# 《如何以“即使知道眼前这位落魄的少年将来会权倾天下，我也要向他退婚”为开头写一个故事？》的字数为： 15170 字
# 《如果中国和印度开始战争，要多长时间击败印度？》的字数为： 11094 字
# 《高三有哪些相见恨晚的刷题技巧？》的字数为： 6513 字
# 《你会选择原谅伤害过你的人吗？》的字数为： 15862 字
# 《你听过最恐怖故事是什么？》的字数为： 13516 字
# 《如果给你六千万，代价是余生都看不见月亮，你会答应吗？》的字数为： 61030 字
# 《如果虐文女主突然醒悟，会有什么故事？》的字数为： 15850 字
# 《如果让你重新开始学计算机，你的学习路线会是怎么选择》的字数为： 7828 字
# 《怎样捧杀掉一个人？》的字数为： 15726 字
# 《有哪些好看的言情小说推荐》的字数为： 15460 字
# 《有哪些学生毁掉老师的案例、经历？》的字数为： 11825 字
# 《有哪些经过精心策划，几乎天衣无缝甚至令人匪夷所思的谋杀案？》的字数为： 8371 字
# 《有哪些让人深思的故事？》的字数为： 13216 字
# 《爱的卑微是种什么样的体验？》的字数为： 12761 字
# 《（被）光速打脸是种怎样的体验？》的字数为： 15739 字
# 《你是什么时候发现自己家还挺有钱的？》的字数为： 11748 字
# 《你见过哪些逆天的造假手段？》的字数为： 15737 字
# 《北伐战争中为什么国民政府敢于用区区十万人攻击三大军阀八十多万人？》的字数为： 15338 字
# 《有些人可以恶心到什么程度？》的字数为： 10876 字
# 《有没有一瞬间，想变坏？》的字数为： 15751 字
# 《有什么让人听了背脊发凉的恐怖故事？》的字数为： 15575 字
# 《有哪些是你进了体制内才知道的事情》的字数为： 10488 字
# 《说谎被打脸是种怎样的体验？》的字数为： 15257 字
# 《你最漂亮的一次“打脸”是怎样的？》的字数为： 15720 字
# 《你有哪些因无意间的举动立了大功的经历或故事？》的字数为： 12196 字
# 《你的帅哥男朋友是在哪里找的？》的字数为： 14976 字
# 《你见过最毁三观的事情是什么呢？》的字数为： 13364 字
# 《假如所有人同时失去了视觉，你突然恢复视力后却发现到处涂满了“不要告诉他们你看得见”，你应该怎么做》的字数为： 10477 字
# 《怎么准备公务员面试并且拿到高分？》的字数为： 6777 字
# 《有哪些英年早逝的将帅如果活久了可能晚节不保？》的字数为： 10813 字
# 《有哪些邪性荒诞的民间故事？》的字数为： 15411 字
# 《有没有治愈的小甜文？》的字数为： 15635 字
# 《脑洞：如果丧尸爆发了，你应该怎样生活？》的字数为： 15571 字
# 《脑洞：如果丧尸爆发了，你应该怎样生活？》的字数为： 15571 字
# 《中西方的神仙都住在天上，他们互相认识吗？》的字数为： 10423 字
# 《人性的阴暗面到底有多可怕？》的字数为： 10347 字
# 《你们见过的最聪明的女生有多聪明？》的字数为： 14879 字
# 《你曾经有过什么不为人知的变态想法？》的字数为： 12581 字
# 《假如所有人同时失去了视觉，你突然恢复视力后却发现到处涂满了“不要告诉他们你看得见”，你应该怎么做》的字数为： 15547 字
# 《公务员面试有哪些话已经成了套话，考官一听就烦的？》的字数为： 6147 字
# 《社交恐惧应该怎么克服？》的字数为： 5041 字
# 《你什么时候觉得你男朋友很恶心？》的字数为： 13908 字
# 《你经历过哪些“见光死”的网恋？》的字数为： 15582 字
# 《你见过最有魄力的人是谁？》的字数为： 9547 字
# 《在外伤中，绝对致命伤都有哪些？》的字数为： 9496 字
# 《害怕自己得狂犬病怎么办？》的字数为： 6525 字
# 《我被一个我不喜欢的大学录取了，选了个不是很喜欢也不讨厌的专业，我不知道干嘛，也不知道未来在哪儿。？》的字数为： 4690 字
# 《有没有听了特别爽的真实复仇故事？》的字数为： 14679 字
# 《有没有治愈的小甜文？》的字数为： 15830 字
# 《特别有钱是一种什么样的体验？》的字数为： 15463 字
# 《请问近几年有哪些案件是被舆论影响了判决的呀？》的字数为： 13256 字
# 《你看过最爽的爽文有多爽？》的字数为： 14879 字
# 《你见过的最阴暗的事是什么？》的字数为： 15439 字
# 《湿气太重该如何调理或如何锻炼？》的字数为： 5466 字
# 《为什么不要去考验人性？》的字数为： 15066 字
# 《你们相信命吗？》的字数为： 4930 字
# 《你们身边有舔狗舔到最后应有尽有的例子吗？》的字数为： 15911 字
# 《你听过或写过最可爱的鬼故事是什么？》的字数为： 15507 字
# 《如何看待徐增平被购买“瓦良格”号航母团队的核心成员联名向中央举报其欺世盗名》的字数为： 11842 字
# 《有什么真实的恐怖照片吗？》的字数为： 12690 字
# 《如何以【当被校园恶霸逼到墙角，我给网恋对象发了最后一条消息，结果恶霸的手机响了】为开头写一篇故事》的字数为： 15720 字
# 《如果碰到鬼的话，正面硬刚会怎样？》的字数为： 12501 字
# 《有没有什么特别恐怖的鬼故事？》的字数为： 13069 字
# 《高三真的能逆袭吗，文科？》的字数为： 13691 字
# 《你看过最爽的爽文有多爽？》的字数为： 15441 字
# 《如果你是替身文的替身，你会怎么做？》的字数为： 15477 字
# 《有一个病娇男友(老公)是一种怎样的体验》的字数为： 15860 字
# 《有什么特别大快人心的报复经历（尤其是对绿茶婊）？》的字数为： 11754 字
# 《网吧少年的爱情——如林之叶》的字数为： 10560 字
# 《你知道有哪些人贩子遭到比较严重的报复或报应的真实事件？》的字数为： 11663 字
# 《你见过的最阴暗的事是什么？》的字数为： 15498 字
# 《在高中你都做过什么骚操作？》的字数为： 15714 字
# 《有哪些平平淡淡却虐到骨子里的虐文？》的字数为： 15850 字
# 《有哪些恶有恶报的故事？》的字数为： 14589 字
# 《有没有重男轻女的反击案例》的字数为： 15494 字
# 《清北学渣请赐教》的字数为： 15727 字
# 《狠人是什么样的人？》的字数为： 7784 字
# 《男生失去了很好的女生会后悔吗？》的字数为： 15384 字
# 《美国军事实力到底有多强》的字数为： 7235 字
# 《装逼却被打脸是一种什么样的体验？》的字数为： 15703 字
# 《近亲结婚一定会生不健康的孩子吗？》的字数为： 7965 字
# 《世界上真的存在完美犯罪吗？》的字数为： 11743 字
# 《你碰到过最恶心的亲戚是怎么样的，作出过哪些举动？》的字数为： 12389 字
# 《如果虐文女主突然醒悟，会有什么故事？》的字数为： 15578 字
# 《最理性的暗恋是什么样子？》的字数为： 14498 字
# 《现阶段比较吃香的公务员岗位有哪些？》的字数为： 10330 字
# 《近亲结婚一定会生不健康的孩子吗？》的字数为： 7965 字
# 《医学里的唯二两个百分之百，都是悲剧。一个是百草枯中毒。另一个是什么？》的字数为： 6523 字
# 《异性合租会不会产生日久生情？》的字数为： 12691 字
# 《我是学霸的对照组》的字数为： 14215 字
# 《有没有什么甜文宠文可以推荐的，谢谢？》的字数为： 13505 字
# 《有没有搞笑沙雕的小甜文？》的字数为： 10985 字
# 《有没有看着很上头的小说推荐？》的字数为： 15605 字
# 《狂犬病真的能潜伏 23 年吗？》的字数为： 9015 字
# 《现实中会有学霸故意考倒数吗？》的字数为： 15607 字
# 《什么是顶级的思维？》的字数为： 6297 字
# 《你看过最爽的爽文有多爽？》的字数为： 15607 字
# 《如何培养自己深度思考的习惯？》的字数为： 6729 字
# 《有没有甜到爆的小说？》的字数为： 15596 字
# 《有没有那种追妻火葬场还追不回来，女主跟别人在一起收获幸福的文》的字数为： 15720 字
# 《绑架李嘉诚儿子的世纪大盗，竟想“无罪释放”》的字数为： 5518 字
# 《一个女生和一个男生做同桌会互相喜欢吗？》的字数为： 15850 字
# 《你穿越成小说中的恶毒女配怎么办？》的字数为： 15908 字
# 《国考税务局面试如何准备？》的字数为： 4989 字
# 《如何以“我是太子妃但太子不爱我”为设定，写一个故事？》的字数为： 15557 字
# 《如何用一张照片表达“恐怖”？》的字数为： 12130 字
# 《有一个占有欲特别强的男朋友是什么体验？》的字数为： 15893 字
# 《有哪些甜甜的重生小说值得推荐？》的字数为： 15606 字
# 《爸爸可以有多疼爱女儿？》的字数为： 13432 字
# 《真正的有钱人是什么样的？》的字数为： 15700 字
# 《谁能分析一下鲁荣渔2682号惨案》的字数为： 15267 字
# 《闪光少女》的字数为： 15752 字
# 《韩信到底有多牛？》的字数为： 10928 字
# 《为什么有的人城府深的吓人？》的字数为： 8352 字
# 《人性阴暗能阴暗到什么程度？》的字数为： 15423 字
# 《人类历史上有哪些疯狂的计划？》的字数为： 9886 字
# 《塑料巴掌爱情》的字数为： 14902 字
# 《如何以“我是太子妃但太子不爱我”为设定，写一个故事？》的字数为： 12179 字
# 《如何以“我穿越成了恶毒女配”为题写一篇小说？》的字数为： 15437 字
# 《学渣人设》的字数为： 15605 字
# 《有一个很漂亮的妹妹是种怎样的体验？》的字数为： 15216 字
# 《有哪些让你觉得“这是我尊贵的盐选会员该看的文”？》的字数为： 15846 字
# 《有哪些让你觉得“这是我尊贵的盐选会员该看的文”？》的字数为： 15616 字
# 《有没有女主很妖艳也很张扬大胆的小说？》的字数为： 15512 字
# 《有没有看着很上头的小说推荐？》的字数为： 15605 字
# 《申论大作文背素材套用管用么？》的字数为： 12039 字
# 《索罗斯做空中国要花多少钱？》的字数为： 12557 字
# 《网恋对象让我考北大》的字数为： 13962 字
# 《能讲下你最痛快的一次经历吗》的字数为： 15596 字
# 《世界上真的存在完美犯罪吗？》的字数为： 15727 字
# 《你的亲戚能坏到什么地步？》的字数为： 14361 字
# 《有哪些事让你看到人性的黑暗？》的字数为： 9710 字
# 《有哪些令人浑身发抖的故事？》的字数为： 11368 字
# 《为什么人心这么复杂，这么险恶》的字数为： 13333 字
# 《为何我始终成为不了顶尖？》的字数为： 4837 字
# 《从哪些小细节可以看出一个人的健康？》的字数为： 8776 字
# 《你有哪些因无意间的举动立了大功的经历或故事？》的字数为： 15373 字
# 《你看过最爽的爽文有多爽？》的字数为： 15766 字
# 《那些想找富二代的女生后来怎么样了？》的字数为： 11925 字
# 《关于我是学神却被脏作弊这件事》的字数为： 15728 字
# 《哪个瞬间你突然觉得读书真有用？》的字数为： 15569 字
# 《如果你是大奸臣的女儿，会怎么样？》的字数为： 15744 字
# 《如果你是大奸臣的女儿，会怎么样？》的字数为： 15744 字
# 《有什么大快人心的复仇故事？》的字数为： 15662 字
# 《中国第一例“非典”病人：广东佛山的一位厨师》的字数为： 15194 字
# 《如何客观地评价《原神》？》的字数为： 6384 字
# 《您遭遇过最耻辱的事是什么？》的字数为： 12614 字
# 《有没有什么巨爽无比的爽文？》的字数为： 15398 字
# 《有没有什么恐怖的故事？》的字数为： 10460 字
# 《男生的手机真的没人能笑着看完吗？》的字数为： 15680 字
# 《人类历史上有哪些疯狂的计划？》的字数为： 8725 字
# 《你看过最爽的爽文有多爽？》的字数为： 15441 字
# 《你看过最爽的爽文有多爽？》的字数为： 15441 字
# 《在哪一瞬间你突然对男朋友死心了？》的字数为： 15469 字
# 《家里面有哪个亲戚令你感到恶心？》的字数为： 13653 字
# 《恐怖是什么感觉？》的字数为： 15621 字
# 《有什么又甜又虐的短篇故事？》的字数为： 15573 字
# 《有什么大快人心的复仇故事？》的字数为： 15698 字
# 《有哪些令人拍案叫绝的推理桥段？》的字数为： 6688 字
# 《有没有又甜还短的睡前小甜文？》的字数为： 15811 字
# 《有没有爆笑沙雕文推荐？》的字数为： 13503 字
# 《你经历过最危险的事是什么？》的字数为： 15466 字
# 《假如后宫嫔妃不想争宠也不想侍寝，她们可以拒绝吗？》的字数为： 15621 字
# 《公务员考公安局怎么样？》的字数为： 9765 字
# 《听过最虐心的一句话是什么？》的字数为： 15666 字
# 《如何以“姐姐我玩腻了”为开头写一个故事？》的字数为： 15906 字
# 《如何以“他红着眼说：你给我服个软”为开头，写一个故事？》的字数为： 15688 字
# 《如何以“我得知自己是个恶毒女配……”为开头写一篇小说？》的字数为： 15916 字
# 《如何以“我把男主养废了”为开头写一个故事？》的字数为： 14359 字
# 《如何以“算了，我来嫁。”为开头写一个故事？》的字数为： 15647 字
# 《如何以“结婚前一天，我有了读心术”为开头写一个故事？》的字数为： 15744 字
# 《曹操穿成武大郎》的字数为： 15510 字
# 《有什么超甜的小甜文可以看吗？》的字数为： 15430 字
# 《有什么超甜的小甜文可以看吗？》的字数为： 15781 字
# 《有哪个瞬间让你觉得这个世界出bug了？》的字数为： 11075 字
# 《有哪些女主很乖巧的小说？》的字数为： 15532 字
# 《有哪些曾经看到深夜哭湿枕头的虐文小说？》的字数为： 14130 字
# 《有没有那种能把我虐哭的短篇小虐文，要那种虐的肝疼的？》的字数为： 15713 字
# 《给子女名字没起好会对子女造成多大的伤害？》的字数为： 14744 字
# 《为什么美队会认为冬兵是最好的朋友，而对于钢铁侠冷漠？》的字数为： 6672 字
# 《人性到底能有多阴暗？》的字数为： 11926 字
# 《你看过最爽的爽文有多爽？》的字数为： 13812 字
# 《你都有着怎样的童年阴影？》的字数为： 15172 字
# 《名媛的谎言》的字数为： 12979 字
# 《和女生合租是怎样一种体验？》的字数为： 11799 字
# 《坏手机》的字数为： 8366 字
# 《处于暧昧期的两个人，交心的尺度在哪？了解彼此到什么层次最合适？》的字数为： 4073 字
# 《如何以“回驸马，公主死的很安静。”为开头写一个故事？》的字数为： 15487 字
# 《如何以“你脸红什么”为开头写个故事？》的字数为： 15644 字
# 《如何以【当被校园恶霸逼到墙角，我给网恋对象发了最后一条消息，结果恶霸的手机响了】为开头写一篇故事》的字数为： 15895 字
# 《婚礼惊悚夜》的字数为： 11027 字
# 《屏幕中的女神》的字数为： 8164 字
# 《我与继妹：高手过招》的字数为： 15300 字
# 《招魂游戏：最后的老友会》的字数为： 15937 字
# 《有哪些渠道可以获取一般人不知道的知识和信息？》的字数为： 4088 字
# 《有没有什么巨爽无比的爽文？》的字数为： 12632 字
# 《武侠小说中有哪些细思恐极的细节？》的字数为： 6688 字
# 《活埋之后：你只有 30 分钟》的字数为： 14857 字
# 《炫富真的很爽吗？》的字数为： 15640 字
# 《番外：回家》的字数为： 4099 字
# 《能讲下你最痛快的一次经历吗》的字数为： 13448 字
# 《致命链接》的字数为： 12287 字
# 《莫道不消魂》的字数为： 15186 字
# 《你听过最吓人的故事是什么？》的字数为： 10452 字
# 《你穿到一个修仙文变成了一个试图勾引男主的恶毒女配，怎么办？》的字数为： 15385 字
# 《你见过哪些把无耻当有趣的行为？》的字数为： 10415 字
# 《如何提高逻辑思维的能力？》的字数为： 4638 字
# 《如何装逼装得别人一愣一愣的？》的字数为： 15579 字
# 《断指》的字数为： 15693 字
# 《有文化可以有多可怕？》的字数为： 15562 字
# 《有没有彪悍的女主重生后反杀的超A文？》的字数为： 15562 字
# 《你有没有哪些手撕绿茶的超爽经历》的字数为： 10754 字
# 《世界上真的有怪物吗？》的字数为： 15677 字
# 《你看过最爽的爽文有多爽？》的字数为： 15565 字
# 《有哪个瞬间让你觉得这个世界出bug了？》的字数为： 15460 字
# 《有哪些好看的言情小说推荐》的字数为： 15232 字
# 《有没有能把你甜哭的短篇小说》的字数为： 15960 字
# 《苟住！裸辞遇丧尸》的字数为： 15483 字
# 《什么叫国运？》的字数为： 10783 字
# 《你们见过的最聪明的女生有多聪明？》的字数为： 14879 字
# 《你见过的最奇葩的人是怎样的？》的字数为： 14263 字
# 《哪一个瞬间让你下定决心分手了？》的字数为： 15297 字
# 《如果光速没有上限，世界会怎么样？》的字数为： 5853 字
# 《律师会为杀人犯辩护吗？》的字数为： 15726 字
# 《有哪个瞬间让你觉得这个世界出bug了？》的字数为： 15678 字
# 《能讲一下你最爽的经历吗？》的字数为： 15581 字
# 《隐秘的副业》的字数为： 10242 字
# 《一个人智商高了有多可怕？》的字数为： 15581 字
# 《你有哪些被骗的经历？》的字数为： 9466 字
# 《入戏太深是种怎样的体验》的字数为： 15048 字
# 《在酒吧喊一次“这轮酒我请”大概得花多少钱？》的字数为： 10776 字
# 《如果穿越成为虐文的女配该怎么办？》的字数为： 15567 字
# 《有什么女主不作不婊不憨批，不玛丽苏的小说吗？》的字数为： 15549 字
# 《有哪些令人浑身发抖的故事？》的字数为： 15439 字
# 《有哪些听起来很疯狂，但却在历史上真实发生过的罕见事实？》的字数为： 10379 字
# 《有哪些听起来很疯狂，但却在历史上真实发生过的罕见事实？》的字数为： 10379 字
# 《有没有又甜还短的甜宠文推荐？》的字数为： 15802 字
# 《有没有又甜还短的甜宠文推荐？》的字数为： 15802 字
# 《一个人智商高了有多可怕？》的字数为： 15727 字
# 《人类历史上有哪些疯狂的计划？》的字数为： 9886 字
# 《人类知道世界的终极真理后会疯掉吗》的字数为： 12371 字
# 《你看过最感动人最震撼的微小说是哪篇？》的字数为： 5292 字
# 《你经历过哪些细思恐极的事？》的字数为： 15572 字
# 《你能想到（编出）的最惊世骇俗的爽文有多爽？》的字数为： 15562 字
# 《医生遇到过哪些“这居然都能活下来”的病人？》的字数为： 9043 字
# 《如果神话传说都是真的，世界会变成什么样子？》的字数为： 8277 字
# 《姐弟恋是什么个啥感觉？》的字数为： 15635 字
# 《有那种高岭之花男主，被女主勾引拉下神坛的文吗？》的字数为： 15722 字
# 《有那种高岭之花男主，被女主勾引拉下神坛的文吗？》的字数为： 15642 字
# 《如果你是大奸臣的女儿，会怎么样？》的字数为： 12929 字
# 《当初希腊愿意让“瓦良格”到达中国的原因是什么？》的字数为： 12056 字
# 《有哪些值得推荐的逻辑学入门读物？》的字数为： 6335 字
# 《长大后，你发现什么样的人不能深交？》的字数为： 10345 字
# 《你见过哪些打脸的神操作？》的字数为： 15927 字
# 《碎玉》的字数为： 15506 字
# 《绿茶婊是怎么样的？》的字数为： 15649 字
# 《一个人可以绝望到什么程度？》的字数为： 15871 字
# 《你们见过最毁三观的事情是什么？》的字数为： 13292 字
# 《你们谈恋爱累吗？》的字数为： 15681 字
# 《你见过的心机最深的人做过什么样的事？》的字数为： 14879 字
# 《大学宿舍可以有多恶心？》的字数为： 15709 字
# 《女大学生去山村支教会有危险吗？》的字数为： 15778 字
# 《如何以“最近，我总觉得屋里多了一个人”为开头写一篇故事？》的字数为： 13867 字
# 《如何以“生了一窝狐狸的我踹翻床边憋笑的臭男人”为开头写个甜饼？》的字数为： 15268 字
# 《摧毁一个孩子有多简单？》的字数为： 15751 字
# 《新冠有可能异变成丧尸病毒么？》的字数为： 15422 字
# 《有什么可以让我笑出鸡叫的小说？》的字数为： 15561 字
# 《有没有甜到忍不住嘴角上扬的小说？》的字数为： 14732 字
# 《生活中有没有特别绿茶的女生？》的字数为： 11214 字
# 《真正的黑社会是什么样子的呢？》的字数为： 12910 字
# 《舍友做过最让你恶心的事是什么？》的字数为： 15893 字
# 《高考作弊或者作弊被抓是种怎样的体验？》的字数为： 13393 字
# 《2022 年高考报志愿哪些专业就业前景比较好？作为过来人，你有什么经验分享？》的字数为： 6503 字
# 《一个人智商高了有多可怕？》的字数为： 12061 字
# 《为什么有的科研人员要搞学术造假？》的字数为： 8231 字
# 《你亲自闻过的最难闻的气味是什么？》的字数为： 5801 字
# 《你们有没有什么内心深处的秘密？》的字数为： 15526 字
# 《你遇到过最惊悚的事情是什么？》的字数为： 13819 字
# 《历史上有哪些影响很大的军队哗变事件？产生的原因是什么，之后又是如何解决的？》的字数为： 9862 字
# 《同居一年以上分手是种怎样的体验？》的字数为： 11971 字
# 《和异性合租的室友发生的最尴尬的事儿是什么？》的字数为： 12517 字
# 《如何以“我做天妃200年了”为开头写个故事？》的字数为： 13272 字
# 《有没有甜到爆的小说？》的字数为： 15596 字
# 《生活中你们发现了哪个 bug，让你觉得世界不是真实的？》的字数为： 15725 字
# 《考教资怎么准备啊？》的字数为： 4634 字
# 《能讲下你最痛快的一次经历吗》的字数为： 15669 字
# 《为什么医生很怕遇见喝了百草枯的病人？》的字数为： 9375 字
# 《你们见过最逆天的女主设定是什么样的？》的字数为： 15850 字
# 《医学里的唯二两个百分之百，都是悲剧。一个是百草枯中毒。另一个是什么？》的字数为： 6523 字
# 《可以用“客厅给你留了灯，带别的女人回来别吵醒我，我八点醒，让她七点滚”这句话为开头写篇文吗？》的字数为： 15487 字
# 《如何以“算了，我来嫁。”为开头写一个故事？》的字数为： 15623 字
# 《如何以“长公主权倾朝野”为开头，写一篇故事？》的字数为： 15520 字
# 《如何以“为什么要喜欢上别人”为开头写一篇文？》的字数为： 15664 字
# 《如何以“他笑着对我说，皇后不能是你”为开头，写一个故事？》的字数为： 15425 字
# 《如何以『皇上不喜欢女人』为开头写一个故事？》的字数为： 15761 字
# 《如何用“我被迫嫁给父亲的仇敌摄政王”为开头写一篇小说？》的字数为： 15378 字
# 《有一个病娇哥哥是什么体验》的字数为： 15592 字
# 《有哪些你明知是假却希望是真的故事？》的字数为： 9610 字
# 《对于几乎已经确定必死的犯罪嫌疑人，律师有什么作用？》的字数为： 15731 字
# 《有没有什么校园甜文》的字数为： 15632 字
# 《有没有特别血腥恐怖 细思极恐的海龟汤推荐？》的字数为： 15947 字
# 《社恐碰到病娇会发生什么？》的字数为： 15571 字
# 《为什么不要去考验人性？》的字数为： 15066 字
# 《你相信有平行空间吗？》的字数为： 11065 字
# 《历史上有哪些最不要脸，最无耻的人或事？》的字数为： 15306 字
# 《历史上都有哪些突破普通人想象的真实事件？》的字数为： 11994 字
# 《在追女生过程中，要不要每天都找她聊天？什么样的表现应该止损放弃？》的字数为： 4740 字
# 《如何以“这是我死去的第十年”为开头，写一个故事？》的字数为： 15586 字
# 《如果社会以暴制暴会怎样？能否降低犯罪率？》的字数为： 7863 字
# 《恋爱关系中最可笑最心酸的事是什么？》的字数为： 12219 字
# 《恋爱的过程，如何从普通朋友到情侣关系呢？》的字数为： 4085 字
# 《我的Siri自杀了》的字数为： 12258 字
# 《有什么精彩绝伦的小故事吗？》的字数为： 15844 字
# 《有哪些很短却很悲伤的故事？》的字数为： 15947 字
# 《有文化可以有多可怕？》的字数为： 15729 字
# 《第四夜：老男孩》的字数为： 4195 字
# 《追女生你犯过哪些低级的错误呢，有什么经验可以分享？》的字数为： 4107 字
# 《高智商犯罪恐怖到什么程度？》的字数为： 15714 字
# 《不善言辞的你，最终是如何通过公务员/事业单位面试的》的字数为： 4958 字
# 《你在老师办公室见过哪些令人窒息的操作？》的字数为： 12084 字
# 《你曾经为了治病，尝试过哪些奇葩的偏方？》的字数为： 8303 字
# 《你看过最恐怖的鬼故事是什么？》的字数为： 10460 字
# 《医生遇到过哪些“这居然都能活下来”的病人？》的字数为： 11192 字
# 《女孩应该知道的妇科常识有哪些？》的字数为： 6425 字
# 《如何以最弱超能力为脑洞写一篇故事？》的字数为： 14538 字
# 《如何保持长期、持续、稳定的努力？》的字数为： 5808 字
# 《怎样理解‘无知者无畏’？》的字数为： 8834 字
# 《有哪些很虐心的短篇小说？》的字数为： 15756 字
# 《有没有很短，结局又神反转的故事或神结局？》的字数为： 15571 字
# 《有没有虐妻一时爽追妻火葬场的文？》的字数为： 15905 字
# 《遇见的奇葩病人都有哪些？》的字数为： 8806 字
# 《飞机坠毁时的乘客是什么样的感觉？》的字数为： 8496 字
# 《一个母亲真的能毁好几代人吗？》的字数为： 15712 字
# 《如何以“我捡到一个又瞎又聋的少年”为开头写一个故事》的字数为： 15811 字
# 《有些人可以恶心到什么程度？》的字数为： 15552 字
# 《有哪一刻让人觉得最愤怒？》的字数为： 15552 字

# %%
for i in range(len(novel_data)):  
    text_data=novel_data[i]['text']
    start_index = text_data.find("出自专栏")
    if start_index == -1:
        continue
    end_index = text_data.find("\n", start_index)
    if start_index != -1 and end_index != -1:  
        novel_data[i]['text']= text_data[end_index+1:]  
    else:  
        print(f"{novel_data[i]['name']}出自专栏后没有换行符")  

for i in range(len(novel_data)):  
    text_data=novel_data[i]['text']
    start_index = text_data.find("备案号")
    if start_index == -1:
        continue
    novel_data[i]['text']= text_data[:start_index]

# %%
# 安装必要的库
# !pip install jieba loguru openai -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple, http://pypi.douban.com/simple, https://pypi.tuna.tsinghua.edu.cn/simple, http://pypi.mirrors.ustc.edu.cn/simple, http://pypi.hustunique.com
# Collecting jieba
#   Downloading http://mirrors.bfsu.edu.cn/pypi/web/packages/c6/cb/18eeb235f833b726522d7ebed54f2278ce28ba9438e3135ab0278d9792a2/jieba-0.42.1.tar.gz (19.2 MB)
#                                               0.0/19.2 MB ? eta -:--:--
#                                              0.0/19.2 MB 653.6 kB/s eta 0:00:30
#                                              0.1/19.2 MB 871.5 kB/s eta 0:00:22
#                                               0.2/19.2 MB 1.4 MB/s eta 0:00:14
#      -                                        0.5/19.2 MB 2.8 MB/s eta 0:00:07
#      --                                       1.0/19.2 MB 4.4 MB/s eta 0:00:05
#      ---                                      1.8/19.2 MB 6.4 MB/s eta 0:00:03
#      ----                                     2.2/19.2 MB 6.8 MB/s eta 0:00:03
#      -----                                    2.5/19.2 MB 6.6 MB/s eta 0:00:03
#      -----                                    2.6/19.2 MB 6.6 MB/s eta 0:00:03
#      -----                                    2.7/19.2 MB 5.9 MB/s eta 0:00:03
#      -----                                    2.8/19.2 MB 5.3 MB/s eta 0:00:04
#      -----                                    2.9/19.2 MB 5.2 MB/s eta 0:00:04
#      -----                                    2.9/19.2 MB 5.2 MB/s eta 0:00:04
#      -----                                    2.9/19.2 MB 5.2 MB/s eta 0:00:04
#      -------                                  3.4/19.2 MB 4.8 MB/s eta 0:00:04
#      -------                                  3.4/19.2 MB 4.6 MB/s eta 0:00:04
#      -------                                  3.4/19.2 MB 4.6 MB/s eta 0:00:04
#      --------                                 3.9/19.2 MB 4.6 MB/s eta 0:00:04
#      --------                                 3.9/19.2 MB 4.6 MB/s eta 0:00:04
#      --------                                 3.9/19.2 MB 4.2 MB/s eta 0:00:04
#      ---------                                4.4/19.2 MB 4.5 MB/s eta 0:00:04
#      ---------                                4.8/19.2 MB 4.6 MB/s eta 0:00:04
#      ----------                               5.1/19.2 MB 4.8 MB/s eta 0:00:03
#      -----------                              5.4/19.2 MB 4.9 MB/s eta 0:00:03
#      -----------                              5.6/19.2 MB 4.9 MB/s eta 0:00:03
#      ------------                             5.8/19.2 MB 4.8 MB/s eta 0:00:03
#      ------------                             6.0/19.2 MB 4.7 MB/s eta 0:00:03
#      ------------                             6.2/19.2 MB 4.7 MB/s eta 0:00:03
#      -------------                            6.3/19.2 MB 4.7 MB/s eta 0:00:03
#      -------------                            6.5/19.2 MB 4.6 MB/s eta 0:00:03
#      -------------                            6.6/19.2 MB 4.6 MB/s eta 0:00:03
#      --------------                           6.8/19.2 MB 4.6 MB/s eta 0:00:03
#      --------------                           7.0/19.2 MB 4.6 MB/s eta 0:00:03
#      --------------                           7.2/19.2 MB 4.5 MB/s eta 0:00:03
#      ---------------                          7.4/19.2 MB 4.5 MB/s eta 0:00:03
#      ---------------                          7.5/19.2 MB 4.5 MB/s eta 0:00:03
#      ---------------                          7.7/19.2 MB 4.5 MB/s eta 0:00:03
#      ----------------                         7.8/19.2 MB 4.4 MB/s eta 0:00:03
#      ----------------                         7.9/19.2 MB 4.4 MB/s eta 0:00:03
#      -----------------                        8.2/19.2 MB 4.4 MB/s eta 0:00:03
#      -----------------                        8.4/19.2 MB 4.4 MB/s eta 0:00:03
#      -----------------                        8.6/19.2 MB 4.4 MB/s eta 0:00:03
#      ------------------                       8.7/19.2 MB 4.4 MB/s eta 0:00:03
#      ------------------                       8.9/19.2 MB 4.3 MB/s eta 0:00:03
#      ------------------                       9.0/19.2 MB 4.3 MB/s eta 0:00:03
#      -------------------                      9.2/19.2 MB 4.3 MB/s eta 0:00:03
#      -------------------                      9.4/19.2 MB 4.3 MB/s eta 0:00:03
#      -------------------                      9.6/19.2 MB 4.3 MB/s eta 0:00:03
#      --------------------                     9.7/19.2 MB 4.3 MB/s eta 0:00:03
#      --------------------                     9.9/19.2 MB 4.3 MB/s eta 0:00:03
#      ---------------------                    10.1/19.2 MB 4.3 MB/s eta 0:00:03
#      ---------------------                    10.2/19.2 MB 4.2 MB/s eta 0:00:03
#      ---------------------                    10.4/19.2 MB 4.4 MB/s eta 0:00:02
#      ----------------------                   10.6/19.2 MB 4.4 MB/s eta 0:00:02
#      ----------------------                   10.8/19.2 MB 4.3 MB/s eta 0:00:02
#      ----------------------                   10.9/19.2 MB 4.3 MB/s eta 0:00:02
#      -----------------------                  11.1/19.2 MB 4.2 MB/s eta 0:00:02
#      -----------------------                  11.1/19.2 MB 4.2 MB/s eta 0:00:02
#      -----------------------                  11.2/19.2 MB 4.1 MB/s eta 0:00:02
#      ------------------------                 11.7/19.2 MB 4.0 MB/s eta 0:00:02
#      ------------------------                 11.8/19.2 MB 4.0 MB/s eta 0:00:02
#      ------------------------                 11.9/19.2 MB 3.9 MB/s eta 0:00:02
#      -------------------------                12.1/19.2 MB 3.9 MB/s eta 0:00:02
#      -------------------------                12.3/19.2 MB 3.8 MB/s eta 0:00:02
#      --------------------------               12.5/19.2 MB 3.8 MB/s eta 0:00:02
#      --------------------------               12.7/19.2 MB 3.8 MB/s eta 0:00:02
#      --------------------------               12.9/19.2 MB 3.8 MB/s eta 0:00:02
#      ---------------------------              13.1/19.2 MB 4.1 MB/s eta 0:00:02
#      ---------------------------              13.3/19.2 MB 4.0 MB/s eta 0:00:02
#      ---------------------------              13.3/19.2 MB 4.0 MB/s eta 0:00:02
#      ----------------------------             13.6/19.2 MB 3.9 MB/s eta 0:00:02
#      ----------------------------             13.8/19.2 MB 4.1 MB/s eta 0:00:02
#      ----------------------------             13.8/19.2 MB 4.0 MB/s eta 0:00:02
#      -----------------------------            14.0/19.2 MB 3.9 MB/s eta 0:00:02
#      -----------------------------            14.1/19.2 MB 4.1 MB/s eta 0:00:02
#      -----------------------------            14.3/19.2 MB 4.0 MB/s eta 0:00:02
#      ------------------------------           14.5/19.2 MB 3.9 MB/s eta 0:00:02
#      ------------------------------           14.7/19.2 MB 3.9 MB/s eta 0:00:02
#      -------------------------------          15.0/19.2 MB 3.9 MB/s eta 0:00:02
#      -------------------------------          15.2/19.2 MB 3.8 MB/s eta 0:00:02
#      -------------------------------          15.3/19.2 MB 3.8 MB/s eta 0:00:02
#      --------------------------------         15.5/19.2 MB 3.8 MB/s eta 0:00:01
#      --------------------------------         15.7/19.2 MB 3.7 MB/s eta 0:00:01
#      --------------------------------         15.8/19.2 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------        16.0/19.2 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------        16.2/19.2 MB 3.7 MB/s eta 0:00:01
#      ----------------------------------       16.3/19.2 MB 3.7 MB/s eta 0:00:01
#      ----------------------------------       16.5/19.2 MB 3.7 MB/s eta 0:00:01
#      ----------------------------------       16.7/19.2 MB 3.7 MB/s eta 0:00:01
#      -----------------------------------      16.8/19.2 MB 3.7 MB/s eta 0:00:01
#      -----------------------------------      17.0/19.2 MB 3.7 MB/s eta 0:00:01
#      -----------------------------------      17.2/19.2 MB 3.7 MB/s eta 0:00:01
#      ------------------------------------     17.3/19.2 MB 3.7 MB/s eta 0:00:01
#      ------------------------------------     17.5/19.2 MB 3.7 MB/s eta 0:00:01
#      ------------------------------------     17.6/19.2 MB 3.7 MB/s eta 0:00:01
#      -------------------------------------    17.8/19.2 MB 3.7 MB/s eta 0:00:01
#      -------------------------------------    18.0/19.2 MB 3.7 MB/s eta 0:00:01
#      -------------------------------------    18.2/19.2 MB 3.7 MB/s eta 0:00:01
#      --------------------------------------   18.3/19.2 MB 3.7 MB/s eta 0:00:01
#      --------------------------------------   18.5/19.2 MB 3.7 MB/s eta 0:00:01
#      --------------------------------------   18.6/19.2 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------  18.8/19.2 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------  19.0/19.2 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------  19.1/19.2 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------  19.2/19.2 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------- 19.2/19.2 MB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting loguru
#   Downloading http://mirrors.bfsu.edu.cn/pypi/web/packages/03/0a/4f6fed21aa246c6b49b561ca55facacc2a44b87d65b8b92362a8e99ba202/loguru-0.7.2-py3-none-any.whl (62 kB)
#                                               0.0/62.5 kB ? eta -:--:--
#      --------------------------------         51.2/62.5 kB ? eta -:--:--
#      ---------------------------------------- 62.5/62.5 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: openai in d:\download\miniconda3\lib\site-packages (1.21.2)
# Requirement already satisfied: colorama>=0.3.4 in d:\download\miniconda3\lib\site-packages (from loguru) (0.4.6)
# Collecting win32-setctime>=1.0.0 (from loguru)
#   Downloading http://mirrors.bfsu.edu.cn/pypi/web/packages/0a/e6/a7d828fef907843b2a5773ebff47fb79ac0c1c88d60c0ca9530ee941e248/win32_setctime-1.1.0-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\download\miniconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\download\miniconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\download\miniconda3\lib\site-packages (from openai) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\download\miniconda3\lib\site-packages (from openai) (2.6.0)
# Requirement already satisfied: sniffio in d:\download\miniconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in d:\download\miniconda3\lib\site-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in d:\download\miniconda3\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in d:\download\miniconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in d:\download\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in d:\download\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\download\miniconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\download\miniconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.1 in d:\download\miniconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.16.1)
# Building wheels for collected packages: jieba
#   Building wheel for jieba (setup.py): started
#   Building wheel for jieba (setup.py): finished with status 'done'
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314474 sha256=259e426fdb536d6316a62de2e1ba732b93ca79041a300da29481e481a7b36461
#   Stored in directory: c:\users\ymy\appdata\local\pip\cache\wheels\44\4e\6f\0cb0f11a4eb633edeccde3d7c8be1ad1e4f1744b488d7e691c
# Successfully built jieba
# Installing collected packages: jieba, win32-setctime, loguru
# Successfully installed jieba-0.42.1 loguru-0.7.2 win32-setctime-1.1.0
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/jieba/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/jieba/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/jieba/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/jieba/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/jieba/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/loguru/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/loguru/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/loguru/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/loguru/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/loguru/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/win32-setctime/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/win32-setctime/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/win32-setctime/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/win32-setctime/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/win32-setctime/

# %%
data = novel_data[3]["text"]
story_name = novel_data[3]["name"]
data
# Out:
# '仙门大比\n重回剑仙少年时\n1\n第二日清晨，我得到了仙盟盟主的接见，令人诧异的是，他的修为显然不大高。也没和我臭美的师父一样掩盖年龄，正是一个普通中年修士所该有的方正模样。\n盟主姓孟，笑眯眯地道：“你姨母早就给我来信说，你要来找谢如寂了。我很久以前就把如寂看作我自己的孩子，他天赋异禀，若是鲤鱼洲少主相配，也算是佳缘一桩。”\n我压下一点对盟主的冷笑，纠正道：“是来找谢如寂和晚尔尔，晚尔尔她——”\n门口有人走了进来，谢如寂握着剑，一身的露气，昨夜里那么晚还在忙，现在又已经执行任务回来了，真是有点不知疲惫在身上的。\n谢如寂将一枚令牌交到孟盟主手上，后者眉眼舒缓，长叹一声道：“辛苦了如寂。那边新运了几只妖魔过来，等会还劳你审讯一下。”\n他点点头，可我垂下眼，正见谢如寂的指尖因劳累而有些颤抖。\n孟盟主喟叹道：“仙盟能者众多，可如你一般的人绝无仅有，若真有朝一日天下纷乱，还要靠你来挑起大梁。”\n我这就有点听不下去了，我知道修真界一直对谢如寂怀有很重的期望，可是哪有把什么希望都压在一个人身上的。他再怎样剑道出众，始终是一个人罢了。\n我抬起眼，笑了笑：“盟主，我就要回扶陵宗了，想让谢如寂送送我。”\n盟主本就期望看见我和谢如寂在一块，立即放人道：“那既然如此，如寂你就去吧。”\n谢如寂和我并肩在仙盟里走。仙盟人员往来频繁，几乎每一刻都会有象征不同讯息的铃声响起来，匆忙的步伐往来错乱，各方异动越发频繁。正见有人正指挥着把新捉的魔族给关进牢狱之中去，被扣押的魔族难得生得和人类相像许多，且是个小孩，身形中很像那个在千叶镇中给我千叶花的小孩，手脚都被钉了仿制销魂钉。\n谢如寂淡淡地看了我一眼，手上翻过来一幅图卷，所呈正是这魔族小孩的罪行，血腥不能直视。我心照不宣地笑一声：“当然不是他。”\n谢如寂静默了一瞬，问道：“你怎么知道？”\n我想了想说：“因为那只是一个织梦幻境，根本不会有那个小孩。”\n仙盟派了玄凤舟送我回去，我伏在船舷上往下张望，最终还是叫住了他：“谢如寂！”\n他仰起头来。\n我大声道：“天下不关你的事！你别听他们瞎说，他们就是想让你多干活，自己轻松点，你别被骗了啊！”\n他怔了一瞬，很浅淡地勾起了一个微笑，眉眼弯弯。\n2\n玄凤舟起飞时晚尔尔赶到，大约是在仙盟待得够久了，也该和我回去了。\n我和晚尔尔一同回了扶陵宗，路上倒也安静。恰好回来的时候，师父也在宗门内，我与晚尔尔便先去了主殿见他。师父看起来十分疲惫，连说话都没什么力气，他大概听了一下所谓失踪事件的情况，就让晚尔尔出去了。\n师父想摸我的头，才发现我原不是那个小姑娘了，这时候我才从皮相之下看出他的苍老来。我问师父：“这段时间出了很多事吗？”\n他应了一声，头一次露出一点软弱来，怅然道：“修真界的将来，还是要靠你们这些后辈了。”\n我有个疑问现在才问出来：“师父，为什么你收我当徒弟呢？后来晚尔尔进门，你都没收下她。”\n师父用看傻子的表情看了我一眼，慢吞吞道：“因为你们鲤鱼洲，承诺给主殿翻新啊。你小时候长得也算可爱，只是眼神凶戾不服输了一些。”\n我就不该嘴贱多问这一句。\n师父压低声音，窗外忽而飘雪，竟然已经由初春兜转到冬的时令了，一年很快就要过去，师父道：“开了春是十年一次的昆仑虚大比，但凡有点名头的仙门弟子都会去，我听闻这次的奖品中或许有玉龙图。如今修真界因着那个传言和各方频繁的异动，都十分紧张，这次的昆仑虚大比，是一个极好的重振信心的机会，你要好好准备。”\n上辈子因着身心缘故，师父把我留在扶陵宗中，没让我出去，这次没想到提早了这么多就告诉我了。我捏紧了手中剑，掌心濡湿一片，那可是玉龙图，心里涌起火热。\n上古玉龙图，鲤鱼洲曾有秘宝玉龙门，后来随着时代变迁不知道何所去向，而玉龙图就是能指引人找到这个神器的藏图。鲤鱼洲历代洲主总是有才能天赋极其出众的人，只是除了初代洲主再没有人能飞升龙神。\n诸人猜测，就是因为缺少神器玉龙门的缘故。\n我心里热血沸腾，匆匆与师父道别了就出去加练了。我有许多欢喜，像是头一回尝到上苍眷顾的甜头，一直跑到殿外，白雪淋了满头时，才冷下来。\n知道这样的消息，在雪中差点摔了一跤，我这般欢喜，不知道有谁可以，头一个想到的就是贺辞声。我跑回房中拿出纸笔，咬着笔头在信纸上写下：“贺辞声，谢谢你的足链，很有用。我有个好消息，但我不想现在告诉你，想要亲口和你说，来年开春见。”我把信纸变作一只憨态的鱼的模样，金光闪过，我定位为昆仑虚，这秘术会将我的信带给他的。\n不知道贺辞声怎么样了。我一直不知道贺辞声究竟得的什么病，就连师父也不知道，只是平时虚弱一些，看着与常人没什么大碍。只是上回他说找到了他的药，不知道有没有用，还是得下回见到他再问问清楚比较好。\n我这样期待着贺辞声的回信，但是直到雪落完了，扶陵山第一支桃花都开了，我都没收到他的回信。\n3\n谢如寂果真遵守他的诺言，在仙盟的事情处理得差不多的时候，就抽空回来教我练剑了。\n我第一次真的进了剑冢。这世间道法本就不一，修真之人用的最多的还是剑，谢如寂恰恰就是天生拿剑之人。他常年所佩之剑名为如寂，不像我的玉龙剑一样有什么渊源，在此之前从未听过这把剑的名字。但谢如寂握了它，它就此出名。\n我在鲤鱼洲的时候没荒废修炼，又加上鲤鱼洲的灵气是世间少有的丰沛之地，修为更是上了一层楼。只是练剑时遭遇了不少困境，行至玉龙剑诀第二卷，就算有玉书心经的指导，我行得也实在艰难。\n剑冢内不知埋葬了多少断剑，连带着旧主的哭泣声，在无望崖下终日长啸。\n因着有谢如寂在的缘故，剑气倒没像从前那样乱飞。即使在白日，这崖底也十分昏暗，抬头只能见一隙光印入，很难想象他在这样的场景内待了这么多年。\n谢如寂提灯开路，一盏灯光晃悠悠地在我前头。\n边上风声不断，我开口问道：“谢剑君，你从什么时候开始在剑冢参悟剑意的？”\n谢如寂侧过一点头，下颌在发丝掩映下露出白：“十二岁。”\n我了然地点点头，那还是一个半大孩子呢：“在这里想必孤独可怖。”\n谢如寂淡淡道：“倒没什么可怕，在哪里对我来说是一样的。”\n我不知道怎么说话，谢如寂突然停步，说：“到了。”\n谢如寂把我带到的这里是一个剑气比较少的地方，但剑气却都十分凶狠地横冲直撞，被擦到一点边都该躺上床休养许久吧。谢如寂退后一步，拣了块石头坐着了，他扬了扬下巴：“去吧，让我看看你的水平。”\n我呼了口气，玉龙剑哗然出鞘，冷光铮然，我借力而起。结果这几道剑气来势汹汹，知道我是女道，偏偏往我脸上撞，像是戏耍一般，我躲避不及，索性用挥出玉龙来吞掉剑意。只是这样下来，只能算是勉勉强强，到最后还是谢如寂从剑意下把我捞出来的。\n我累得倒在地上，眼瞧着谢如寂的鞋在我眼前停下，汗水迷蒙视线，十分狼狈。我气喘吁吁地问：“谢如寂，为什么我不能练剑？”\n为什么我不该练剑？\n谢如寂垂下眼，眼睫遮住深深浅浅：“朝珠。寡情的人，剑才挥得快，而你多情。”\n4\n谢如寂给我上的第一课，就是让我知晓了自己在他眼底的生涩。\n他让我在剑意之中闭眼打坐，好好听听那些剑风。我便照做，这些剑风在我耳边呼啸，头两个时辰，我只觉刺耳混沌，好在我什么都不多，只有耐心足够。只是渐渐地感觉出不同来，每一道有每一道不同的感觉。\n有的稍柔和，有的凌厉。唯有听清剑语，遇上时才知晓如何去应对。\n我突然有点意会了。我睁开眼，再用玉龙剑应对那些剑气时就不觉得方才那么吃力。我对自己的一点小突破有点欢喜，抬起眼看谢如寂，他不知何时，竟然靠着后头的石壁睡着了，他的衣角里露出了半枚仙盟的令牌，上头不时有玄色的光亮起来。\n我之前在仙盟时待过，所以知道这是有事召的意思。他眼下有青色，谢如寂和我师父，一个比一个疲惫。他梦见了很不好的东西，连眉心都是皱起来的。\n谢如寂很敏锐，我才刚看了他一下，他立时就醒了过来，揉了揉眉心，声音有些低哑：“我睡着了。”\n我把我带来的东西都收拾好，应了声：“我刚好也累了，那就明日再说吧。”\n谢如寂默许，起身道：“我送你上去吧。”\n我没反对，要是我一个人再走一遍刚刚的路，可能会被那些亡剑的残魂给分吃掉。又是十分安静地走了刚刚那条路，谢如寂踏着剑意而起，揪着我的衣领，我还没反应过来，就已经在崖边的平地上了。谢如寂长发高束，目如流星，这时候才有一些少年人的意气模样。\n我落在平地上，没多说什么，就回我的小院落去了。\n雪已经停了，我翻上围墙时，旁边的院子空空荡荡，我不禁感叹一声，毕竟在我的想象里，理应有一个贺辞声在隔壁埋烤红薯吃的。\n5\n我在谢如寂这边学剑，每次都要到竭尽所有气力了，才能回来，但是效果也是立竿见影的，我甚至能勉强自己在剑冢之中行走了，玉龙剑诀的第二卷在他的教导之下，竟然一次性开完了。\n我不禁感叹，有第一剑开小灶，原来是这样好的事情。\n这日我在谢如寂这里练完剑，谢如寂开口道：“明天暂歇一日，不必再来。”\n我看他收回剑的动作有些凝滞，外头天寒地冻，虽然我们是修真人，但也是能感受到四时变换的。谢如寂常年都穿玄衣，也没见得衣服增添，怪不得我见他面色苍白。\n我收剑时犹豫了一下，才嘱咐道：“天寒地冻，剑君注意保暖。”\n谢如寂轻轻嗯了声，我没什么好磨蹭逗留的，转身就走了。结果第二天早起，见外头霜叶瑟瑟，才发觉身上的玄鱼佩不知去路，想必是练剑的时候丢在无望崖下了。\n我便沿着雪回去，今日无望崖下的剑意十分凶戾，我到昨日里练剑的地方时，几乎身上十分狼狈，被刮出许多血痕来，最终几近逃难一般一头栽进雪里才躲过一道穷追不舍的罡风。我捡起昨日里丢失的玄鱼佩，便准备往回走，却见深处一点光亮，我侧耳倾听像是有些异动，那是无望崖下的一处深潭，像是有人在那里。\n我本就无意接近，抓起一把雪擦去额头上刚刚摔出的血痕。\n正见风雪慢慢，晚尔 ...

# %%
# 拆分《呼啸山庄》的文本为 800 字一段的段落
import jieba

paragraphs = []
for i in range(len(novel_data)):
    # 读取数据集中第 4 本小说《呼啸山庄》的文本作为训练集数据来源
    data = novel_data[i]["text"]
    story_name = novel_data[i]["name"]
    # 利用jieba进行句子切分
    sentences = []

    for sentence in data.split('\n'):  # 使用\n作为切分符
        sentences.append(sentence)

    # 将句子合并成800字一段的段落
    current_paragraph = ''
    for sentence in sentences:
        if len(current_paragraph) + len(sentence) <= 800:
            current_paragraph += sentence
        else:
            paragraphs.append(current_paragraph.strip())
            current_paragraph = sentence

    # 将最后一段加入到段落列表中
    if current_paragraph:
        paragraphs.append(current_paragraph.strip())
    if i % 1000 == 0:
        print(f"已处理{i}本小说")
# Out:
# 已处理0本小说
# 已处理100本小说
# 已处理200本小说
# 已处理300本小说
# 已处理400本小说
# 已处理500本小说
# 已处理600本小说
# 已处理700本小说
# 已处理800本小说
# 已处理900本小说
# 已处理1000本小说
# 已处理1100本小说
# 已处理1200本小说
# 已处理1300本小说
# 已处理1400本小说
# 已处理1500本小说
# 已处理1600本小说
# 已处理1700本小说
# 已处理1800本小说
# 已处理1900本小说
# 已处理2000本小说
# 已处理2100本小说
# 已处理2200本小说
# 已处理2300本小说
# 已处理2400本小说
# 已处理2500本小说
# 已处理2600本小说
# 已处理2700本小说
# 已处理2800本小说
# 已处理2900本小说
# 已处理3000本小说
# 已处理3100本小说
# 已处理3200本小说
# 已处理3300本小说
# 已处理3400本小说
# 已处理3500本小说
# 已处理3600本小说
# 已处理3700本小说
# 已处理3800本小说
# 已处理3900本小说
# 已处理4000本小说
# 已处理4100本小说
# 已处理4200本小说
# 已处理4300本小说
# 已处理4400本小说
# 已处理4500本小说
# 已处理4600本小说
# 已处理4700本小说
# 已处理4800本小说
# 已处理4900本小说
# 已处理5000本小说
# 已处理5100本小说
# 已处理5200本小说
# 已处理5300本小说
# 已处理5400本小说
# 已处理5500本小说
# 已处理5600本小说
# 已处理5700本小说
# 已处理5800本小说
# 已处理5900本小说
# 已处理6000本小说
# 已处理6100本小说
# 已处理6200本小说
# 已处理6300本小说
# 已处理6400本小说
# 已处理6500本小说
# 已处理6600本小说
# 已处理6700本小说
# 已处理6800本小说
# 已处理6900本小说
# 已处理7000本小说
# 已处理7100本小说
# 已处理7200本小说
# 已处理7300本小说
# 已处理7400本小说
# 已处理7500本小说
# 已处理7600本小说
# 已处理7700本小说
# 已处理7800本小说
# 已处理7900本小说
# 已处理8000本小说
# 已处理8100本小说
# 已处理8200本小说
# 已处理8300本小说
# 已处理8400本小说
# 已处理8500本小说
# 已处理8600本小说
# 已处理8700本小说
# 已处理8800本小说
# 已处理8900本小说
# 已处理9000本小说
# 已处理9100本小说
# 已处理9200本小说

# %%
len(paragraphs)
# Out:
# 139537

# %%
from loguru import logger
import json
from tqdm import tqdm
import time
import os
from openai import OpenAI
# 配置loguru输出到文件
logger.remove()  # 移除默认的控制台输出
logger.add("logs/app_{time:YYYY-MM-DD}.log", level="INFO", rotation="00:00", retention="10 days")
# Out:
# 1

# %%
# 使用deepseek-chat api给段落打标签的接口
def get_response(text):
    client = OpenAI(
        api_key="sk-ad4b59759cfd41228839ddc634fa29f6",  # 如果您没有配置环境变量，请在此处用您的API Key进行替换
        base_url="https://api.deepseek.com",  # 填写DashScope SDK的base_url
    )
    completion = client.chat.completions.create(
        model="deepseek-chat",
        messages=[
            {
                'role': 'system', 
                'content': '总结user提交的内容。用一句不超过50字的话总结这段小说的情节。仅回答总结，不需要添加其他内容。'
            },
            {
                'role': 'user', 
                'content': text
            }
        ])
    
    return completion.choices[0].message.content

# %%
# 设置容错机制，可最多重试 5 次，如果失败记录错误日志
def get_summary_with_retry(text):
    max_retries = 5
    retry_delay = 5  # in seconds
    attempts = 0
    while attempts < max_retries:
        try:
            return get_response(text)
        except Exception as e:
            attempts += 1
            if attempts < max_retries:
                logger.warning(f"Attempt {attempts} failed for text: {text}. Retrying in {retry_delay} seconds...")
                time.sleep(retry_delay)
            else:
                logger.error(f"All {max_retries} attempts failed for text: {text}. Error: {e}")
                raise

# %%
# 创建文件夹
os.makedirs('data', exist_ok=True)
os.makedirs('output', exist_ok=True)
os.makedirs('dataset', exist_ok=True)

# %%
# 批量给指定的小说打标签的接口函数
def build_dataset(ind,texts):
    instruction_prompt = "你是一个熟读各类小说的专家，请你根据要求写一段800字左右的小说。请根据背景确定故事风格和文风，要求该故事有完整的起因、发展、高潮、结尾，在800字内结束故事。尽可能让故事情节精彩、引人入胜。"
    dataset = []
    dataset_error = []
    for text in tqdm(texts, desc=f"Processing {ind}", total=len(texts)):
        try:
            summary = get_summary_with_retry(text)
            # print(summary)
            dataset.append({
                "instruction": instruction_prompt,
                "input": summary,
                "output": text
            })
        except Exception as e:
            dataset_error.append(text)
            logger.error(f"Failed to process text: {text}. Error: {e}")
    
    with open(f"./data/{ind}_zhihu.json", "w") as f:
        f.write(json.dumps(dataset, ensure_ascii=False, indent=4))

    with open(f"./data/{ind}_error.txt", "w") as f:
        f.write(json.dumps(dataset_error, ensure_ascii=False, indent=4))
    return dataset

# %%
for i in range(0,len(paragraphs),1000):
    dataset = build_dataset(i,paragraphs[i:i+1000])
# Out:
# Processing 0: 100%|██████████| 1000/1000 [58:58<00:00,  3.54s/it]
# Processing 1000:  25%|██▍       | 249/1000 [14:29<43:43,  3.49s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 for i in range(0,len(paragraphs),1000):
# ----> 2     dataset = build_dataset(i,paragraphs[i:i+1000])
#
# Cell In[19], line 8, in build_dataset(ind, texts)
#       6 for text in tqdm(texts, desc=f"Processing {ind}", total=len(texts)):
#       7     try:
# ----> 8         summary = get_summary_with_retry(text)
#       9         # print(summary)
#      10         dataset.append({
#      11             "instruction": instruction_prompt,
#      12             "input": summary,
#      13             "output": text
#      14         })
#
# Cell In[11], line 8, in get_summary_with_retry(text)
#       6 while attempts < max_retries:
#       7     try:
# ----> 8         return get_response(text)
#       9     except Exception as e:
#      10         attempts += 1
#
# Cell In[10], line 7, in get_response(text)
#       2 def get_response(text):
#       3     client = OpenAI(
#       4         api_key="sk-ad4b59759cfd41228839ddc634fa29f6",  # 如果您没有配置环境变量，请在此处用您的API Key进行替换
#       5         base_url="https://api.deepseek.com",  # 填写DashScope SDK的base_url
#       6     )
# ----> 7     completion = client.chat.completions.create(
#       8         model="deepseek-chat",
#       9         messages=[
#      10             {
#      11                 'role': 'system',
#      12                 'content': '总结user提交的内容。用一句不超过50字的话总结这段小说的情节。仅回答总结，不需要添加其他内容。'
#      13             },
#      14             {
#      15                 'role': 'user',
#      16                 'content': text
#      17             }
#      18         ])
#      20     return completion.choices[0].message.content
#
# File d:\Download\miniconda3\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File d:\Download\miniconda3\Lib\site-packages\openai\resources\chat\completions.py:581, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     550 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     551 def create(
#     552     self,
#    (...)
#     579     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     580 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 581     return self._post(
#     582         "/chat/completions",
#     583         body=maybe_transform(
#     584             {
#     585                 "messages": messages,
#     586                 "model": model,
#     587                 "frequency_penalty": frequency_penalty,
#     588                 "function_call": function_call,
#     589                 "functions": functions,
#     590                 "logit_bias": logit_bias,
#     591                 "logprobs": logprobs,
#     592                 "max_tokens": max_tokens,
#     593                 "n": n,
#     594                 "presence_penalty": presence_penalty,
#     595                 "response_format": response_format,
#     596                 "seed": seed,
#     597                 "stop": stop,
#     598                 "stream": stream,
#     599                 "temperature": temperature,
#     600                 "tool_choice": tool_choice,
#     601                 "tools": tools,
#     602                 "top_logprobs": top_logprobs,
#     603                 "top_p": top_p,
#     604                 "user": user,
#     605             },
#     606             completion_create_params.CompletionCreateParams,
#     607         ),
#     608         options=make_request_options(
#     609             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     610         ),
#     611         cast_to=ChatCompletion,
#     612         stream=stream or False,
#     613         stream_cls=Stream[ChatCompletionChunk],
#     614     )
#
# File d:\Download\miniconda3\Lib\site-packages\openai\_base_client.py:1233, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1219 def post(
#    1220     self,
#    1221     path: str,
#    (...)
#    1228     stream_cls: type[_StreamT] | None = None,
#    1229 ) -> ResponseT | _StreamT:
#    1230     opts = FinalRequestOptions.construct(
#    1231         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1232     )
# -> 1233     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Download\miniconda3\Lib\site-packages\openai\_base_client.py:922, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     913 def request(
#     914     self,
#     915     cast_to: Type[ResponseT],
#    (...)
#     920     stream_cls: type[_StreamT] | None = None,
#     921 ) -> ResponseT | _StreamT:
# --> 922     return self._request(
#     923         cast_to=cast_to,
#     924         options=options,
#     925         stream=stream,
#     926         stream_cls=stream_cls,
#     927         remaining_retries=remaining_retries,
#     928     )
#
# File d:\Download\miniconda3\Lib\site-packages\openai\_base_client.py:951, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     948     kwargs["auth"] = self.custom_auth
#     950 try:
# --> 951     response = self._client.send(
#     952         request,
#     953         stream=stream or self._should_stream_response_body(request=request),
#     954         **kwargs,
#     955     )
#     956 except httpx.TimeoutException as err:
#     957     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File d:\Download\miniconda3\Lib\site-packages\httpx\_client.py:929, in Client.send(self, request, stream, auth, follow_redirects)
#     927 except BaseException as exc:
#     928     response.close()
# --> 929     raise exc
#
# File d:\Download\miniconda3\Lib\site-packages\httpx\_client.py:923, in Client.send(self, request, stream, auth, follow_redirects)
#     921 try:
#     922     if not stream:
# --> 923         response.read()
#     925     return response
#     927 except BaseException as exc:
#
# File d:\Download\miniconda3\Lib\site-packages\httpx\_models.py:811, in Response.read(self)
#     807 """
#     808 Read and return the response content.
#     809 """
#     810 if not hasattr(self, "_content"):
# --> 811     self._content = b"".join(self.iter_bytes())
#     812 return self._content
#
# File d:\Download\miniconda3\Lib\site-packages\httpx\_models.py:829, in Response.iter_bytes(self, chunk_size)
#     827 chunker = ByteChunker(chunk_size=chunk_size)
#     828 with request_context(request=self._request):
# --> 829     for raw_bytes in self.iter_raw():
#     830         decoded = decoder.decode(raw_bytes)
#     831         for chunk in chunker.decode(decoded):
#
# File d:\Download\miniconda3\Lib\site-packages\httpx\_models.py:887, in Response.iter_raw(self, chunk_size)
#     884 chunker = ByteChunker(chunk_size=chunk_size)
#     886 with request_context(request=self._request):
# --> 887     for raw_stream_bytes in self.stream:
#     888         self._num_bytes_downloaded += len(raw_stream_bytes)
#     889         for chunk in chunker.decode(raw_stream_bytes):
#
# File d:\Download\miniconda3\Lib\site-packages\httpx\_client.py:124, in BoundSyncStream.__iter__(self)
#     123 def __iter__(self) -> typing.Iterator[bytes]:
# --> 124     for chunk in self._stream:
#     125         yield chunk
#
# File d:\Download\miniconda3\Lib\site-packages\httpx\_transports\default.py:111, in ResponseStream.__iter__(self)
#     109 def __iter__(self) -> typing.Iterator[bytes]:
#     110     with map_httpcore_exceptions():
# --> 111         for part in self._httpcore_stream:
#     112             yield part
#
# File d:\Download\miniconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:361, in ConnectionPoolByteStream.__iter__(self)
#     360 def __iter__(self) -> Iterator[bytes]:
# --> 361     for part in self._stream:
#     362         yield part
#
# File d:\Download\miniconda3\Lib\site-packages\httpcore\_sync\http11.py:337, in HTTP11ConnectionByteStream.__iter__(self)
#     335 with ShieldCancellation():
#     336     self.close()
# --> 337 raise exc
#
# File d:\Download\miniconda3\Lib\site-packages\httpcore\_sync\http11.py:329, in HTTP11ConnectionByteStream.__iter__(self)
#     327 try:
#     328     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 329         for chunk in self._connection._receive_response_body(**kwargs):
#     330             yield chunk
#     331 except BaseException as exc:
#     332     # If we get an exception while streaming the response,
#     333     # we want to close the response (and possibly the connection)
#     334     # before raising that exception.
#
# File d:\Download\miniconda3\Lib\site-packages\httpcore\_sync\http11.py:198, in HTTP11Connection._receive_response_body(self, request)
#     195 timeout = timeouts.get("read", None)
#     197 while True:
# --> 198     event = self._receive_event(timeout=timeout)
#     199     if isinstance(event, h11.Data):
#     200         yield bytes(event.data)
#
# File d:\Download\miniconda3\Lib\site-packages\httpcore\_sync\http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File d:\Download\miniconda3\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File d:\Download\miniconda3\Lib\ssl.py:1263, in SSLSocket.recv(self, buflen, flags)
#    1259     if flags != 0:
#    1260         raise ValueError(
#    1261             "non-zero flags not allowed in calls to recv() on %s" %
#    1262             self.__class__)
# -> 1263     return self.read(buflen)
#    1264 else:
#    1265     return super().recv(buflen, flags)
#
# File d:\Download\miniconda3\Lib\ssl.py:1136, in SSLSocket.read(self, len, buffer)
#    1134         return self._sslobj.read(len, buffer)
#    1135     else:
# -> 1136         return self._sslobj.read(len)
#    1137 except SSLError as x:
#    1138     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
num_processes = multiprocessing.cpu_count()
